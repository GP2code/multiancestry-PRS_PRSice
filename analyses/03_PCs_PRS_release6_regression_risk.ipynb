# %% [markdown]
# # Estimate Multi-ancestry PRS versus PD risk
# - **Project:** Multi-ancestry PRS
# - **Version:** Python/3.9
# - **Status:** COMPLETE
# - **Last Updated:** 25-FEB-2024
#
# ## Notebook Overview
# - Logistic regression models adjusted by covariates (age, gender, PCs)

# %%
## Load packages
module load python
module load R
# Out:
# [+] Loading python 3.10  ...
# [+] Loading gcc  11.3.0  ...
# [+] Loading HDF5  1.12.2
# [+] Loading netcdf  4.9.0
# [-] Unloading gcc  11.3.0  ...
# [+] Loading gcc  11.3.0  ...
# [+] Loading openmpi/4.1.3/gcc-11.3.0  ...
# [+] Loading pandoc  2.18  on cn2458
# [+] Loading pcre2  10.40
# [+] Loading R 4.3.2

# %%
## Change kernel to python
import pandas as pd

# Read the file into a DataFrame
file_path = f"{WORK_DIR}/GP2_master_key_release6.txt"
df = pd.read_csv(file_path, delimiter='\t')  # Assuming columns are tab-separated, adjust if needed

# Add a new column with "0"
df.insert(0, 'New_Column', 0)

# Extract columns GP2sampleID and sex_for_qc
result_df = df[['New_Column', 'GP2sampleID', 'sex_for_qc', 'age']]

# Save the result to a CSV file without headers
result_df.to_csv(f'{WORK_DIR}/covariates.txt', index=False, header=True, sep = '\t')

# %%
cd ${WORK_DIR}/quality_control/release6/genotype_qc/
ls *eigenvec
# Out:
# GP2_release6_NOVEMBER_2023_AAC.eigenvec
# GP2_release6_NOVEMBER_2023_AFR.eigenvec
# GP2_release6_NOVEMBER_2023_AJ.eigenvec
# GP2_release6_NOVEMBER_2023_AMR.eigenvec
# GP2_release6_NOVEMBER_2023_CAH.eigenvec
# GP2_release6_NOVEMBER_2023_CAS.eigenvec
# GP2_release6_NOVEMBER_2023_EAS.eigenvec
# GP2_release6_NOVEMBER_2023_EUR.eigenvec
# GP2_release6_NOVEMBER_2023_FIN.eigenvec
# GP2_release6_NOVEMBER_2023_MDE.eigenvec
# GP2_release6_NOVEMBER_2023_SAS.eigenvec
# GP2_release6_NOVEMBER_AAC_maf_hwe_pca.eigenvec
# GP2_release6_NOVEMBER_AFR_maf_hwe_pca.eigenvec
# GP2_release6_NOVEMBER_AJ_maf_hwe_pca.eigenvec
# GP2_release6_NOVEMBER_AMR_maf_hwe_pca.eigenvec
# GP2_release6_NOVEMBER_CAS_maf_hwe_pca.eigenvec
# GP2_release6_NOVEMBER_EAS_maf_hwe_pca.eigenvec
# GP2_release6_NOVEMBER_EUR_maf_hwe_pca.eigenvec
# GP2_release6_NOVEMBER_FIN_maf_hwe_pca.eigenvec
# GP2_release6_NOVEMBER_MDE_maf_hwe_pca.eigenvec
# GP2_release6_NOVEMBER_SAS_maf_hwe_pca.eigenvec

# %%
import pandas as pd
import statsmodels.api as sm

## RUN PRS versus RISK across ancestries (AFRICAN summary stats)
# List of ancestries
ancestries = ["AAC", "AFR", "AJ", "AMR", "EAS", "EUR", "CAS"]

for ancestry in ancestries:  
    print("Ancestry:", ancestry)
    # Construct file paths
    prs_file = f"{WORK_DIR}/imputed_data/" + ancestry + "/PRS_score_release_AFRICANS.profile"
    covs_file = f"{WORK_DIR}/quality_control/release6/genotype_qc/GP2_release6_NOVEMBER_" + ancestry + "_maf_hwe_pca.eigenvec"

    # Read PRS data
    temp_data = pd.read_csv(prs_file, delim_whitespace =True)

    # Read covariates data
    # Specify your custom column names
    custom_column_names = ["FID", "IID", "PC1", "PC2", "PC3", "PC4", "PC5", "PC6", "PC7", "PC8", "PC9", "PC10"]

    # Read the tab-delimited file, skip the first line, and use custom column names
    temp_covs = pd.read_csv(covs_file, delim_whitespace =True, skiprows=1, names=custom_column_names)

    # Read additional covariates
    temp_covs_2 = pd.read_csv(f"{WORK_DIR}/covariates.txt", sep="\t")
    temp_covs_2.head()
    temp_covs_2 = temp_covs_2.rename(columns={"GP2sampleID": "IID"})

    # Merge covariates
    covs = pd.merge(temp_covs, temp_covs_2, on="IID")

    # Merge PRS data and covariates
    data = pd.merge(temp_data, covs, on="IID")

    # print("looking a covs")
    # print(covs.head())
    # print("looking at temp_data")
    # print(temp_data.head())
    # print("looking at data")
    # print(data.head())
    # print(data.describe())

    # Remove missing or unknown cases
    dat = data[data["PHENO"] != -9]

    # Logistic regression model phenotype
    dat['CASE'] = dat['PHENO'] - 1 

    # Standardize PRS
    mean_controls = dat.loc[dat["CASE"] == 0, "SCORE"].mean()
    sd_controls = dat.loc[dat["CASE"] == 0, "SCORE"].std()
    dat["zSCORE"] = (dat["SCORE"] - mean_controls) / sd_controls

    # Quick peak at the data
    print("Taking a look at the dataset for " + ancestry + " regression models.")
    print(dat.describe())

    # Logistic regression model using statsmodels formula
    formula = "CASE ~ zSCORE + sex_for_qc + age + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC7 + PC8 + PC9 + PC10"
    model = sm.Logit.from_formula(formula, data=dat)
    result = model.fit()

    # Print the summary
    print(result.summary())

    # Print
    print("Done analyzing " + ancestry + " now on to the next thing.")
# Out:
# Ancestry: AAC
# Taking a look at the dataset for AAC regression models.
#         FID_x        PHENO          CNT         CNT2        SCORE   FID_y  \
# count  1030.0  1030.000000  1030.000000  1030.000000  1030.000000  1030.0
# mean      0.0     1.242718   166.126214    81.626214    -0.004264     0.0
# std       0.0     0.428935     1.980368     5.026373     0.003391     0.0
# min       0.0     1.000000   156.000000    66.000000    -0.015085     0.0
# 25%       0.0     1.000000   166.000000    78.000000    -0.006524     0.0
# 50%       0.0     1.000000   166.000000    82.000000    -0.004318     0.0
# 75%       0.0     1.000000   168.000000    85.000000    -0.002065     0.0
# max       0.0     2.000000   168.000000    97.000000     0.007922     0.0
#
#                PC1          PC2          PC3          PC4  ...          PC6  \
# count  1030.000000  1030.000000  1030.000000  1030.000000  ...  1030.000000
# mean     -0.009980     0.003704     0.000382     0.000388  ...    -0.000329
# std       0.017125     0.022483     0.030607     0.010635  ...     0.030206
# min      -0.033599    -0.045752    -0.458968    -0.047664  ...    -0.436147
# 25%      -0.020904    -0.009009    -0.000814    -0.006343  ...    -0.009340
# 50%      -0.014576     0.003609     0.004129     0.000099  ...    -0.000538
# 75%      -0.004136     0.013117     0.008565     0.006900  ...     0.009240
# max       0.074809     0.124427     0.026472     0.050560  ...     0.196375
#
#                PC7          PC8          PC9         PC10  New_Column  \
# count  1030.000000  1030.000000  1030.000000  1030.000000      1030.0
# mean     -0.000303    -0.000007     0.000497     0.000132         0.0
# std       0.030361     0.030334     0.016482     0.028248         0.0
# min      -0.406578    -0.179384    -0.048169    -0.102527         0.0
# 25%      -0.009806    -0.011162    -0.010167    -0.017858         0.0
# 50%      -0.000200    -0.002399     0.000553    -0.000995         0.0
# 75%       0.008177     0.008085     0.011469     0.018500         0.0
# max       0.295931     0.443832     0.051439     0.173980         0.0
#
#         sex_for_qc         age         CASE       zSCORE
# count  1030.000000  881.000000  1030.000000  1030.000000
# mean      1.589320   65.837020     0.242718     0.080668
# std       0.492196   10.474319     0.428935     1.033220
# min       1.000000   18.000000     0.000000    -3.216374
# 25%       1.000000   60.000000     0.000000    -0.608082
# 50%       2.000000   66.000000     0.000000     0.064221
# 75%       2.000000   72.000000     0.000000     0.750823
# max       2.000000   95.000000     1.000000     3.793796
#
# [8 rows x 21 columns]
# Optimization terminated successfully.
#          Current function value: 0.412153
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                  881
# Model:                          Logit   Df Residuals:                      867
# Method:                           MLE   Df Model:                           13
# Date:                Mon, 04 Mar 2024   Pseudo R-squ.:                  0.1957
# Time:                        16:40:10   Log-Likelihood:                -363.11
# converged:                       True   LL-Null:                       -451.45
# Covariance Type:            nonrobust   LLR p-value:                 8.011e-31
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.3521      0.636     -2.127      0.033      -2.598      -0.106
# zSCORE         0.3176      0.094      3.363      0.001       0.132       0.503
# sex_for_qc    -0.7989      0.190     -4.215      0.000      -1.170      -0.427
# age            0.0244      0.009      2.766      0.006       0.007       0.042
# PC1           53.1456      6.747      7.876      0.000      39.921      66.370
# PC2            0.2423      3.873      0.063      0.950      -7.349       7.834
# PC3          -17.7579     13.844     -1.283      0.200     -44.892       9.377
# PC4            1.2306     10.381      0.119      0.906     -19.116      21.577
# PC5          -18.1888      5.392     -3.373      0.001     -28.757      -7.620
# PC6           19.3859      6.625      2.926      0.003       6.402      32.370
# PC7            4.8892      6.366      0.768      0.442      -7.588      17.366
# PC8           15.3896      5.994      2.568      0.010       3.642      27.137
# PC9           -4.8365      6.089     -0.794      0.427     -16.771       7.098
# PC10          -2.9519      3.533     -0.836      0.403      -9.876       3.973
# ==============================================================================
# Done analyzing AAC now on to the next thing.
# Ancestry: AFR
# /tmp/ipykernel_2940629/767849212.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat['CASE'] = dat['PHENO'] - 1
# /tmp/ipykernel_2940629/767849212.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat["zSCORE"] = (dat["SCORE"] - mean_controls) / sd_controls
# /tmp/ipykernel_2940629/767849212.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat['CASE'] = dat['PHENO'] - 1
# /tmp/ipykernel_2940629/767849212.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat["zSCORE"] = (dat["SCORE"] - mean_controls) / sd_controls
# Taking a look at the dataset for AFR regression models.
#         FID_x        PHENO          CNT        CNT2        SCORE   FID_y  \
# count  2569.0  2569.000000  2569.000000  2569.00000  2569.000000  2569.0
# mean      0.0     1.355002   162.507591    80.47100    -0.001763     0.0
# std       0.0     0.478607     2.821404     4.93265     0.002846     0.0
# min       0.0     1.000000   150.000000    64.00000    -0.012241     0.0
# 25%       0.0     1.000000   160.000000    77.00000    -0.003739     0.0
# 50%       0.0     1.000000   162.000000    81.00000    -0.001834     0.0
# 75%       0.0     2.000000   164.000000    84.00000     0.000125     0.0
# max       0.0     2.000000   166.000000    97.00000     0.008498     0.0
#
#                PC1          PC2          PC3          PC4  ...          PC6  \
# count  2569.000000  2569.000000  2569.000000  2569.000000  ...  2569.000000
# mean      0.000098     0.000521    -0.000131     0.000178  ...     0.000027
# std       0.019510     0.019190     0.019698     0.019666  ...     0.019703
# min      -0.086743    -0.062793    -0.267818    -0.193079  ...    -0.124184
# 25%       0.003080    -0.016056    -0.000504    -0.007958  ...    -0.004954
# 50%       0.005676     0.008915     0.004123    -0.003376  ...    -0.000029
# 75%       0.009268     0.016572     0.007552     0.002904  ...     0.004821
# max       0.016398     0.025739     0.018598     0.093391  ...     0.453329
#
#                PC7          PC8          PC9         PC10  New_Column  \
# count  2569.000000  2569.000000  2569.000000  2569.000000      2569.0
# mean      0.000009     0.000026    -0.000024     0.000049         0.0
# std       0.019707     0.019657     0.019687     0.019693         0.0
# min      -0.500779    -0.053069    -0.137205    -0.265407         0.0
# 25%      -0.006332    -0.006676    -0.006264    -0.008784         0.0
# 50%       0.000440    -0.000819    -0.000399    -0.000132         0.0
# 75%       0.006973     0.004987     0.005580     0.008405         0.0
# max       0.063078     0.525289     0.529396     0.166573         0.0
#
#         sex_for_qc          age         CASE       zSCORE
# count  2569.000000  1040.000000  2569.000000  2569.000000
# mean      1.436357    63.424856     0.355002     0.051917
# std       0.496030    14.980335     0.478607     0.993788
# min       1.000000    18.000000     0.000000    -3.606513
# 25%       1.000000    58.000000     0.000000    -0.637836
# 50%       1.000000    66.000000     0.000000     0.027301
# 75%       2.000000    73.000000     1.000000     0.711380
# max       2.000000    92.000000     1.000000     3.634906
#
# [8 rows x 21 columns]
# Optimization terminated successfully.
#          Current function value: 0.397443
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                 1040
# Model:                          Logit   Df Residuals:                     1026
# Method:                           MLE   Df Model:                           13
# Date:                Mon, 04 Mar 2024   Pseudo R-squ.:                 0.09800
# Time:                        16:40:10   Log-Likelihood:                -413.34
# converged:                       True   LL-Null:                       -458.25
# Covariance Type:            nonrobust   LLR p-value:                 1.514e-13
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.1306      0.506     -4.214      0.000      -3.122      -1.140
# zSCORE         0.2275      0.087      2.621      0.009       0.057       0.398
# sex_for_qc    -0.3627      0.179     -2.021      0.043      -0.714      -0.011
# age            0.0077      0.006      1.404      0.160      -0.003       0.019
# PC1          -24.3878      4.827     -5.052      0.000     -33.849     -14.927
# PC2            9.7834      9.562      1.023      0.306      -8.958      28.525
# PC3            7.5713     22.394      0.338      0.735     -36.319      51.462
# PC4          -27.5135     16.691     -1.648      0.099     -60.227       5.200
# PC5            5.8900     16.191      0.364      0.716     -25.844      37.624
# PC6            7.7969     14.453      0.539      0.590     -20.531      36.125
# PC7           -6.4062     11.566     -0.554      0.580     -29.075      16.262
# PC8          -18.7814     10.133     -1.853      0.064     -38.642       1.079
# PC9           -9.3441     10.290     -0.908      0.364     -29.512      10.824
# PC10          16.9177     10.202      1.658      0.097      -3.077      36.912
# ==============================================================================
# Done analyzing AFR now on to the next thing.
# Ancestry: AJ
# Taking a look at the dataset for AJ regression models.
#         FID_x        PHENO          CNT         CNT2        SCORE   FID_y  \
# count  1460.0  1460.000000  1460.000000  1460.000000  1460.000000  1460.0
# mean      0.0     1.687671   164.541096    78.069178     0.000038     0.0
# std       0.0     0.463602     1.607158     5.481604     0.003994     0.0
# min       0.0     1.000000   156.000000    62.000000    -0.013144     0.0
# 25%       0.0     1.000000   164.000000    75.000000    -0.002579     0.0
# 50%       0.0     2.000000   164.000000    78.000000     0.000160     0.0
# 75%       0.0     2.000000   166.000000    82.000000     0.002593     0.0
# max       0.0     2.000000   166.000000    94.000000     0.013296     0.0
#
#                PC1          PC2          PC3          PC4  ...          PC6  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  ...  1460.000000
# mean      0.000386    -0.000949    -0.000961     0.000456  ...    -0.000814
# std       0.009207     0.008944     0.017801     0.013905  ...     0.013946
# min      -0.029825    -0.034457    -0.076438    -0.209755  ...    -0.050562
# 25%      -0.005959    -0.006781    -0.010562    -0.007867  ...    -0.010233
# 50%       0.000505    -0.001005     0.000103     0.000257  ...    -0.000954
# 75%       0.006889     0.004874     0.010536     0.009139  ...     0.008670
# max       0.030427     0.027236     0.048794     0.116349  ...     0.048372
#
#                PC7          PC8          PC9         PC10  New_Column  \
# count  1460.000000  1460.000000  1460.000000  1460.000000      1460.0
# mean     -0.000264    -0.000071     0.000385     0.000809         0.0
# std       0.014605     0.013290     0.015533     0.015747         0.0
# min      -0.047622    -0.120060    -0.306696    -0.086506         0.0
# 25%      -0.009486    -0.008790    -0.008289    -0.009515         0.0
# 50%      -0.000525    -0.000580     0.000651     0.000449         0.0
# 75%       0.008242     0.008571     0.009484     0.010086         0.0
# max       0.219105     0.057783     0.054630     0.063205         0.0
#
#         sex_for_qc          age         CASE       zSCORE
# count  1460.000000  1193.000000  1460.000000  1460.000000
# mean      1.313699    68.917248     0.687671     0.102538
# std       0.464154     9.835406     0.463602     1.043122
# min       1.000000    35.000000     0.000000    -3.340522
# 25%       1.000000    62.000000     0.000000    -0.580900
# 50%       1.000000    69.842574     1.000000     0.134639
# 75%       2.000000    76.000000     1.000000     0.769894
# max       2.000000    96.000000     1.000000     3.565605
#
# [8 rows x 21 columns]
# /tmp/ipykernel_2940629/767849212.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat['CASE'] = dat['PHENO'] - 1
# /tmp/ipykernel_2940629/767849212.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat["zSCORE"] = (dat["SCORE"] - mean_controls) / sd_controls
# /tmp/ipykernel_2940629/767849212.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat['CASE'] = dat['PHENO'] - 1
# /tmp/ipykernel_2940629/767849212.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat["zSCORE"] = (dat["SCORE"] - mean_controls) / sd_controls
# Optimization terminated successfully.
#          Current function value: 0.521712
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                 1193
# Model:                          Logit   Df Residuals:                     1179
# Method:                           MLE   Df Model:                           13
# Date:                Mon, 04 Mar 2024   Pseudo R-squ.:                 0.02633
# Time:                        16:40:10   Log-Likelihood:                -622.40
# converged:                       True   LL-Null:                       -639.23
# Covariance Type:            nonrobust   LLR p-value:                  0.001354
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.2555      0.539      2.328      0.020       0.199       2.312
# zSCORE         0.0328      0.068      0.483      0.629      -0.100       0.166
# sex_for_qc    -0.7119      0.143     -4.975      0.000      -0.992      -0.431
# age            0.0138      0.007      1.938      0.053      -0.000       0.028
# PC1           -8.3600      7.649     -1.093      0.274     -23.351       6.631
# PC2           -1.0571      7.928     -0.133      0.894     -16.596      14.482
# PC3            2.0486      4.420      0.464      0.643      -6.614      10.711
# PC4           -0.7969      5.509     -0.145      0.885     -11.595      10.001
# PC5           -0.9606      5.651     -0.170      0.865     -12.036      10.115
# PC6           -0.9862      5.148     -0.192      0.848     -11.077       9.104
# PC7            4.9079      5.251      0.935      0.350      -5.383      15.199
# PC8           -2.0974      5.363     -0.391      0.696     -12.608       8.414
# PC9           -0.9759      4.852     -0.201      0.841     -10.485       8.533
# PC10           7.8561      4.941      1.590      0.112      -1.828      17.541
# ==============================================================================
# Done analyzing AJ now on to the next thing.
# Ancestry: AMR
# Taking a look at the dataset for AMR regression models.
#        FID_x       PHENO         CNT        CNT2       SCORE  FID_y  \
# count  453.0  453.000000  453.000000  453.000000  453.000000  453.0
# mean     0.0    1.701987  166.445916   78.024283    0.000512    0.0
# std      0.0    0.457891    1.745997    5.194605    0.003880    0.0
# min      0.0    1.000000  158.000000   64.000000   -0.010442    0.0
# 25%      0.0    1.000000  166.000000   75.000000   -0.002049    0.0
# 50%      0.0    2.000000  166.000000   78.000000    0.000575    0.0
# 75%      0.0    2.000000  168.000000   82.000000    0.002851    0.0
# max      0.0    2.000000  168.000000   96.000000    0.013695    0.0
#
#               PC1         PC2         PC3         PC4  ...         PC6  \
# count  453.000000  453.000000  453.000000  453.000000  ...  453.000000
# mean    -0.017819   -0.008568    0.000970   -0.000533  ...    0.003584
# std      0.029649    0.034075    0.037581    0.038946  ...    0.023263
# min     -0.123816   -0.093844   -0.312350   -0.408986  ...   -0.073245
# 25%     -0.036678   -0.031159   -0.009846   -0.006238  ...   -0.009768
# 50%     -0.019175   -0.011139    0.001072    0.004173  ...    0.003848
# 75%      0.003184    0.012866    0.011358    0.013370  ...    0.018079
# max      0.048969    0.123855    0.371717    0.052928  ...    0.080846
#
#               PC7         PC8         PC9        PC10  New_Column  sex_for_qc  \
# count  453.000000  453.000000  453.000000  453.000000       453.0  453.000000
# mean     0.004827   -0.001417   -0.001931    0.001105         0.0    1.441501
# std      0.031831    0.023974    0.023192    0.025400         0.0    0.497115
# min     -0.092123   -0.204018   -0.141111   -0.057064         0.0    1.000000
# 25%     -0.014814   -0.012361   -0.013899   -0.014084         0.0    1.000000
# 50%      0.010154   -0.000880   -0.002580    0.001453         0.0    1.000000
# 75%      0.026593    0.012373    0.011910    0.013774         0.0    2.000000
# max      0.078738    0.055613    0.130723    0.247554         0.0    2.000000
#
#               age        CASE      zSCORE
# count  348.000000  453.000000  453.000000
# mean    61.091687    0.701987    0.185299
# std     11.407730    0.457891    1.046022
# min     26.000000    0.000000   -2.767627
# 25%     54.000000    0.000000   -0.505063
# 50%     61.000000    1.000000    0.202536
# 75%     69.000000    1.000000    0.815975
# max    101.000000    1.000000    3.739339
#
# [8 rows x 21 columns]
# Optimization terminated successfully.
#          Current function value: 0.511104
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                  348
# Model:                          Logit   Df Residuals:                      334
# Method:                           MLE   Df Model:                           13
# Date:                Mon, 04 Mar 2024   Pseudo R-squ.:                 0.08064
# Time:                        16:40:10   Log-Likelihood:                -177.86
# converged:                       True   LL-Null:                       -193.46
# Covariance Type:            nonrobust   LLR p-value:                  0.003151
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.1306      0.910      3.439      0.001       1.346       4.915
# zSCORE         0.4210      0.137      3.073      0.002       0.152       0.689
# sex_for_qc    -0.1971      0.271     -0.728      0.466      -0.727       0.333
# age           -0.0250      0.012     -2.084      0.037      -0.049      -0.001
# PC1            2.1955      6.585      0.333      0.739     -10.711      15.102
# PC2           -0.0763      5.663     -0.013      0.989     -11.176      11.023
# PC3           -9.3526      6.714     -1.393      0.164     -22.512       3.807
# PC4           -9.3070      6.681     -1.393      0.164     -22.401       3.788
# PC5          -24.8988      7.908     -3.149      0.002     -40.397      -9.400
# PC6           -9.9333      6.507     -1.526      0.127     -22.688       2.821
# PC7           -4.6869      4.599     -1.019      0.308     -13.701       4.328
# PC8          -16.3013      6.149     -2.651      0.008     -28.354      -4.249
# PC9           -4.7928      6.373     -0.752      0.452     -17.284       7.698
# PC10          -9.6333      5.787     -1.665      0.096     -20.976       1.709
# ==============================================================================
# Done analyzing AMR now on to the next thing.
# Ancestry: EAS
# Taking a look at the dataset for EAS regression models.
#         FID_x        PHENO          CNT         CNT2        SCORE   FID_y  \
# count  3328.0  3328.000000  3328.000000  3328.000000  3328.000000  3328.0
# mean      0.0     1.299279   148.557692    70.046274     0.002527     0.0
# std       0.0     0.458011     4.234376     5.258479     0.003497     0.0
# min       0.0     1.000000   130.000000    50.000000    -0.010073     0.0
# 25%       0.0     1.000000   146.000000    67.000000     0.000163     0.0
# 50%       0.0     1.000000   148.000000    70.000000     0.002469     0.0
# 75%       0.0     2.000000   152.000000    74.000000     0.004865     0.0
# max       0.0     2.000000   160.000000    90.000000     0.014626     0.0
#
#                PC1          PC2          PC3          PC4  ...          PC6  \
# count  3328.000000  3328.000000  3328.000000  3328.000000  ...  3328.000000
# mean      0.001644    -0.000132    -0.004306    -0.000278  ...    -0.000873
# std       0.013886     0.015333     0.014706     0.012836  ...     0.005497
# min      -0.023276    -0.018313    -0.031935    -0.146574  ...    -0.046697
# 25%      -0.008635    -0.011417    -0.018440    -0.003950  ...    -0.003913
# 50%       0.003604    -0.008585    -0.003301     0.000622  ...    -0.000782
# 75%       0.006037     0.013056     0.009446     0.004360  ...     0.002474
# max       0.031778     0.043429     0.027029     0.050745  ...     0.022488
#
#                PC7          PC8          PC9         PC10  New_Column  \
# count  3328.000000  3328.000000  3328.000000  3328.000000      3328.0
# mean      0.001659    -0.000495     0.000165    -0.000027         0.0
# std       0.012751     0.014075     0.015525     0.008219         0.0
# min      -0.068679    -0.064052    -0.086185    -0.064993         0.0
# 25%      -0.003833    -0.006279    -0.005761    -0.004744         0.0
# 50%       0.002041    -0.000369    -0.000500     0.000145         0.0
# 75%       0.008951     0.005326     0.004697     0.004964         0.0
# max       0.058891     0.280381     0.382536     0.033372         0.0
#
#         sex_for_qc          age         CASE       zSCORE
# count  3328.000000  2137.000000  3328.000000  3328.000000
# mean      1.305589    64.181170     0.299279     0.060799
# std       0.460726    10.731823     0.458011     1.005450
# min       1.000000    20.000000     0.000000    -3.562210
# 25%       1.000000    58.000000     0.000000    -0.618998
# 50%       1.000000    65.000000     0.000000     0.044179
# 75%       2.000000    71.000000     1.000000     0.733015
# max       2.000000    98.000000     1.000000     3.539751
#
# [8 rows x 21 columns]
# Optimization terminated successfully.
#          Current function value: 0.529950
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                 2137
# Model:                          Logit   Df Residuals:                     2123
# Method:                           MLE   Df Model:                           13
# Date:                Mon, 04 Mar 2024   Pseudo R-squ.:                  0.2275
# Time:                        16:40:11   Log-Likelihood:                -1132.5
# converged:                       True   LL-Null:                       -1466.0
# Covariance Type:            nonrobust   LLR p-value:                3.864e-134
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.7586      0.364     -2.082      0.037      -1.473      -0.044
# zSCORE         0.1069      0.053      2.029      0.042       0.004       0.210
# sex_for_qc    -0.5306      0.105     -5.077      0.000      -0.735      -0.326
# age            0.0207      0.005      4.183      0.000       0.011       0.030
# PC1          -53.9930      4.073    -13.255      0.000     -61.977     -46.009
# PC2          -44.9390      4.507     -9.971      0.000     -53.772     -36.106
# PC3           19.8298      6.693      2.963      0.003       6.712      32.948
# PC4            7.0209      5.156      1.362      0.173      -3.085      17.127
# PC5            7.3650     12.876      0.572      0.567     -17.871      32.601
# PC6           10.6546     12.198      0.873      0.382     -13.253      34.562
# PC7            8.6551      4.802      1.802      0.071      -0.757      18.067
# PC8           -7.2083      7.001     -1.030      0.303     -20.930       6.514
# PC9            0.1085      7.915      0.014      0.989     -15.404      15.621
# PC10           0.4824      6.879      0.070      0.944     -13.000      13.965
# ==============================================================================
# Done analyzing EAS now on to the next thing.
# Ancestry: EUR
# /tmp/ipykernel_2940629/767849212.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat['CASE'] = dat['PHENO'] - 1
# /tmp/ipykernel_2940629/767849212.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat["zSCORE"] = (dat["SCORE"] - mean_controls) / sd_controls
# /tmp/ipykernel_2940629/767849212.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat['CASE'] = dat['PHENO'] - 1
# /tmp/ipykernel_2940629/767849212.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat["zSCORE"] = (dat["SCORE"] - mean_controls) / sd_controls
# /tmp/ipykernel_2940629/767849212.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat['CASE'] = dat['PHENO'] - 1
# /tmp/ipykernel_2940629/767849212.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat["zSCORE"] = (dat["SCORE"] - mean_controls) / sd_controls
# Taking a look at the dataset for EUR regression models.
#          FID_x         PHENO           CNT          CNT2         SCORE  \
# count  19311.0  19311.000000  19311.000000  19311.000000  19311.000000
# mean       0.0      1.607426    159.724509     73.720470      0.002226
# std        0.0      0.488336      3.363237      5.405883      0.003889
# min        0.0      1.000000    142.000000     53.000000     -0.013118
# 25%        0.0      1.000000    158.000000     70.000000     -0.000392
# 50%        0.0      2.000000    160.000000     74.000000      0.002204
# 75%        0.0      2.000000    162.000000     77.000000      0.004834
# max        0.0      2.000000    168.000000     96.000000      0.016607
#
#          FID_y           PC1           PC2           PC3           PC4  ...  \
# count  19311.0  19311.000000  19311.000000  19311.000000  19311.000000  ...
# mean       0.0      0.000058     -0.000155     -0.000047      0.000197  ...
# std        0.0      0.006639      0.006877      0.006820      0.005567  ...
# min        0.0     -0.036964     -0.050640     -0.025231     -0.200306  ...
# 25%        0.0     -0.000856     -0.000868     -0.003098     -0.001911  ...
# 50%        0.0      0.001944      0.001388      0.000140      0.000418  ...
# 75%        0.0      0.003734      0.003124      0.002966      0.002741  ...
# max        0.0      0.009587      0.021952      0.053952      0.018009  ...
#
#                 PC6           PC7           PC8           PC9          PC10  \
# count  19311.000000  19311.000000  19311.000000  19311.000000  19311.000000
# mean       0.000068      0.000004      0.000032     -0.000111     -0.000009
# std        0.005512      0.006644      0.005639      0.005700      0.005611
# min       -0.274217     -0.060811     -0.283507     -0.200710     -0.104564
# 25%       -0.002416     -0.003489     -0.002779     -0.002947     -0.003126
# 50%        0.000124     -0.000076      0.000066     -0.000137      0.000163
# 75%        0.002676      0.003263      0.002842      0.002697      0.003365
# max        0.064354      0.178202      0.089575      0.124141      0.141332
#
#        New_Column    sex_for_qc           age          CASE        zSCORE
# count     19311.0  19311.000000  13852.000000  19311.000000  19311.000000
# mean          0.0      1.388898     65.987271      0.607426      0.084288
# std           0.0      0.487513     10.838823      0.488336      1.015618
# min           0.0      1.000000      0.000000      0.000000     -3.922794
# 25%           0.0      1.000000     59.000000      0.000000     -0.599332
# 50%           0.0      1.000000     67.000000      1.000000      0.078730
# 75%           0.0      2.000000     74.000000      1.000000      0.765491
# max           0.0      2.000000    103.000000      1.000000      3.840178
#
# [8 rows x 21 columns]
# Optimization terminated successfully.
#          Current function value: 0.654134
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                13852
# Model:                          Logit   Df Residuals:                    13838
# Method:                           MLE   Df Model:                           13
# Date:                Mon, 04 Mar 2024   Pseudo R-squ.:                 0.02250
# Time:                        16:40:11   Log-Likelihood:                -9061.1
# converged:                       True   LL-Null:                       -9269.6
# Covariance Type:            nonrobust   LLR p-value:                 5.512e-81
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0508      0.122      0.417      0.676      -0.188       0.289
# zSCORE         0.1395      0.017      7.984      0.000       0.105       0.174
# sex_for_qc    -0.3743      0.036    -10.454      0.000      -0.445      -0.304
# age            0.0141      0.002      8.557      0.000       0.011       0.017
# PC1          -13.7169      2.857     -4.802      0.000     -19.316      -8.118
# PC2          -23.4051      4.022     -5.819      0.000     -31.289     -15.522
# PC3           -2.7194      3.409     -0.798      0.425      -9.402       3.963
# PC4           14.9554      3.497      4.277      0.000       8.102      21.809
# PC5            0.3968      3.295      0.120      0.904      -6.062       6.856
# PC6           12.6331      4.143      3.049      0.002       4.513      20.753
# PC7          -17.2813      3.137     -5.508      0.000     -23.430     -11.132
# PC8           -2.4567      3.732     -0.658      0.510      -9.771       4.857
# PC9           -0.7896      3.374     -0.234      0.815      -7.402       5.823
# PC10          10.2550      3.237      3.168      0.002       3.910      16.600
# ==============================================================================
# Done analyzing EUR now on to the next thing.
# Ancestry: CAS
# Taking a look at the dataset for CAS regression models.
#        FID_x       PHENO         CNT       CNT2       SCORE  FID_y  \
# count  489.0  489.000000  489.000000  489.00000  489.000000  489.0
# mean     0.0    1.445808  162.854806   76.90593   -0.000285    0.0
# std      0.0    0.497564    2.913610    5.50813    0.003812    0.0
# min      0.0    1.000000  152.000000   62.00000   -0.011295    0.0
# 25%      0.0    1.000000  162.000000   73.00000   -0.002843    0.0
# 50%      0.0    1.000000  162.000000   77.00000   -0.000251    0.0
# 75%      0.0    2.000000  166.000000   80.00000    0.002326    0.0
# max      0.0    2.000000  168.000000   93.00000    0.011229    0.0
#
#               PC1         PC2         PC3         PC4  ...         PC6  \
# count  489.000000  489.000000  489.000000  489.000000  ...  489.000000
# mean     0.011176    0.011638    0.002317    0.001303  ...   -0.004259
# std      0.034442    0.019901    0.042740    0.025456  ...    0.026702
# min     -0.067964   -0.051880   -0.073610   -0.079306  ...   -0.067326
# 25%      0.003960    0.000247   -0.013056   -0.002658  ...   -0.014022
# 50%      0.028927    0.004889   -0.000369    0.006057  ...   -0.003728
# 75%      0.035037    0.022562    0.005837    0.011985  ...    0.003586
# max      0.073469    0.105707    0.321708    0.249913  ...    0.216763
#
#               PC7         PC8         PC9        PC10  New_Column  sex_for_qc  \
# count  489.000000  489.000000  489.000000  489.000000       489.0  489.000000
# mean     0.000621    0.001625    0.000409    0.003386         0.0    1.519427
# std      0.013093    0.019291    0.019316    0.023438         0.0    0.500134
# min     -0.032206   -0.087851   -0.072243   -0.374722         0.0    1.000000
# 25%     -0.008713   -0.006776   -0.007355   -0.005007         0.0    1.000000
# 50%     -0.000364    0.002846    0.001411    0.004892         0.0    2.000000
# 75%      0.007837    0.010446    0.010422    0.013787         0.0    2.000000
# max      0.047724    0.177401    0.189628    0.073469         0.0    2.000000
#
#               age        CASE      zSCORE
# count  339.000000  489.000000  489.000000
# mean    57.984431    0.445808    0.063500
# std      8.338760    0.497564    0.986989
# min     30.449315    0.000000   -2.787330
# 25%     52.000000    0.000000   -0.598773
# 50%     57.445585    0.000000    0.072293
# 75%     62.535250    1.000000    0.739527
# max     84.000000    1.000000    3.044784
#
# [8 rows x 21 columns]
# Optimization terminated successfully.
#          Current function value: 0.549219
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                  339
# Model:                          Logit   Df Residuals:                      325
# Method:                           MLE   Df Model:                           13
# Date:                Mon, 04 Mar 2024   Pseudo R-squ.:                  0.1992
# Time:                        16:40:11   Log-Likelihood:                -186.19
# converged:                       True   LL-Null:                       -232.49
# Covariance Type:            nonrobust   LLR p-value:                 4.413e-14
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -5.4296      1.193     -4.551      0.000      -7.768      -3.091
# zSCORE         0.1820      0.140      1.298      0.194      -0.093       0.457
# sex_for_qc    -0.7451      0.262     -2.843      0.004      -1.259      -0.231
# age            0.1210      0.018      6.649      0.000       0.085       0.157
# PC1          -21.1032     16.152     -1.307      0.191     -52.760      10.554
# PC2            8.1200     23.437      0.346      0.729     -37.817      54.057
# PC3           16.8266     24.843      0.677      0.498     -31.866      65.519
# PC4          -19.9120     16.614     -1.199      0.231     -52.474      12.650
# PC5           13.9867     20.033      0.698      0.485     -25.277      53.251
# PC6            7.3634     16.333      0.451      0.652     -24.649      39.376
# PC7           19.9114     11.790      1.689      0.091      -3.196      43.019
# PC8           19.0947     11.385      1.677      0.094      -3.220      41.409
# PC9           -6.8379      9.976     -0.685      0.493     -26.390      12.714
# PC10          -5.4077      6.637     -0.815      0.415     -18.416       7.601
# ==============================================================================
# Done analyzing CAS now on to the next thing.

# %%
import pandas as pd
import statsmodels.api as sm

## RUN PRS versus RISK across ancestries (EUROPEAN summ stats)
# List of ancestries
ancestries = ["AAC", "AFR", "AJ", "AMR", "EAS", "EUR", "CAS"]

for ancestry in ancestries:  
    print("Ancestry:", ancestry)
    # Construct file paths
    prs_file = f"{WORK_DIR}/imputed_data/" + ancestry + "/PRS_score_release_EUROPEAN.profile"
    covs_file = f"{WORK_DIR}/quality_control/release6/genotype_qc/GP2_release6_NOVEMBER_" + ancestry + "_maf_hwe_pca.eigenvec"

    # Read PRS data
    temp_data = pd.read_csv(prs_file, delim_whitespace =True)

    # Read covariates data
    # Specify your custom column names
    custom_column_names = ["FID", "IID", "PC1", "PC2", "PC3", "PC4", "PC5", "PC6", "PC7", "PC8", "PC9", "PC10"]

    # Read the tab-delimited file, skip the first line, and use custom column names
    temp_covs = pd.read_csv(covs_file, delim_whitespace =True, skiprows=1, names=custom_column_names)

    # Read additional covariates
    temp_covs_2 = pd.read_csv(f"{WORK_DIR}/covariates.txt", sep="\t")
    temp_covs_2.head()
    temp_covs_2 = temp_covs_2.rename(columns={"GP2sampleID": "IID"})

    # Merge covariates
    covs = pd.merge(temp_covs, temp_covs_2, on="IID")

    # Merge PRS data and covariates
    data = pd.merge(temp_data, covs, on="IID")

    # print("looking a covs")
    # print(covs.head())
    # print("looking at temp_data")
    # print(temp_data.head())
    # print("looking at data")
    # print(data.head())
    # print(data.describe())

    # Remove missing or unknown cases
    dat = data[data["PHENO"] != -9]

    # Logistic regression model phenotype
    dat['CASE'] = dat['PHENO'] - 1 

    # Standardize PRS
    mean_controls = dat.loc[dat["CASE"] == 0, "SCORE"].mean()
    sd_controls = dat.loc[dat["CASE"] == 0, "SCORE"].std()
    dat["zSCORE"] = (dat["SCORE"] - mean_controls) / sd_controls

    # Quick peak at the data
    print("Taking a look at the dataset for " + ancestry + " regression models.")
    print(dat.describe())

    # Logistic regression model using statsmodels formula
    formula = "CASE ~ zSCORE + sex_for_qc + age + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC7 + PC8 + PC9 + PC10"
    model = sm.Logit.from_formula(formula, data=dat)
    result = model.fit()

    # Print the summary
    print(result.summary())

    # Print
    print("Done analyzing " + ancestry + " now on to the next thing.")
# Out:
# Ancestry: AAC
# Taking a look at the dataset for AAC regression models.
#         FID_x        PHENO          CNT         CNT2        SCORE   FID_y  \
# count  1030.0  1030.000000  1030.000000  1030.000000  1030.000000  1030.0
# mean      0.0     1.242718   178.114563    72.143689    -0.016308     0.0
# std       0.0     0.428935     1.984998     5.317219     0.002766     0.0
# min       0.0     1.000000   168.000000    54.000000    -0.025477     0.0
# 25%       0.0     1.000000   178.000000    69.000000    -0.018209     0.0
# 50%       0.0     1.000000   178.000000    72.000000    -0.016281     0.0
# 75%       0.0     1.000000   180.000000    76.000000    -0.014559     0.0
# max       0.0     2.000000   180.000000    90.000000    -0.007043     0.0
#
#                PC1          PC2          PC3          PC4  ...          PC6  \
# count  1030.000000  1030.000000  1030.000000  1030.000000  ...  1030.000000
# mean     -0.009980     0.003704     0.000382     0.000388  ...    -0.000329
# std       0.017125     0.022483     0.030607     0.010635  ...     0.030206
# min      -0.033599    -0.045752    -0.458968    -0.047664  ...    -0.436147
# 25%      -0.020904    -0.009009    -0.000814    -0.006343  ...    -0.009340
# 50%      -0.014576     0.003609     0.004129     0.000099  ...    -0.000538
# 75%      -0.004136     0.013117     0.008565     0.006900  ...     0.009240
# max       0.074809     0.124427     0.026472     0.050560  ...     0.196375
#
#                PC7          PC8          PC9         PC10  New_Column  \
# count  1030.000000  1030.000000  1030.000000  1030.000000      1030.0
# mean     -0.000303    -0.000007     0.000497     0.000132         0.0
# std       0.030361     0.030334     0.016482     0.028248         0.0
# min      -0.406578    -0.179384    -0.048169    -0.102527         0.0
# 25%      -0.009806    -0.011162    -0.010167    -0.017858         0.0
# 50%      -0.000200    -0.002399     0.000553    -0.000995         0.0
# 75%       0.008177     0.008085     0.011469     0.018500         0.0
# max       0.295931     0.443832     0.051439     0.173980         0.0
#
#         sex_for_qc         age         CASE       zSCORE
# count  1030.000000  881.000000  1030.000000  1030.000000
# mean      1.589320   65.837020     0.242718     0.115338
# std       0.492196   10.474319     0.428935     1.033434
# min       1.000000   18.000000     0.000000    -3.311111
# 25%       1.000000   60.000000     0.000000    -0.595026
# 50%       2.000000   66.000000     0.000000     0.125132
# 75%       2.000000   72.000000     0.000000     0.768744
# max       2.000000   95.000000     1.000000     3.577298
#
# [8 rows x 21 columns]
# Optimization terminated successfully.
#          Current function value: 0.405912
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                  881
# Model:                          Logit   Df Residuals:                      867
# Method:                           MLE   Df Model:                           13
# Date:                Mon, 04 Mar 2024   Pseudo R-squ.:                  0.2079
# Time:                        16:40:11   Log-Likelihood:                -357.61
# converged:                       True   LL-Null:                       -451.45
# Covariance Type:            nonrobust   LLR p-value:                 4.555e-33
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.2804      0.638     -2.005      0.045      -2.532      -0.029
# zSCORE         0.4485      0.097      4.627      0.000       0.258       0.638
# sex_for_qc    -0.7645      0.190     -4.013      0.000      -1.138      -0.391
# age            0.0216      0.009      2.436      0.015       0.004       0.039
# PC1           51.9454      6.855      7.577      0.000      38.509      65.382
# PC2            1.3464      3.951      0.341      0.733      -6.398       9.091
# PC3          -18.6889     13.838     -1.351      0.177     -45.811       8.433
# PC4            2.2806     10.538      0.216      0.829     -18.373      22.934
# PC5          -17.7632      5.520     -3.218      0.001     -28.582      -6.944
# PC6           18.0538      6.419      2.813      0.005       5.473      30.635
# PC7            5.1547      6.481      0.795      0.426      -7.547      17.857
# PC8           15.4960      6.051      2.561      0.010       3.636      27.356
# PC9           -4.2655      6.041     -0.706      0.480     -16.105       7.574
# PC10          -2.4187      3.510     -0.689      0.491      -9.297       4.460
# ==============================================================================
# Done analyzing AAC now on to the next thing.
# Ancestry: AFR
# /tmp/ipykernel_2940629/457888.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat['CASE'] = dat['PHENO'] - 1
# /tmp/ipykernel_2940629/457888.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat["zSCORE"] = (dat["SCORE"] - mean_controls) / sd_controls
# /tmp/ipykernel_2940629/457888.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat['CASE'] = dat['PHENO'] - 1
# /tmp/ipykernel_2940629/457888.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat["zSCORE"] = (dat["SCORE"] - mean_controls) / sd_controls
# Taking a look at the dataset for AFR regression models.
#         FID_x        PHENO          CNT         CNT2        SCORE   FID_y  \
# count  2569.0  2569.000000  2569.000000  2569.000000  2569.000000  2569.0
# mean      0.0     1.355002   172.455430    68.635267    -0.018585     0.0
# std       0.0     0.478607     2.857407     4.912285     0.002530     0.0
# min       0.0     1.000000   160.000000    49.000000    -0.026690     0.0
# 25%       0.0     1.000000   170.000000    65.000000    -0.020366     0.0
# 50%       0.0     1.000000   172.000000    69.000000    -0.018567     0.0
# 75%       0.0     2.000000   174.000000    72.000000    -0.016979     0.0
# max       0.0     2.000000   176.000000    85.000000    -0.008618     0.0
#
#                PC1          PC2          PC3          PC4  ...          PC6  \
# count  2569.000000  2569.000000  2569.000000  2569.000000  ...  2569.000000
# mean      0.000098     0.000521    -0.000131     0.000178  ...     0.000027
# std       0.019510     0.019190     0.019698     0.019666  ...     0.019703
# min      -0.086743    -0.062793    -0.267818    -0.193079  ...    -0.124184
# 25%       0.003080    -0.016056    -0.000504    -0.007958  ...    -0.004954
# 50%       0.005676     0.008915     0.004123    -0.003376  ...    -0.000029
# 75%       0.009268     0.016572     0.007552     0.002904  ...     0.004821
# max       0.016398     0.025739     0.018598     0.093391  ...     0.453329
#
#                PC7          PC8          PC9         PC10  New_Column  \
# count  2569.000000  2569.000000  2569.000000  2569.000000      2569.0
# mean      0.000009     0.000026    -0.000024     0.000049         0.0
# std       0.019707     0.019657     0.019687     0.019693         0.0
# min      -0.500779    -0.053069    -0.137205    -0.265407         0.0
# 25%      -0.006332    -0.006676    -0.006264    -0.008784         0.0
# 50%       0.000440    -0.000819    -0.000399    -0.000132         0.0
# 75%       0.006973     0.004987     0.005580     0.008405         0.0
# max       0.063078     0.525289     0.529396     0.166573         0.0
#
#         sex_for_qc          age         CASE       zSCORE
# count  2569.000000  1040.000000  2569.000000  2569.000000
# mean      1.436357    63.424856     0.355002     0.048553
# std       0.496030    14.980335     0.478607     0.983655
# min       1.000000    18.000000     0.000000    -3.102744
# 25%       1.000000    58.000000     0.000000    -0.643937
# 50%       1.000000    66.000000     0.000000     0.055441
# 75%       2.000000    73.000000     1.000000     0.672670
# max       2.000000    92.000000     1.000000     3.923404
#
# [8 rows x 21 columns]
# Optimization terminated successfully.
#          Current function value: 0.395720
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                 1040
# Model:                          Logit   Df Residuals:                     1026
# Method:                           MLE   Df Model:                           13
# Date:                Mon, 04 Mar 2024   Pseudo R-squ.:                  0.1019
# Time:                        16:40:11   Log-Likelihood:                -411.55
# converged:                       True   LL-Null:                       -458.25
# Covariance Type:            nonrobust   LLR p-value:                 3.112e-14
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.0333      0.505     -4.024      0.000      -3.024      -1.043
# zSCORE         0.2911      0.090      3.226      0.001       0.114       0.468
# sex_for_qc    -0.3475      0.180     -1.931      0.053      -0.700       0.005
# age            0.0061      0.006      1.106      0.269      -0.005       0.017
# PC1          -23.6100      4.808     -4.911      0.000     -33.033     -14.187
# PC2           11.8306      9.678      1.222      0.222      -7.137      30.798
# PC3            8.6496     22.551      0.384      0.701     -35.549      52.848
# PC4          -29.1310     16.738     -1.740      0.082     -61.937       3.675
# PC5            5.7013     16.199      0.352      0.725     -26.048      37.450
# PC6            8.5326     14.446      0.591      0.555     -19.781      36.846
# PC7           -8.1036     11.594     -0.699      0.485     -30.828      14.620
# PC8          -18.9640     10.220     -1.856      0.064     -38.995       1.067
# PC9           -8.7622     10.316     -0.849      0.396     -28.981      11.457
# PC10          18.3888     10.256      1.793      0.073      -1.712      38.489
# ==============================================================================
# Done analyzing AFR now on to the next thing.
# Ancestry: AJ
# Taking a look at the dataset for AJ regression models.
#         FID_x        PHENO          CNT         CNT2        SCORE   FID_y  \
# count  1460.0  1460.000000  1460.000000  1460.000000  1460.000000  1460.0
# mean      0.0     1.687671   174.526027    79.072603    -0.009291     0.0
# std       0.0     0.463602     1.614705     5.718332     0.005500     0.0
# min       0.0     1.000000   166.000000    62.000000    -0.020508     0.0
# 25%       0.0     1.000000   174.000000    75.000000    -0.012832     0.0
# 50%       0.0     2.000000   174.000000    79.000000    -0.010219     0.0
# 75%       0.0     2.000000   176.000000    83.000000    -0.007077     0.0
# max       0.0     2.000000   176.000000    96.000000     0.018070     0.0
#
#                PC1          PC2          PC3          PC4  ...          PC6  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  ...  1460.000000
# mean      0.000386    -0.000949    -0.000961     0.000456  ...    -0.000814
# std       0.009207     0.008944     0.017801     0.013905  ...     0.013946
# min      -0.029825    -0.034457    -0.076438    -0.209755  ...    -0.050562
# 25%      -0.005959    -0.006781    -0.010562    -0.007867  ...    -0.010233
# 50%       0.000505    -0.001005     0.000103     0.000257  ...    -0.000954
# 75%       0.006889     0.004874     0.010536     0.009139  ...     0.008670
# max       0.030427     0.027236     0.048794     0.116349  ...     0.048372
#
#                PC7          PC8          PC9         PC10  New_Column  \
# count  1460.000000  1460.000000  1460.000000  1460.000000      1460.0
# mean     -0.000264    -0.000071     0.000385     0.000809         0.0
# std       0.014605     0.013290     0.015533     0.015747         0.0
# min      -0.047622    -0.120060    -0.306696    -0.086506         0.0
# 25%      -0.009486    -0.008790    -0.008289    -0.009515         0.0
# 50%      -0.000525    -0.000580     0.000651     0.000449         0.0
# 75%       0.008242     0.008571     0.009484     0.010086         0.0
# max       0.219105     0.057783     0.054630     0.063205         0.0
#
#         sex_for_qc          age         CASE       zSCORE
# count  1460.000000  1193.000000  1460.000000  1460.000000
# mean      1.313699    68.917248     0.687671     0.598402
# std       0.464154     9.835406     0.463602     1.406786
# min       1.000000    35.000000     0.000000    -2.270941
# 25%       1.000000    62.000000     0.000000    -0.307438
# 50%       1.000000    69.842574     1.000000     0.361012
# 75%       2.000000    76.000000     1.000000     1.164779
# max       2.000000    96.000000     1.000000     7.597104
#
# [8 rows x 21 columns]
# /tmp/ipykernel_2940629/457888.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat['CASE'] = dat['PHENO'] - 1
# /tmp/ipykernel_2940629/457888.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat["zSCORE"] = (dat["SCORE"] - mean_controls) / sd_controls
# /tmp/ipykernel_2940629/457888.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat['CASE'] = dat['PHENO'] - 1
# /tmp/ipykernel_2940629/457888.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat["zSCORE"] = (dat["SCORE"] - mean_controls) / sd_controls
# Optimization terminated successfully.
#          Current function value: 0.474546
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                 1193
# Model:                          Logit   Df Residuals:                     1179
# Method:                           MLE   Df Model:                           13
# Date:                Mon, 04 Mar 2024   Pseudo R-squ.:                  0.1144
# Time:                        16:40:12   Log-Likelihood:                -566.13
# converged:                       True   LL-Null:                       -639.23
# Covariance Type:            nonrobust   LLR p-value:                 1.199e-24
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5893      0.573      1.029      0.304      -0.534       1.712
# zSCORE         0.6703      0.074      9.064      0.000       0.525       0.815
# sex_for_qc    -0.7530      0.151     -4.982      0.000      -1.049      -0.457
# age            0.0208      0.008      2.748      0.006       0.006       0.036
# PC1           -8.6398      8.209     -1.052      0.293     -24.730       7.450
# PC2           -3.5205      8.356     -0.421      0.674     -19.898      12.857
# PC3            1.3553      4.689      0.289      0.773      -7.834      10.545
# PC4            0.5347      6.012      0.089      0.929     -11.249      12.318
# PC5           -2.1434      5.920     -0.362      0.717     -13.746       9.459
# PC6           -2.3491      5.404     -0.435      0.664     -12.941       8.243
# PC7            2.5741      5.641      0.456      0.648      -8.483      13.631
# PC8           -4.0244      5.630     -0.715      0.475     -15.058       7.009
# PC9           -0.9137      5.348     -0.171      0.864     -11.396       9.569
# PC10           7.7146      5.152      1.497      0.134      -2.384      17.813
# ==============================================================================
# Done analyzing AJ now on to the next thing.
# Ancestry: AMR
# Taking a look at the dataset for AMR regression models.
#        FID_x       PHENO         CNT        CNT2       SCORE  FID_y  \
# count  453.0  453.000000  453.000000  453.000000  453.000000  453.0
# mean     0.0    1.701987  178.375276   80.615894   -0.010135    0.0
# std      0.0    0.457891    1.787495    5.979531    0.003833    0.0
# min      0.0    1.000000  170.000000   63.000000   -0.021627    0.0
# 25%      0.0    1.000000  178.000000   77.000000   -0.012976    0.0
# 50%      0.0    2.000000  178.000000   81.000000   -0.010324    0.0
# 75%      0.0    2.000000  180.000000   85.000000   -0.007907    0.0
# max      0.0    2.000000  180.000000  101.000000    0.008308    0.0
#
#               PC1         PC2         PC3         PC4  ...         PC6  \
# count  453.000000  453.000000  453.000000  453.000000  ...  453.000000
# mean    -0.017819   -0.008568    0.000970   -0.000533  ...    0.003584
# std      0.029649    0.034075    0.037581    0.038946  ...    0.023263
# min     -0.123816   -0.093844   -0.312350   -0.408986  ...   -0.073245
# 25%     -0.036678   -0.031159   -0.009846   -0.006238  ...   -0.009768
# 50%     -0.019175   -0.011139    0.001072    0.004173  ...    0.003848
# 75%      0.003184    0.012866    0.011358    0.013370  ...    0.018079
# max      0.048969    0.123855    0.371717    0.052928  ...    0.080846
#
#               PC7         PC8         PC9        PC10  New_Column  sex_for_qc  \
# count  453.000000  453.000000  453.000000  453.000000       453.0  453.000000
# mean     0.004827   -0.001417   -0.001931    0.001105         0.0    1.441501
# std      0.031831    0.023974    0.023192    0.025400         0.0    0.497115
# min     -0.092123   -0.204018   -0.141111   -0.057064         0.0    1.000000
# 25%     -0.014814   -0.012361   -0.013899   -0.014084         0.0    1.000000
# 50%      0.010154   -0.000880   -0.002580    0.001453         0.0    1.000000
# 75%      0.026593    0.012373    0.011910    0.013774         0.0    2.000000
# max      0.078738    0.055613    0.130723    0.247554         0.0    2.000000
#
#               age        CASE      zSCORE
# count  348.000000  453.000000  453.000000
# mean    61.091687    0.701987    0.349299
# std     11.407730    0.457891    1.151446
# min     26.000000    0.000000   -3.102838
# 25%     54.000000    0.000000   -0.504114
# 50%     61.000000    1.000000    0.292483
# 75%     69.000000    1.000000    1.018792
# max    101.000000    1.000000    5.889770
#
# [8 rows x 21 columns]
# Optimization terminated successfully.
#          Current function value: 0.495966
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                  348
# Model:                          Logit   Df Residuals:                      334
# Method:                           MLE   Df Model:                           13
# Date:                Mon, 04 Mar 2024   Pseudo R-squ.:                  0.1079
# Time:                        16:40:12   Log-Likelihood:                -172.60
# converged:                       True   LL-Null:                       -193.46
# Covariance Type:            nonrobust   LLR p-value:                 7.231e-05
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.2348      0.937      3.453      0.001       1.399       5.071
# zSCORE         0.5687      0.134      4.234      0.000       0.305       0.832
# sex_for_qc    -0.3343      0.279     -1.200      0.230      -0.880       0.212
# age           -0.0233      0.012     -1.903      0.057      -0.047       0.001
# PC1            5.1333      6.686      0.768      0.443      -7.972      18.238
# PC2            2.5116      5.799      0.433      0.665      -8.854      13.877
# PC3           -5.6448      6.737     -0.838      0.402     -18.850       7.560
# PC4           -7.3255      6.719     -1.090      0.276     -20.494       5.843
# PC5          -21.9305      7.929     -2.766      0.006     -37.471      -6.390
# PC6           -9.7884      6.652     -1.471      0.141     -22.827       3.250
# PC7           -6.3802      4.659     -1.370      0.171     -15.511       2.750
# PC8           -9.0520      6.464     -1.400      0.161     -21.721       3.617
# PC9           -3.1683      6.771     -0.468      0.640     -16.438      10.102
# PC10         -13.4566      6.161     -2.184      0.029     -25.532      -1.381
# ==============================================================================
# Done analyzing AMR now on to the next thing.
# Ancestry: EAS
# /tmp/ipykernel_2940629/457888.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat['CASE'] = dat['PHENO'] - 1
# /tmp/ipykernel_2940629/457888.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat["zSCORE"] = (dat["SCORE"] - mean_controls) / sd_controls
# Taking a look at the dataset for EAS regression models.
#         FID_x        PHENO         CNT         CNT2        SCORE   FID_y  \
# count  3328.0  3328.000000  3328.00000  3328.000000  3328.000000  3328.0
# mean      0.0     1.299279   156.29387    64.910156     0.000075     0.0
# std       0.0     0.458011     4.30169     5.538730     0.002857     0.0
# min       0.0     1.000000   138.00000    44.000000    -0.009778     0.0
# 25%       0.0     1.000000   154.00000    61.000000    -0.001836     0.0
# 50%       0.0     1.000000   156.00000    65.000000     0.000054     0.0
# 75%       0.0     2.000000   160.00000    69.000000     0.002034     0.0
# max       0.0     2.000000   168.00000    82.000000     0.010797     0.0
#
#                PC1          PC2          PC3          PC4  ...          PC6  \
# count  3328.000000  3328.000000  3328.000000  3328.000000  ...  3328.000000
# mean      0.001644    -0.000132    -0.004306    -0.000278  ...    -0.000873
# std       0.013886     0.015333     0.014706     0.012836  ...     0.005497
# min      -0.023276    -0.018313    -0.031935    -0.146574  ...    -0.046697
# 25%      -0.008635    -0.011417    -0.018440    -0.003950  ...    -0.003913
# 50%       0.003604    -0.008585    -0.003301     0.000622  ...    -0.000782
# 75%       0.006037     0.013056     0.009446     0.004360  ...     0.002474
# max       0.031778     0.043429     0.027029     0.050745  ...     0.022488
#
#                PC7          PC8          PC9         PC10  New_Column  \
# count  3328.000000  3328.000000  3328.000000  3328.000000      3328.0
# mean      0.001659    -0.000495     0.000165    -0.000027         0.0
# std       0.012751     0.014075     0.015525     0.008219         0.0
# min      -0.068679    -0.064052    -0.086185    -0.064993         0.0
# 25%      -0.003833    -0.006279    -0.005761    -0.004744         0.0
# 50%       0.002041    -0.000369    -0.000500     0.000145         0.0
# 75%       0.008951     0.005326     0.004697     0.004964         0.0
# max       0.058891     0.280381     0.382536     0.033372         0.0
#
#         sex_for_qc          age         CASE       zSCORE
# count  3328.000000  2137.000000  3328.000000  3328.000000
# mean      1.305589    64.181170     0.299279     0.121514
# std       0.460726    10.731823     0.458011     1.004866
# min       1.000000    20.000000     0.000000    -3.343898
# 25%       1.000000    58.000000     0.000000    -0.550888
# 50%       1.000000    65.000000     0.000000     0.114155
# 75%       2.000000    71.000000     1.000000     0.810239
# max       2.000000    98.000000     1.000000     3.892455
#
# [8 rows x 21 columns]
# Optimization terminated successfully.
#          Current function value: 0.517399
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                 2137
# Model:                          Logit   Df Residuals:                     2123
# Method:                           MLE   Df Model:                           13
# Date:                Mon, 04 Mar 2024   Pseudo R-squ.:                  0.2458
# Time:                        16:40:12   Log-Likelihood:                -1105.7
# converged:                       True   LL-Null:                       -1466.0
# Covariance Type:            nonrobust   LLR p-value:                1.326e-145
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.9590      0.369     -2.599      0.009      -1.682      -0.236
# zSCORE         0.4053      0.055      7.419      0.000       0.298       0.512
# sex_for_qc    -0.5367      0.106     -5.061      0.000      -0.744      -0.329
# age            0.0229      0.005      4.563      0.000       0.013       0.033
# PC1          -53.3146      4.122    -12.934      0.000     -61.394     -45.235
# PC2          -43.0892      4.564     -9.442      0.000     -52.034     -34.144
# PC3           19.4478      6.788      2.865      0.004       6.143      32.753
# PC4            7.2364      5.191      1.394      0.163      -2.937      17.410
# PC5            6.4261     12.983      0.495      0.621     -19.020      31.872
# PC6           12.3816     12.396      0.999      0.318     -11.914      36.677
# PC7            9.9476      4.863      2.045      0.041       0.416      19.479
# PC8           -7.1367      7.108     -1.004      0.315     -21.067       6.794
# PC9            0.6440      7.990      0.081      0.936     -15.017      16.305
# PC10           0.1696      6.963      0.024      0.981     -13.478      13.817
# ==============================================================================
# Done analyzing EAS now on to the next thing.
# Ancestry: EUR
# /tmp/ipykernel_2940629/457888.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat['CASE'] = dat['PHENO'] - 1
# /tmp/ipykernel_2940629/457888.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat["zSCORE"] = (dat["SCORE"] - mean_controls) / sd_controls
# Taking a look at the dataset for EUR regression models.
#          FID_x         PHENO           CNT          CNT2         SCORE  \
# count  19311.0  19311.000000  19311.000000  19311.000000  19311.000000
# mean       0.0      1.607426    171.708353     77.871938     -0.009962
# std        0.0      0.488336      3.368953      5.675227      0.003123
# min        0.0      1.000000    154.000000     55.000000     -0.020786
# 25%        0.0      1.000000    170.000000     74.000000     -0.012031
# 50%        0.0      2.000000    172.000000     78.000000     -0.010059
# 75%        0.0      2.000000    174.000000     82.000000     -0.008004
# max        0.0      2.000000    180.000000    100.000000      0.014443
#
#          FID_y           PC1           PC2           PC3           PC4  ...  \
# count  19311.0  19311.000000  19311.000000  19311.000000  19311.000000  ...
# mean       0.0      0.000058     -0.000155     -0.000047      0.000197  ...
# std        0.0      0.006639      0.006877      0.006820      0.005567  ...
# min        0.0     -0.036964     -0.050640     -0.025231     -0.200306  ...
# 25%        0.0     -0.000856     -0.000868     -0.003098     -0.001911  ...
# 50%        0.0      0.001944      0.001388      0.000140      0.000418  ...
# 75%        0.0      0.003734      0.003124      0.002966      0.002741  ...
# max        0.0      0.009587      0.021952      0.053952      0.018009  ...
#
#                 PC6           PC7           PC8           PC9          PC10  \
# count  19311.000000  19311.000000  19311.000000  19311.000000  19311.000000
# mean       0.000068      0.000004      0.000032     -0.000111     -0.000009
# std        0.005512      0.006644      0.005639      0.005700      0.005611
# min       -0.274217     -0.060811     -0.283507     -0.200710     -0.104564
# 25%       -0.002416     -0.003489     -0.002779     -0.002947     -0.003126
# 50%        0.000124     -0.000076      0.000066     -0.000137      0.000163
# 75%        0.002676      0.003263      0.002842      0.002697      0.003365
# max        0.064354      0.178202      0.089575      0.124141      0.141332
#
#        New_Column    sex_for_qc           age          CASE        zSCORE
# count     19311.0  19311.000000  13852.000000  19311.000000  19311.000000
# mean          0.0      1.388898     65.987271      0.607426      0.300911
# std           0.0      0.487513     10.838823      0.488336      1.078772
# min           0.0      1.000000      0.000000      0.000000     -3.437846
# 25%           0.0      1.000000     59.000000      0.000000     -0.413712
# 50%           0.0      1.000000     67.000000      1.000000      0.267471
# 75%           0.0      2.000000     74.000000      1.000000      0.977279
# max           0.0      2.000000    103.000000      1.000000      8.730640
#
# [8 rows x 21 columns]
# Optimization terminated successfully.
#          Current function value: 0.630022
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                13852
# Model:                          Logit   Df Residuals:                    13838
# Method:                           MLE   Df Model:                           13
# Date:                Mon, 04 Mar 2024   Pseudo R-squ.:                 0.05853
# Time:                        16:40:12   Log-Likelihood:                -8727.1
# converged:                       True   LL-Null:                       -9269.6
# Covariance Type:            nonrobust   LLR p-value:                9.134e-224
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.1107      0.125     -0.884      0.377      -0.356       0.135
# zSCORE         0.4665      0.018     25.727      0.000       0.431       0.502
# sex_for_qc    -0.3866      0.037    -10.528      0.000      -0.459      -0.315
# age            0.0153      0.002      9.020      0.000       0.012       0.019
# PC1           -9.9784      2.917     -3.420      0.001     -15.696      -4.260
# PC2          -23.6611      4.122     -5.740      0.000     -31.741     -15.582
# PC3            0.1050      3.503      0.030      0.976      -6.760       6.970
# PC4           14.1725      3.526      4.020      0.000       7.263      21.082
# PC5            0.2570      3.449      0.075      0.941      -6.502       7.016
# PC6           11.9599      4.216      2.837      0.005       3.697      20.223
# PC7          -17.0354      3.255     -5.233      0.000     -23.416     -10.655
# PC8           -2.5390      3.821     -0.664      0.506     -10.028       4.950
# PC9            0.5859      3.426      0.171      0.864      -6.128       7.300
# PC10          10.9519      3.341      3.278      0.001       4.403      17.501
# ==============================================================================
# Done analyzing EUR now on to the next thing.
# Ancestry: CAS
# Taking a look at the dataset for CAS regression models.
#        FID_x       PHENO         CNT        CNT2       SCORE  FID_y  \
# count  489.0  489.000000  489.000000  489.000000  489.000000  489.0
# mean     0.0    1.445808  172.846626   76.229039   -0.009734    0.0
# std      0.0    0.497564    2.910375    6.208856    0.003219    0.0
# min      0.0    1.000000  162.000000   58.000000   -0.019206    0.0
# 25%      0.0    1.000000  170.000000   72.000000   -0.011983    0.0
# 50%      0.0    1.000000  172.000000   76.000000   -0.009740    0.0
# 75%      0.0    2.000000  176.000000   80.000000   -0.007490    0.0
# max      0.0    2.000000  178.000000   94.000000   -0.001641    0.0
#
#               PC1         PC2         PC3         PC4  ...         PC6  \
# count  489.000000  489.000000  489.000000  489.000000  ...  489.000000
# mean     0.011176    0.011638    0.002317    0.001303  ...   -0.004259
# std      0.034442    0.019901    0.042740    0.025456  ...    0.026702
# min     -0.067964   -0.051880   -0.073610   -0.079306  ...   -0.067326
# 25%      0.003960    0.000247   -0.013056   -0.002658  ...   -0.014022
# 50%      0.028927    0.004889   -0.000369    0.006057  ...   -0.003728
# 75%      0.035037    0.022562    0.005837    0.011985  ...    0.003586
# max      0.073469    0.105707    0.321708    0.249913  ...    0.216763
#
#               PC7         PC8         PC9        PC10  New_Column  sex_for_qc  \
# count  489.000000  489.000000  489.000000  489.000000       489.0  489.000000
# mean     0.000621    0.001625    0.000409    0.003386         0.0    1.519427
# std      0.013093    0.019291    0.019316    0.023438         0.0    0.500134
# min     -0.032206   -0.087851   -0.072243   -0.374722         0.0    1.000000
# 25%     -0.008713   -0.006776   -0.007355   -0.005007         0.0    1.000000
# 50%     -0.000364    0.002846    0.001411    0.004892         0.0    2.000000
# 75%      0.007837    0.010446    0.010422    0.013787         0.0    2.000000
# max      0.047724    0.177401    0.189628    0.073469         0.0    2.000000
#
#               age        CASE      zSCORE
# count  339.000000  489.000000  489.000000
# mean    57.984431    0.445808    0.121754
# std      8.338760    0.497564    1.007065
# min     30.449315    0.000000   -2.841344
# 25%     52.000000    0.000000   -0.581805
# 50%     57.445585    0.000000    0.119861
# 75%     62.535250    1.000000    0.823714
# max     84.000000    1.000000    2.653564
#
# [8 rows x 21 columns]
# Optimization terminated successfully.
#          Current function value: 0.526878
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                  339
# Model:                          Logit   Df Residuals:                      325
# Method:                           MLE   Df Model:                           13
# Date:                Mon, 04 Mar 2024   Pseudo R-squ.:                  0.2317
# Time:                        16:40:12   Log-Likelihood:                -178.61
# converged:                       True   LL-Null:                       -232.49
# Covariance Type:            nonrobust   LLR p-value:                 5.126e-17
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -5.5929      1.223     -4.571      0.000      -7.991      -3.195
# zSCORE         0.5454      0.139      3.935      0.000       0.274       0.817
# sex_for_qc    -0.7508      0.269     -2.794      0.005      -1.277      -0.224
# age            0.1224      0.019      6.528      0.000       0.086       0.159
# PC1          -19.6771     16.577     -1.187      0.235     -52.168      12.814
# PC2            8.9843     23.433      0.383      0.701     -36.944      54.913
# PC3           19.9296     25.453      0.783      0.434     -29.957      69.816
# PC4          -27.7774     17.169     -1.618      0.106     -61.428       5.873
# PC5           12.8456     20.672      0.621      0.534     -27.671      53.362
# PC6            5.7244     16.661      0.344      0.731     -26.931      38.380
# PC7           19.6604     12.052      1.631      0.103      -3.962      43.283
# PC8           19.6077     11.789      1.663      0.096      -3.499      42.714
# PC9           -8.9131     10.258     -0.869      0.385     -29.019      11.193
# PC10          -6.6339      7.056     -0.940      0.347     -20.463       7.195
# ==============================================================================
# Done analyzing CAS now on to the next thing.
# /tmp/ipykernel_2940629/457888.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat['CASE'] = dat['PHENO'] - 1
# /tmp/ipykernel_2940629/457888.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat["zSCORE"] = (dat["SCORE"] - mean_controls) / sd_controls

# %%
import pandas as pd
import statsmodels.api as sm

## RUN PRS versus RISK across ancestries (LATINO summ stats)
# List of ancestries
ancestries = ["AAC", "AFR", "AJ", "AMR", "EAS", "EUR", "CAS"]

for ancestry in ancestries:  
    print("Ancestry:", ancestry)
    # Construct file paths
    prs_file = f"{WORK_DIR}/imputed_data/" + ancestry + "/PRS_score_release_LATINO.profile"
    covs_file = f"{WORK_DIR}/quality_control/release6/genotype_qc/GP2_release6_NOVEMBER_" + ancestry + "_maf_hwe_pca.eigenvec"

    # Read PRS data
    temp_data = pd.read_csv(prs_file, delim_whitespace =True)

    # Read covariates data
    # Specify your custom column names
    custom_column_names = ["FID", "IID", "PC1", "PC2", "PC3", "PC4", "PC5", "PC6", "PC7", "PC8", "PC9", "PC10"]

    # Read the tab-delimited file, skip the first line, and use custom column names
    temp_covs = pd.read_csv(covs_file, delim_whitespace =True, skiprows=1, names=custom_column_names)

    # Read additional covariates
    temp_covs_2 = pd.read_csv(f"{WORK_DIR}/covariates.txt", sep="\t")
    temp_covs_2.head()
    temp_covs_2 = temp_covs_2.rename(columns={"GP2sampleID": "IID"})

    # Merge covariates
    covs = pd.merge(temp_covs, temp_covs_2, on="IID")

    # Merge PRS data and covariates
    data = pd.merge(temp_data, covs, on="IID")

    # print("looking a covs")
    # print(covs.head())
    # print("looking at temp_data")
    # print(temp_data.head())
    # print("looking at data")
    # print(data.head())
    # print(data.describe())

    # Remove missing or unknown cases
    dat = data[data["PHENO"] != -9]

    # Logistic regression model phenotype
    dat['CASE'] = dat['PHENO'] - 1 

    # Standardize PRS
    mean_controls = dat.loc[dat["CASE"] == 0, "SCORE"].mean()
    sd_controls = dat.loc[dat["CASE"] == 0, "SCORE"].std()
    dat["zSCORE"] = (dat["SCORE"] - mean_controls) / sd_controls

    # Quick peak at the data
    print("Taking a look at the dataset for " + ancestry + " regression models.")
    print(dat.describe())

    # Logistic regression model using statsmodels formula
    formula = "CASE ~ zSCORE + sex_for_qc + age + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC7 + PC8 + PC9 + PC10"
    model = sm.Logit.from_formula(formula, data=dat)
    result = model.fit()

    # Print the summary
    print(result.summary())

    # Print
    print("Done analyzing " + ancestry + " now on to the next thing.")
# Out:
# /tmp/ipykernel_2940629/1867000089.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat['CASE'] = dat['PHENO'] - 1
# /tmp/ipykernel_2940629/1867000089.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat["zSCORE"] = (dat["SCORE"] - mean_controls) / sd_controls
# Ancestry: AAC
# Taking a look at the dataset for AAC regression models.
#         FID_x        PHENO          CNT         CNT2        SCORE   FID_y  \
# count  1030.0  1030.000000  1030.000000  1030.000000  1030.000000  1030.0
# mean      0.0     1.242718   134.493204    54.601942    -0.001271     0.0
# std       0.0     0.428935     1.697609     4.717974     0.001997     0.0
# min       0.0     1.000000   128.000000    41.000000    -0.007731     0.0
# 25%       0.0     1.000000   134.000000    51.000000    -0.002624     0.0
# 50%       0.0     1.000000   134.000000    55.000000    -0.001272     0.0
# 75%       0.0     1.000000   136.000000    58.000000     0.000063     0.0
# max       0.0     2.000000   136.000000    70.000000     0.005501     0.0
#
#                PC1          PC2          PC3          PC4  ...          PC6  \
# count  1030.000000  1030.000000  1030.000000  1030.000000  ...  1030.000000
# mean     -0.009980     0.003704     0.000382     0.000388  ...    -0.000329
# std       0.017125     0.022483     0.030607     0.010635  ...     0.030206
# min      -0.033599    -0.045752    -0.458968    -0.047664  ...    -0.436147
# 25%      -0.020904    -0.009009    -0.000814    -0.006343  ...    -0.009340
# 50%      -0.014576     0.003609     0.004129     0.000099  ...    -0.000538
# 75%      -0.004136     0.013117     0.008565     0.006900  ...     0.009240
# max       0.074809     0.124427     0.026472     0.050560  ...     0.196375
#
#                PC7          PC8          PC9         PC10  New_Column  \
# count  1030.000000  1030.000000  1030.000000  1030.000000      1030.0
# mean     -0.000303    -0.000007     0.000497     0.000132         0.0
# std       0.030361     0.030334     0.016482     0.028248         0.0
# min      -0.406578    -0.179384    -0.048169    -0.102527         0.0
# 25%      -0.009806    -0.011162    -0.010167    -0.017858         0.0
# 50%      -0.000200    -0.002399     0.000553    -0.000995         0.0
# 75%       0.008177     0.008085     0.011469     0.018500         0.0
# max       0.295931     0.443832     0.051439     0.173980         0.0
#
#         sex_for_qc         age         CASE       zSCORE
# count  1030.000000  881.000000  1030.000000  1030.000000
# mean      1.589320   65.837020     0.242718     0.044686
# std       0.492196   10.474319     0.428935     0.998334
# min       1.000000   18.000000     0.000000    -3.184342
# 25%       1.000000   60.000000     0.000000    -0.631747
# 50%       2.000000   66.000000     0.000000     0.043924
# 75%       2.000000   72.000000     0.000000     0.711369
# max       2.000000   95.000000     1.000000     3.429345
#
# [8 rows x 21 columns]
# Optimization terminated successfully.
#          Current function value: 0.417260
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                  881
# Model:                          Logit   Df Residuals:                      867
# Method:                           MLE   Df Model:                           13
# Date:                Mon, 04 Mar 2024   Pseudo R-squ.:                  0.1857
# Time:                        16:40:12   Log-Likelihood:                -367.61
# converged:                       True   LL-Null:                       -451.45
# Covariance Type:            nonrobust   LLR p-value:                 5.424e-29
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.3481      0.632     -2.134      0.033      -2.586      -0.110
# zSCORE         0.1438      0.092      1.557      0.120      -0.037       0.325
# sex_for_qc    -0.7535      0.188     -4.013      0.000      -1.121      -0.385
# age            0.0243      0.009      2.786      0.005       0.007       0.041
# PC1           54.8330      6.682      8.206      0.000      41.737      67.929
# PC2           -1.9204      3.790     -0.507      0.612      -9.348       5.508
# PC3          -19.0349     13.740     -1.385      0.166     -45.965       7.895
# PC4            1.1931     10.398      0.115      0.909     -19.187      21.573
# PC5          -17.3150      5.370     -3.224      0.001     -27.841      -6.789
# PC6           19.1651      6.562      2.921      0.003       6.304      32.026
# PC7            4.8654      6.395      0.761      0.447      -7.668      17.399
# PC8           15.6307      6.054      2.582      0.010       3.764      27.497
# PC9           -6.3476      6.021     -1.054      0.292     -18.149       5.454
# PC10          -1.6248      3.491     -0.465      0.642      -8.467       5.217
# ==============================================================================
# Done analyzing AAC now on to the next thing.
# Ancestry: AFR
# /tmp/ipykernel_2940629/1867000089.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat['CASE'] = dat['PHENO'] - 1
# /tmp/ipykernel_2940629/1867000089.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat["zSCORE"] = (dat["SCORE"] - mean_controls) / sd_controls
# Taking a look at the dataset for AFR regression models.
#         FID_x        PHENO          CNT         CNT2        SCORE   FID_y  \
# count  2569.0  2569.000000  2569.000000  2569.000000  2569.000000  2569.0
# mean      0.0     1.355002   133.293889    51.275983    -0.001513     0.0
# std       0.0     0.478607     2.438265     4.405168     0.001801     0.0
# min       0.0     1.000000   122.000000    34.000000    -0.008699     0.0
# 25%       0.0     1.000000   132.000000    48.000000    -0.002697     0.0
# 50%       0.0     1.000000   134.000000    51.000000    -0.001533     0.0
# 75%       0.0     2.000000   136.000000    54.000000    -0.000319     0.0
# max       0.0     2.000000   136.000000    66.000000     0.005471     0.0
#
#                PC1          PC2          PC3          PC4  ...          PC6  \
# count  2569.000000  2569.000000  2569.000000  2569.000000  ...  2569.000000
# mean      0.000098     0.000521    -0.000131     0.000178  ...     0.000027
# std       0.019510     0.019190     0.019698     0.019666  ...     0.019703
# min      -0.086743    -0.062793    -0.267818    -0.193079  ...    -0.124184
# 25%       0.003080    -0.016056    -0.000504    -0.007958  ...    -0.004954
# 50%       0.005676     0.008915     0.004123    -0.003376  ...    -0.000029
# 75%       0.009268     0.016572     0.007552     0.002904  ...     0.004821
# max       0.016398     0.025739     0.018598     0.093391  ...     0.453329
#
#                PC7          PC8          PC9         PC10  New_Column  \
# count  2569.000000  2569.000000  2569.000000  2569.000000      2569.0
# mean      0.000009     0.000026    -0.000024     0.000049         0.0
# std       0.019707     0.019657     0.019687     0.019693         0.0
# min      -0.500779    -0.053069    -0.137205    -0.265407         0.0
# 25%      -0.006332    -0.006676    -0.006264    -0.008784         0.0
# 50%       0.000440    -0.000819    -0.000399    -0.000132         0.0
# 75%       0.006973     0.004987     0.005580     0.008405         0.0
# max       0.063078     0.525289     0.529396     0.166573         0.0
#
#         sex_for_qc          age         CASE       zSCORE
# count  2569.000000  1040.000000  2569.000000  2569.000000
# mean      1.436357    63.424856     0.355002     0.017981
# std       0.496030    14.980335     0.478607     0.984899
# min       1.000000    18.000000     0.000000    -3.911105
# 25%       1.000000    58.000000     0.000000    -0.629462
# 50%       1.000000    66.000000     0.000000     0.007050
# 75%       2.000000    73.000000     1.000000     0.670866
# max       2.000000    92.000000     1.000000     3.836796
#
# [8 rows x 21 columns]
# Optimization terminated successfully.
#          Current function value: 0.399633
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                 1040
# Model:                          Logit   Df Residuals:                     1026
# Method:                           MLE   Df Model:                           13
# Date:                Mon, 04 Mar 2024   Pseudo R-squ.:                 0.09303
# Time:                        16:40:13   Log-Likelihood:                -415.62
# converged:                       True   LL-Null:                       -458.25
# Covariance Type:            nonrobust   LLR p-value:                 1.116e-12
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.9630      0.500     -3.924      0.000      -2.943      -0.983
# zSCORE         0.1361      0.088      1.551      0.121      -0.036       0.308
# sex_for_qc    -0.3828      0.179     -2.137      0.033      -0.734      -0.032
# age            0.0061      0.005      1.120      0.263      -0.005       0.017
# PC1          -23.3357      4.788     -4.873      0.000     -32.721     -13.950
# PC2            8.1422      9.537      0.854      0.393     -10.551      26.835
# PC3            8.2524     22.333      0.370      0.712     -35.519      52.023
# PC4          -27.3477     16.501     -1.657      0.097     -59.690       4.994
# PC5            8.6989     16.112      0.540      0.589     -22.881      40.278
# PC6            9.5489     14.412      0.663      0.508     -18.698      37.796
# PC7           -7.5171     11.592     -0.648      0.517     -30.236      15.202
# PC8          -16.7926     10.164     -1.652      0.098     -36.714       3.128
# PC9           -8.2415     10.262     -0.803      0.422     -28.354      11.871
# PC10          18.8210     10.223      1.841      0.066      -1.217      38.859
# ==============================================================================
# Done analyzing AFR now on to the next thing.
# Ancestry: AJ
# /tmp/ipykernel_2940629/1867000089.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat['CASE'] = dat['PHENO'] - 1
# /tmp/ipykernel_2940629/1867000089.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat["zSCORE"] = (dat["SCORE"] - mean_controls) / sd_controls
# Taking a look at the dataset for AJ regression models.
#         FID_x        PHENO          CNT         CNT2        SCORE   FID_y  \
# count  1460.0  1460.000000  1460.000000  1460.000000  1460.000000  1460.0
# mean      0.0     1.687671   133.228767    62.817808    -0.000218     0.0
# std       0.0     0.463602     1.163646     4.989196     0.002242     0.0
# min       0.0     1.000000   124.000000    47.000000    -0.008780     0.0
# 25%       0.0     1.000000   132.000000    60.000000    -0.001754     0.0
# 50%       0.0     2.000000   134.000000    63.000000    -0.000137     0.0
# 75%       0.0     2.000000   134.000000    66.000000     0.001289     0.0
# max       0.0     2.000000   134.000000    79.000000     0.007633     0.0
#
#                PC1          PC2          PC3          PC4  ...          PC6  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  ...  1460.000000
# mean      0.000386    -0.000949    -0.000961     0.000456  ...    -0.000814
# std       0.009207     0.008944     0.017801     0.013905  ...     0.013946
# min      -0.029825    -0.034457    -0.076438    -0.209755  ...    -0.050562
# 25%      -0.005959    -0.006781    -0.010562    -0.007867  ...    -0.010233
# 50%       0.000505    -0.001005     0.000103     0.000257  ...    -0.000954
# 75%       0.006889     0.004874     0.010536     0.009139  ...     0.008670
# max       0.030427     0.027236     0.048794     0.116349  ...     0.048372
#
#                PC7          PC8          PC9         PC10  New_Column  \
# count  1460.000000  1460.000000  1460.000000  1460.000000      1460.0
# mean     -0.000264    -0.000071     0.000385     0.000809         0.0
# std       0.014605     0.013290     0.015533     0.015747         0.0
# min      -0.047622    -0.120060    -0.306696    -0.086506         0.0
# 25%      -0.009486    -0.008790    -0.008289    -0.009515         0.0
# 50%      -0.000525    -0.000580     0.000651     0.000449         0.0
# 75%       0.008242     0.008571     0.009484     0.010086         0.0
# max       0.219105     0.057783     0.054630     0.063205         0.0
#
#         sex_for_qc          age         CASE       zSCORE
# count  1460.000000  1193.000000  1460.000000  1460.000000
# mean      1.313699    68.917248     0.687671     0.147668
# std       0.464154     9.835406     0.463602     1.045471
# min       1.000000    35.000000     0.000000    -3.844549
# 25%       1.000000    62.000000     0.000000    -0.568657
# 50%       1.000000    69.842574     1.000000     0.185099
# 75%       2.000000    76.000000     1.000000     0.850162
# max       2.000000    96.000000     1.000000     3.807993
#
# [8 rows x 21 columns]
# /tmp/ipykernel_2940629/1867000089.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat['CASE'] = dat['PHENO'] - 1
# /tmp/ipykernel_2940629/1867000089.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat["zSCORE"] = (dat["SCORE"] - mean_controls) / sd_controls
# Optimization terminated successfully.
#          Current function value: 0.517796
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                 1193
# Model:                          Logit   Df Residuals:                     1179
# Method:                           MLE   Df Model:                           13
# Date:                Mon, 04 Mar 2024   Pseudo R-squ.:                 0.03364
# Time:                        16:40:13   Log-Likelihood:                -617.73
# converged:                       True   LL-Null:                       -639.23
# Covariance Type:            nonrobust   LLR p-value:                 4.481e-05
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.1560      0.543      2.130      0.033       0.092       2.220
# zSCORE         0.2110      0.069      3.079      0.002       0.077       0.345
# sex_for_qc    -0.6965      0.144     -4.845      0.000      -0.978      -0.415
# age            0.0148      0.007      2.060      0.039       0.001       0.029
# PC1           -8.9645      7.693     -1.165      0.244     -24.042       6.113
# PC2           -0.8656      7.963     -0.109      0.913     -16.473      14.741
# PC3            2.6249      4.433      0.592      0.554      -6.063      11.313
# PC4           -0.9352      5.487     -0.170      0.865     -11.689       9.819
# PC5           -1.5840      5.649     -0.280      0.779     -12.656       9.488
# PC6           -0.6124      5.159     -0.119      0.906     -10.725       9.500
# PC7            4.3288      5.225      0.829      0.407      -5.911      14.569
# PC8           -1.5222      5.368     -0.284      0.777     -12.043       8.998
# PC9           -1.2659      4.788     -0.264      0.791     -10.650       8.119
# PC10           8.2361      4.949      1.664      0.096      -1.463      17.935
# ==============================================================================
# Done analyzing AJ now on to the next thing.
# Ancestry: AMR
# Taking a look at the dataset for AMR regression models.
#        FID_x       PHENO         CNT       CNT2       SCORE  FID_y  \
# count  453.0  453.000000  453.000000  453.00000  453.000000  453.0
# mean     0.0    1.701987  134.927152   63.02649    0.000402    0.0
# std      0.0    0.457891    1.434866    5.06936    0.002212    0.0
# min      0.0    1.000000  128.000000   49.00000   -0.006490    0.0
# 25%      0.0    1.000000  134.000000   60.00000   -0.001027    0.0
# 50%      0.0    2.000000  136.000000   63.00000    0.000450    0.0
# 75%      0.0    2.000000  136.000000   66.00000    0.001961    0.0
# max      0.0    2.000000  136.000000   82.00000    0.006613    0.0
#
#               PC1         PC2         PC3         PC4  ...         PC6  \
# count  453.000000  453.000000  453.000000  453.000000  ...  453.000000
# mean    -0.017819   -0.008568    0.000970   -0.000533  ...    0.003584
# std      0.029649    0.034075    0.037581    0.038946  ...    0.023263
# min     -0.123816   -0.093844   -0.312350   -0.408986  ...   -0.073245
# 25%     -0.036678   -0.031159   -0.009846   -0.006238  ...   -0.009768
# 50%     -0.019175   -0.011139    0.001072    0.004173  ...    0.003848
# 75%      0.003184    0.012866    0.011358    0.013370  ...    0.018079
# max      0.048969    0.123855    0.371717    0.052928  ...    0.080846
#
#               PC7         PC8         PC9        PC10  New_Column  sex_for_qc  \
# count  453.000000  453.000000  453.000000  453.000000       453.0  453.000000
# mean     0.004827   -0.001417   -0.001931    0.001105         0.0    1.441501
# std      0.031831    0.023974    0.023192    0.025400         0.0    0.497115
# min     -0.092123   -0.204018   -0.141111   -0.057064         0.0    1.000000
# 25%     -0.014814   -0.012361   -0.013899   -0.014084         0.0    1.000000
# 50%      0.010154   -0.000880   -0.002580    0.001453         0.0    1.000000
# 75%      0.026593    0.012373    0.011910    0.013774         0.0    2.000000
# max      0.078738    0.055613    0.130723    0.247554         0.0    2.000000
#
#               age        CASE      zSCORE
# count  348.000000  453.000000  453.000000
# mean    61.091687    0.701987    0.171519
# std     11.407730    0.457891    1.078381
# min     26.000000    0.000000   -3.188674
# 25%     54.000000    0.000000   -0.525202
# 50%     61.000000    1.000000    0.195271
# 75%     69.000000    1.000000    0.931841
# max    101.000000    1.000000    3.200222
#
# [8 rows x 21 columns]
# Optimization terminated successfully.
#          Current function value: 0.516942
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                  348
# Model:                          Logit   Df Residuals:                      334
# Method:                           MLE   Df Model:                           13
# Date:                Mon, 04 Mar 2024   Pseudo R-squ.:                 0.07014
# Time:                        16:40:13   Log-Likelihood:                -179.90
# converged:                       True   LL-Null:                       -193.46
# Covariance Type:            nonrobust   LLR p-value:                   0.01191
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.0085      0.906      3.320      0.001       1.233       4.784
# zSCORE         0.3119      0.130      2.403      0.016       0.058       0.566
# sex_for_qc    -0.2171      0.271     -0.800      0.424      -0.749       0.315
# age           -0.0218      0.012     -1.803      0.071      -0.045       0.002
# PC1            5.2136      6.653      0.784      0.433      -7.827      18.254
# PC2           -0.1008      5.626     -0.018      0.986     -11.128      10.927
# PC3           -7.8732      6.653     -1.183      0.237     -20.912       5.166
# PC4           -9.6278      6.675     -1.442      0.149     -22.711       3.456
# PC5          -23.0369      7.791     -2.957      0.003     -38.306      -7.768
# PC6           -8.9261      6.398     -1.395      0.163     -21.466       3.613
# PC7           -5.0156      4.574     -1.097      0.273     -13.980       3.949
# PC8          -12.3037      5.968     -2.062      0.039     -24.001      -0.606
# PC9           -1.7392      6.169     -0.282      0.778     -13.830      10.352
# PC10         -10.2512      5.736     -1.787      0.074     -21.493       0.991
# ==============================================================================
# Done analyzing AMR now on to the next thing.
# Ancestry: EAS
# /tmp/ipykernel_2940629/1867000089.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat['CASE'] = dat['PHENO'] - 1
# /tmp/ipykernel_2940629/1867000089.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat["zSCORE"] = (dat["SCORE"] - mean_controls) / sd_controls
# Taking a look at the dataset for EAS regression models.
#         FID_x        PHENO          CNT         CNT2        SCORE   FID_y  \
# count  3328.0  3328.000000  3328.000000  3328.000000  3328.000000  3328.0
# mean      0.0     1.299279   126.243389    53.582031     0.002200     0.0
# std       0.0     0.458011     3.755643     4.992739     0.001866     0.0
# min       0.0     1.000000   110.000000    36.000000    -0.003884     0.0
# 25%       0.0     1.000000   124.000000    50.000000     0.000950     0.0
# 50%       0.0     1.000000   126.000000    54.000000     0.002199     0.0
# 75%       0.0     2.000000   128.000000    57.000000     0.003526     0.0
# max       0.0     2.000000   136.000000    69.000000     0.008708     0.0
#
#                PC1          PC2          PC3          PC4  ...          PC6  \
# count  3328.000000  3328.000000  3328.000000  3328.000000  ...  3328.000000
# mean      0.001644    -0.000132    -0.004306    -0.000278  ...    -0.000873
# std       0.013886     0.015333     0.014706     0.012836  ...     0.005497
# min      -0.023276    -0.018313    -0.031935    -0.146574  ...    -0.046697
# 25%      -0.008635    -0.011417    -0.018440    -0.003950  ...    -0.003913
# 50%       0.003604    -0.008585    -0.003301     0.000622  ...    -0.000782
# 75%       0.006037     0.013056     0.009446     0.004360  ...     0.002474
# max       0.031778     0.043429     0.027029     0.050745  ...     0.022488
#
#                PC7          PC8          PC9         PC10  New_Column  \
# count  3328.000000  3328.000000  3328.000000  3328.000000      3328.0
# mean      0.001659    -0.000495     0.000165    -0.000027         0.0
# std       0.012751     0.014075     0.015525     0.008219         0.0
# min      -0.068679    -0.064052    -0.086185    -0.064993         0.0
# 25%      -0.003833    -0.006279    -0.005761    -0.004744         0.0
# 50%       0.002041    -0.000369    -0.000500     0.000145         0.0
# 75%       0.008951     0.005326     0.004697     0.004964         0.0
# max       0.058891     0.280381     0.382536     0.033372         0.0
#
#         sex_for_qc          age         CASE       zSCORE
# count  3328.000000  2137.000000  3328.000000  3328.000000
# mean      1.305589    64.181170     0.299279     0.063186
# std       0.460726    10.731823     0.458011     0.999739
# min       1.000000    20.000000     0.000000    -3.196552
# 25%       1.000000    58.000000     0.000000    -0.606703
# 50%       1.000000    65.000000     0.000000     0.062377
# 75%       2.000000    71.000000     1.000000     0.773378
# max       2.000000    98.000000     1.000000     3.549957
#
# [8 rows x 21 columns]
# Optimization terminated successfully.
#          Current function value: 0.527810
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                 2137
# Model:                          Logit   Df Residuals:                     2123
# Method:                           MLE   Df Model:                           13
# Date:                Mon, 04 Mar 2024   Pseudo R-squ.:                  0.2306
# Time:                        16:40:13   Log-Likelihood:                -1127.9
# converged:                       True   LL-Null:                       -1466.0
# Covariance Type:            nonrobust   LLR p-value:                4.301e-136
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.8074      0.365     -2.212      0.027      -1.523      -0.092
# zSCORE         0.1926      0.053      3.629      0.000       0.089       0.297
# sex_for_qc    -0.5379      0.105     -5.131      0.000      -0.743      -0.332
# age            0.0215      0.005      4.336      0.000       0.012       0.031
# PC1          -53.9118      4.085    -13.197      0.000     -61.919     -45.905
# PC2          -43.1892      4.516     -9.563      0.000     -52.041     -34.338
# PC3           19.2019      6.713      2.860      0.004       6.044      32.360
# PC4            6.5084      5.146      1.265      0.206      -3.577      16.594
# PC5            6.9204     12.886      0.537      0.591     -18.335      32.176
# PC6           10.5036     12.220      0.860      0.390     -13.448      34.455
# PC7            9.9255      4.817      2.061      0.039       0.485      19.366
# PC8           -6.2720      7.014     -0.894      0.371     -20.020       7.476
# PC9            0.2714      7.943      0.034      0.973     -15.296      15.839
# PC10           1.1208      6.886      0.163      0.871     -12.375      14.617
# ==============================================================================
# Done analyzing EAS now on to the next thing.
# Ancestry: EUR
# /tmp/ipykernel_2940629/1867000089.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat['CASE'] = dat['PHENO'] - 1
# /tmp/ipykernel_2940629/1867000089.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat["zSCORE"] = (dat["SCORE"] - mean_controls) / sd_controls
# /tmp/ipykernel_2940629/1867000089.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat['CASE'] = dat['PHENO'] - 1
# /tmp/ipykernel_2940629/1867000089.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat["zSCORE"] = (dat["SCORE"] - mean_controls) / sd_controls
# Taking a look at the dataset for EUR regression models.
#          FID_x         PHENO           CNT          CNT2         SCORE  \
# count  19311.0  19311.000000  19311.000000  19311.000000  19311.000000
# mean       0.0      1.607426    129.782611     60.405831     -0.000124
# std        0.0      0.488336      2.894623      4.991056      0.002155
# min        0.0      1.000000    116.000000     42.000000     -0.009660
# 25%        0.0      1.000000    128.000000     57.000000     -0.001577
# 50%        0.0      2.000000    130.000000     60.000000     -0.000118
# 75%        0.0      2.000000    132.000000     64.000000      0.001328
# max        0.0      2.000000    136.000000     78.000000      0.008472
#
#          FID_y           PC1           PC2           PC3           PC4  ...  \
# count  19311.0  19311.000000  19311.000000  19311.000000  19311.000000  ...
# mean       0.0      0.000058     -0.000155     -0.000047      0.000197  ...
# std        0.0      0.006639      0.006877      0.006820      0.005567  ...
# min        0.0     -0.036964     -0.050640     -0.025231     -0.200306  ...
# 25%        0.0     -0.000856     -0.000868     -0.003098     -0.001911  ...
# 50%        0.0      0.001944      0.001388      0.000140      0.000418  ...
# 75%        0.0      0.003734      0.003124      0.002966      0.002741  ...
# max        0.0      0.009587      0.021952      0.053952      0.018009  ...
#
#                 PC6           PC7           PC8           PC9          PC10  \
# count  19311.000000  19311.000000  19311.000000  19311.000000  19311.000000
# mean       0.000068      0.000004      0.000032     -0.000111     -0.000009
# std        0.005512      0.006644      0.005639      0.005700      0.005611
# min       -0.274217     -0.060811     -0.283507     -0.200710     -0.104564
# 25%       -0.002416     -0.003489     -0.002779     -0.002947     -0.003126
# 50%        0.000124     -0.000076      0.000066     -0.000137      0.000163
# 75%        0.002676      0.003263      0.002842      0.002697      0.003365
# max        0.064354      0.178202      0.089575      0.124141      0.141332
#
#        New_Column    sex_for_qc           age          CASE        zSCORE
# count     19311.0  19311.000000  13852.000000  19311.000000  19311.000000
# mean          0.0      1.388898     65.987271      0.607426      0.147837
# std           0.0      0.487513     10.838823      0.488336      1.005343
# min           0.0      1.000000      0.000000      0.000000     -4.301022
# 25%           0.0      1.000000     59.000000      0.000000     -0.530011
# 50%           0.0      1.000000     67.000000      1.000000      0.150610
# 75%           0.0      2.000000     74.000000      1.000000      0.825243
# max           0.0      2.000000    103.000000      1.000000      4.158007
#
# [8 rows x 21 columns]
# Optimization terminated successfully.
#          Current function value: 0.649632
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                13852
# Model:                          Logit   Df Residuals:                    13838
# Method:                           MLE   Df Model:                           13
# Date:                Mon, 04 Mar 2024   Pseudo R-squ.:                 0.02923
# Time:                        16:40:13   Log-Likelihood:                -8998.7
# converged:                       True   LL-Null:                       -9269.6
# Covariance Type:            nonrobust   LLR p-value:                1.884e-107
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0566      0.122      0.463      0.644      -0.183       0.296
# zSCORE         0.2417      0.018     13.606      0.000       0.207       0.277
# sex_for_qc    -0.3781      0.036    -10.508      0.000      -0.449      -0.308
# age            0.0138      0.002      8.334      0.000       0.011       0.017
# PC1          -11.5176      2.867     -4.017      0.000     -17.137      -5.898
# PC2          -22.0941      4.048     -5.458      0.000     -30.028     -14.160
# PC3           -2.5696      3.435     -0.748      0.454      -9.303       4.164
# PC4           14.8035      3.504      4.225      0.000       7.936      21.671
# PC5            0.4136      3.337      0.124      0.901      -6.127       6.954
# PC6           13.7180      4.114      3.334      0.001       5.654      21.782
# PC7          -17.1823      3.174     -5.414      0.000     -23.402     -10.962
# PC8           -2.6601      3.804     -0.699      0.484     -10.115       4.795
# PC9           -0.1628      3.389     -0.048      0.962      -6.804       6.479
# PC10          10.5539      3.264      3.233      0.001       4.156      16.951
# ==============================================================================
# Done analyzing EUR now on to the next thing.
# Ancestry: CAS
# Taking a look at the dataset for CAS regression models.
#        FID_x       PHENO         CNT        CNT2       SCORE  FID_y  \
# count  489.0  489.000000  489.000000  489.000000  489.000000  489.0
# mean     0.0    1.445808  130.936605   59.153374    0.001280    0.0
# std      0.0    0.497564    2.418777    5.560306    0.002244    0.0
# min      0.0    1.000000  122.000000   44.000000   -0.006298    0.0
# 25%      0.0    1.000000  130.000000   55.000000   -0.000254    0.0
# 50%      0.0    1.000000  132.000000   59.000000    0.001364    0.0
# 75%      0.0    2.000000  132.000000   63.000000    0.002897    0.0
# max      0.0    2.000000  134.000000   77.000000    0.007581    0.0
#
#               PC1         PC2         PC3         PC4  ...         PC6  \
# count  489.000000  489.000000  489.000000  489.000000  ...  489.000000
# mean     0.011176    0.011638    0.002317    0.001303  ...   -0.004259
# std      0.034442    0.019901    0.042740    0.025456  ...    0.026702
# min     -0.067964   -0.051880   -0.073610   -0.079306  ...   -0.067326
# 25%      0.003960    0.000247   -0.013056   -0.002658  ...   -0.014022
# 50%      0.028927    0.004889   -0.000369    0.006057  ...   -0.003728
# 75%      0.035037    0.022562    0.005837    0.011985  ...    0.003586
# max      0.073469    0.105707    0.321708    0.249913  ...    0.216763
#
#               PC7         PC8         PC9        PC10  New_Column  sex_for_qc  \
# count  489.000000  489.000000  489.000000  489.000000       489.0  489.000000
# mean     0.000621    0.001625    0.000409    0.003386         0.0    1.519427
# std      0.013093    0.019291    0.019316    0.023438         0.0    0.500134
# min     -0.032206   -0.087851   -0.072243   -0.374722         0.0    1.000000
# 25%     -0.008713   -0.006776   -0.007355   -0.005007         0.0    1.000000
# 50%     -0.000364    0.002846    0.001411    0.004892         0.0    2.000000
# 75%      0.007837    0.010446    0.010422    0.013787         0.0    2.000000
# max      0.047724    0.177401    0.189628    0.073469         0.0    2.000000
#
#               age        CASE      zSCORE
# count  339.000000  489.000000  489.000000
# mean    57.984431    0.445808    0.113492
# std      8.338760    0.497564    1.003983
# min     30.449315    0.000000   -3.276594
# 25%     52.000000    0.000000   -0.572800
# 50%     57.445585    0.000000    0.151296
# 75%     62.535250    1.000000    0.836959
# max     84.000000    1.000000    2.932675
#
# [8 rows x 21 columns]
# Optimization terminated successfully.
#          Current function value: 0.539677
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                  339
# Model:                          Logit   Df Residuals:                      325
# Method:                           MLE   Df Model:                           13
# Date:                Mon, 04 Mar 2024   Pseudo R-squ.:                  0.2131
# Time:                        16:40:14   Log-Likelihood:                -182.95
# converged:                       True   LL-Null:                       -232.49
# Covariance Type:            nonrobust   LLR p-value:                 2.498e-15
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -5.3966      1.187     -4.545      0.000      -7.724      -3.070
# zSCORE         0.3767      0.135      2.794      0.005       0.112       0.641
# sex_for_qc    -0.7688      0.265     -2.898      0.004      -1.289      -0.249
# age            0.1194      0.018      6.598      0.000       0.084       0.155
# PC1          -19.5645     16.306     -1.200      0.230     -51.523      12.394
# PC2            6.8174     23.266      0.293      0.770     -38.783      52.418
# PC3           20.5394     25.123      0.818      0.414     -28.700      69.779
# PC4          -28.1973     17.099     -1.649      0.099     -61.710       5.316
# PC5           14.1695     20.350      0.696      0.486     -25.717      54.056
# PC6            8.1944     16.521      0.496      0.620     -24.187      40.576
# PC7           18.8775     11.859      1.592      0.111      -4.365      42.120
# PC8           19.5061     11.551      1.689      0.091      -3.133      42.145
# PC9           -8.1482     10.121     -0.805      0.421     -27.985      11.689
# PC10          -5.6757      6.709     -0.846      0.398     -18.825       7.474
# ==============================================================================
# Done analyzing CAS now on to the next thing.

# %%
import pandas as pd
import statsmodels.api as sm

## RUN PRS versus RISK across ancestries (EAST ASIANS summ stats)
# List of ancestries
ancestries = ["AAC", "AFR", "AJ", "AMR", "EAS", "EUR", "CAS"]

for ancestry in ancestries:  
    print("Ancestry:", ancestry)
    # Construct file paths
    prs_file = f"{WORK_DIR}/imputed_data/" + ancestry + "/PRS_score_release_EASTASIANS.profile"
    covs_file = f"{WORK_DIR}/quality_control/release6/genotype_qc/GP2_release6_NOVEMBER_" + ancestry + "_maf_hwe_pca.eigenvec"

    # Read PRS data
    temp_data = pd.read_csv(prs_file, delim_whitespace =True)

    # Read covariates data
    # Specify your custom column names
    custom_column_names = ["FID", "IID", "PC1", "PC2", "PC3", "PC4", "PC5", "PC6", "PC7", "PC8", "PC9", "PC10"]

    # Read the tab-delimited file, skip the first line, and use custom column names
    temp_covs = pd.read_csv(covs_file, delim_whitespace =True, skiprows=1, names=custom_column_names)

    # Read additional covariates
    temp_covs_2 = pd.read_csv(f"{WORK_DIR}/covariates.txt", sep="\t")
    temp_covs_2.head()
    temp_covs_2 = temp_covs_2.rename(columns={"GP2sampleID": "IID"})

    # Merge covariates
    covs = pd.merge(temp_covs, temp_covs_2, on="IID")

    # Merge PRS data and covariates
    data = pd.merge(temp_data, covs, on="IID")

    # print("looking a covs")
    # print(covs.head())
    # print("looking at temp_data")
    # print(temp_data.head())
    # print("looking at data")
    # print(data.head())
    # print(data.describe())

    # Remove missing or unknown cases
    dat = data[data["PHENO"] != -9]

    # Logistic regression model phenotype
    dat['CASE'] = dat['PHENO'] - 1 

    # Standardize PRS
    mean_controls = dat.loc[dat["CASE"] == 0, "SCORE"].mean()
    sd_controls = dat.loc[dat["CASE"] == 0, "SCORE"].std()
    dat["zSCORE"] = (dat["SCORE"] - mean_controls) / sd_controls

    # Quick peak at the data
    print("Taking a look at the dataset for " + ancestry + " regression models.")
    print(dat.describe())

    # Logistic regression model using statsmodels formula
    formula = "CASE ~ zSCORE + sex_for_qc + age + PC1 + PC2 + PC3 + PC4 + PC5 + PC6 + PC7 + PC8 + PC9 + PC10"
    model = sm.Logit.from_formula(formula, data=dat)
    result = model.fit()

    # Print the summary
    print(result.summary())

    # Print
    print("Done analyzing " + ancestry + " now on to the next thing.")
# Out:
# Ancestry: AAC
# Taking a look at the dataset for AAC regression models.
#         FID_x        PHENO          CNT         CNT2        SCORE   FID_y  \
# count  1030.0  1030.000000  1030.000000  1030.000000  1030.000000  1030.0
# mean      0.0     1.242718   126.631068    57.075728    -0.002478     0.0
# std       0.0     0.428935     1.628764     4.617549     0.003183     0.0
# min       0.0     1.000000   118.000000    40.000000    -0.010982     0.0
# 25%       0.0     1.000000   126.000000    54.000000    -0.004699     0.0
# 50%       0.0     1.000000   126.000000    57.000000    -0.002532     0.0
# 75%       0.0     1.000000   128.000000    60.000000    -0.000287     0.0
# max       0.0     2.000000   128.000000    72.000000     0.006207     0.0
#
#                PC1          PC2          PC3          PC4  ...          PC6  \
# count  1030.000000  1030.000000  1030.000000  1030.000000  ...  1030.000000
# mean     -0.009980     0.003704     0.000382     0.000388  ...    -0.000329
# std       0.017125     0.022483     0.030607     0.010635  ...     0.030206
# min      -0.033599    -0.045752    -0.458968    -0.047664  ...    -0.436147
# 25%      -0.020904    -0.009009    -0.000814    -0.006343  ...    -0.009340
# 50%      -0.014576     0.003609     0.004129     0.000099  ...    -0.000538
# 75%      -0.004136     0.013117     0.008565     0.006900  ...     0.009240
# max       0.074809     0.124427     0.026472     0.050560  ...     0.196375
#
#                PC7          PC8          PC9         PC10  New_Column  \
# count  1030.000000  1030.000000  1030.000000  1030.000000      1030.0
# mean     -0.000303    -0.000007     0.000497     0.000132         0.0
# std       0.030361     0.030334     0.016482     0.028248         0.0
# min      -0.406578    -0.179384    -0.048169    -0.102527         0.0
# 25%      -0.009806    -0.011162    -0.010167    -0.017858         0.0
# 50%      -0.000200    -0.002399     0.000553    -0.000995         0.0
# 75%       0.008177     0.008085     0.011469     0.018500         0.0
# max       0.295931     0.443832     0.051439     0.173980         0.0
#
#         sex_for_qc         age         CASE       zSCORE
# count  1030.000000  881.000000  1030.000000  1030.000000
# mean      1.589320   65.837020     0.242718     0.094468
# std       0.492196   10.474319     0.428935     1.013895
# min       1.000000   18.000000     0.000000    -2.614365
# 25%       1.000000   60.000000     0.000000    -0.612850
# 50%       2.000000   66.000000     0.000000     0.077298
# 75%       2.000000   72.000000     0.000000     0.792487
# max       2.000000   95.000000     1.000000     2.861054
#
# [8 rows x 21 columns]
# Optimization terminated successfully.
#          Current function value: 0.412815
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                  881
# Model:                          Logit   Df Residuals:                      867
# Method:                           MLE   Df Model:                           13
# Date:                Mon, 04 Mar 2024   Pseudo R-squ.:                  0.1944
# Time:                        16:40:14   Log-Likelihood:                -363.69
# converged:                       True   LL-Null:                       -451.45
# Covariance Type:            nonrobust   LLR p-value:                 1.385e-30
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.3538      0.636     -2.128      0.033      -2.601      -0.107
# zSCORE         0.3062      0.096      3.175      0.001       0.117       0.495
# sex_for_qc    -0.7827      0.189     -4.146      0.000      -1.153      -0.413
# age            0.0240      0.009      2.730      0.006       0.007       0.041
# PC1           52.5091      6.758      7.770      0.000      39.264      65.755
# PC2           -0.2548      3.871     -0.066      0.948      -7.843       7.333
# PC3          -18.3764     13.822     -1.330      0.184     -45.467       8.714
# PC4           -0.5631     10.400     -0.054      0.957     -20.946      19.820
# PC5          -18.4024      5.424     -3.393      0.001     -29.034      -7.771
# PC6           19.1895      6.465      2.968      0.003       6.519      31.860
# PC7            5.1608      6.363      0.811      0.417      -7.311      17.633
# PC8           15.5267      5.975      2.598      0.009       3.815      27.238
# PC9           -4.7089      6.038     -0.780      0.435     -16.543       7.125
# PC10          -1.4254      3.489     -0.409      0.683      -8.263       5.413
# ==============================================================================
# Done analyzing AAC now on to the next thing.
# Ancestry: AFR
# /tmp/ipykernel_2940629/3627123294.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat['CASE'] = dat['PHENO'] - 1
# /tmp/ipykernel_2940629/3627123294.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat["zSCORE"] = (dat["SCORE"] - mean_controls) / sd_controls
# /tmp/ipykernel_2940629/3627123294.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat['CASE'] = dat['PHENO'] - 1
# /tmp/ipykernel_2940629/3627123294.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat["zSCORE"] = (dat["SCORE"] - mean_controls) / sd_controls
# Taking a look at the dataset for AFR regression models.
#         FID_x        PHENO          CNT         CNT2        SCORE   FID_y  \
# count  2569.0  2569.000000  2569.000000  2569.000000  2569.000000  2569.0
# mean      0.0     1.355002   125.420786    54.637213    -0.004499     0.0
# std       0.0     0.478607     2.298765     4.439972     0.002793     0.0
# min       0.0     1.000000   114.000000    37.000000    -0.014022     0.0
# 25%       0.0     1.000000   124.000000    52.000000    -0.006336     0.0
# 50%       0.0     1.000000   126.000000    55.000000    -0.004533     0.0
# 75%       0.0     2.000000   128.000000    58.000000    -0.002631     0.0
# max       0.0     2.000000   128.000000    70.000000     0.005817     0.0
#
#                PC1          PC2          PC3          PC4  ...          PC6  \
# count  2569.000000  2569.000000  2569.000000  2569.000000  ...  2569.000000
# mean      0.000098     0.000521    -0.000131     0.000178  ...     0.000027
# std       0.019510     0.019190     0.019698     0.019666  ...     0.019703
# min      -0.086743    -0.062793    -0.267818    -0.193079  ...    -0.124184
# 25%       0.003080    -0.016056    -0.000504    -0.007958  ...    -0.004954
# 50%       0.005676     0.008915     0.004123    -0.003376  ...    -0.000029
# 75%       0.009268     0.016572     0.007552     0.002904  ...     0.004821
# max       0.016398     0.025739     0.018598     0.093391  ...     0.453329
#
#                PC7          PC8          PC9         PC10  New_Column  \
# count  2569.000000  2569.000000  2569.000000  2569.000000      2569.0
# mean      0.000009     0.000026    -0.000024     0.000049         0.0
# std       0.019707     0.019657     0.019687     0.019693         0.0
# min      -0.500779    -0.053069    -0.137205    -0.265407         0.0
# 25%      -0.006332    -0.006676    -0.006264    -0.008784         0.0
# 50%       0.000440    -0.000819    -0.000399    -0.000132         0.0
# 75%       0.006973     0.004987     0.005580     0.008405         0.0
# max       0.063078     0.525289     0.529396     0.166573         0.0
#
#         sex_for_qc          age         CASE       zSCORE
# count  2569.000000  1040.000000  2569.000000  2569.000000
# mean      1.436357    63.424856     0.355002     0.040013
# std       0.496030    14.980335     0.478607     1.005569
# min       1.000000    18.000000     0.000000    -3.388237
# 25%       1.000000    58.000000     0.000000    -0.621571
# 50%       1.000000    66.000000     0.000000     0.027735
# 75%       2.000000    73.000000     1.000000     0.712294
# max       2.000000    92.000000     1.000000     3.753358
#
# [8 rows x 21 columns]
# Optimization terminated successfully.
#          Current function value: 0.396229
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                 1040
# Model:                          Logit   Df Residuals:                     1026
# Method:                           MLE   Df Model:                           13
# Date:                Mon, 04 Mar 2024   Pseudo R-squ.:                  0.1008
# Time:                        16:40:14   Log-Likelihood:                -412.08
# converged:                       True   LL-Null:                       -458.25
# Covariance Type:            nonrobust   LLR p-value:                 4.971e-14
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.9984      0.504     -3.967      0.000      -2.986      -1.011
# zSCORE         0.2742      0.090      3.057      0.002       0.098       0.450
# sex_for_qc    -0.3770      0.180     -2.096      0.036      -0.729      -0.025
# age            0.0065      0.006      1.183      0.237      -0.004       0.017
# PC1          -22.8442      4.792     -4.767      0.000     -32.237     -13.452
# PC2           11.4001      9.590      1.189      0.235      -7.396      30.197
# PC3            7.8352     22.442      0.349      0.727     -36.150      51.821
# PC4          -28.5787     16.632     -1.718      0.086     -61.177       4.020
# PC5            6.2504     16.106      0.388      0.698     -25.317      37.818
# PC6            8.0341     14.510      0.554      0.580     -20.404      36.473
# PC7           -8.8810     11.658     -0.762      0.446     -31.730      13.968
# PC8          -16.4630     10.184     -1.617      0.106     -36.424       3.498
# PC9           -9.0766     10.298     -0.881      0.378     -29.261      11.108
# PC10          18.4757     10.242      1.804      0.071      -1.598      38.550
# ==============================================================================
# Done analyzing AFR now on to the next thing.
# Ancestry: AJ
# Taking a look at the dataset for AJ regression models.
#         FID_x        PHENO          CNT         CNT2        SCORE   FID_y  \
# count  1460.0  1460.000000  1460.000000  1460.000000  1460.000000  1460.0
# mean      0.0     1.687671   122.723288    60.400000     0.001861     0.0
# std       0.0     0.463602     1.472668     4.979905     0.003180     0.0
# min       0.0     1.000000   114.000000    46.000000    -0.007872     0.0
# 25%       0.0     1.000000   122.000000    57.000000    -0.000354     0.0
# 50%       0.0     2.000000   122.000000    60.000000     0.001843     0.0
# 75%       0.0     2.000000   124.000000    64.000000     0.004071     0.0
# max       0.0     2.000000   124.000000    77.000000     0.011714     0.0
#
#                PC1          PC2          PC3          PC4  ...          PC6  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  ...  1460.000000
# mean      0.000386    -0.000949    -0.000961     0.000456  ...    -0.000814
# std       0.009207     0.008944     0.017801     0.013905  ...     0.013946
# min      -0.029825    -0.034457    -0.076438    -0.209755  ...    -0.050562
# 25%      -0.005959    -0.006781    -0.010562    -0.007867  ...    -0.010233
# 50%       0.000505    -0.001005     0.000103     0.000257  ...    -0.000954
# 75%       0.006889     0.004874     0.010536     0.009139  ...     0.008670
# max       0.030427     0.027236     0.048794     0.116349  ...     0.048372
#
#                PC7          PC8          PC9         PC10  New_Column  \
# count  1460.000000  1460.000000  1460.000000  1460.000000      1460.0
# mean     -0.000264    -0.000071     0.000385     0.000809         0.0
# std       0.014605     0.013290     0.015533     0.015747         0.0
# min      -0.047622    -0.120060    -0.306696    -0.086506         0.0
# 25%      -0.009486    -0.008790    -0.008289    -0.009515         0.0
# 50%      -0.000525    -0.000580     0.000651     0.000449         0.0
# 75%       0.008242     0.008571     0.009484     0.010086         0.0
# max       0.219105     0.057783     0.054630     0.063205         0.0
#
#         sex_for_qc          age         CASE       zSCORE
# count  1460.000000  1193.000000  1460.000000  1460.000000
# mean      1.313699    68.917248     0.687671     0.171030
# std       0.464154     9.835406     0.463602     1.049742
# min       1.000000    35.000000     0.000000    -3.042185
# 25%       1.000000    62.000000     0.000000    -0.560401
# 50%       1.000000    69.842574     1.000000     0.165122
# 75%       2.000000    76.000000     1.000000     0.900667
# max       2.000000    96.000000     1.000000     3.423760
#
# [8 rows x 21 columns]
# /tmp/ipykernel_2940629/3627123294.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat['CASE'] = dat['PHENO'] - 1
# /tmp/ipykernel_2940629/3627123294.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat["zSCORE"] = (dat["SCORE"] - mean_controls) / sd_controls
# /tmp/ipykernel_2940629/3627123294.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat['CASE'] = dat['PHENO'] - 1
# /tmp/ipykernel_2940629/3627123294.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat["zSCORE"] = (dat["SCORE"] - mean_controls) / sd_controls
# Optimization terminated successfully.
#          Current function value: 0.515641
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                 1193
# Model:                          Logit   Df Residuals:                     1179
# Method:                           MLE   Df Model:                           13
# Date:                Mon, 04 Mar 2024   Pseudo R-squ.:                 0.03766
# Time:                        16:40:14   Log-Likelihood:                -615.16
# converged:                       True   LL-Null:                       -639.23
# Covariance Type:            nonrobust   LLR p-value:                 6.180e-06
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.0925      0.543      2.013      0.044       0.029       2.156
# zSCORE         0.2603      0.069      3.798      0.000       0.126       0.395
# sex_for_qc    -0.6877      0.144     -4.773      0.000      -0.970      -0.405
# age            0.0153      0.007      2.141      0.032       0.001       0.029
# PC1           -7.9374      7.706     -1.030      0.303     -23.040       7.165
# PC2           -1.4376      8.021     -0.179      0.858     -17.159      14.284
# PC3            1.6607      4.452      0.373      0.709      -7.065      10.386
# PC4           -1.1242      5.487     -0.205      0.838     -11.878       9.630
# PC5           -0.8273      5.685     -0.146      0.884     -11.971      10.316
# PC6           -0.7483      5.161     -0.145      0.885     -10.863       9.367
# PC7            4.9118      5.225      0.940      0.347      -5.328      15.152
# PC8           -2.0308      5.381     -0.377      0.706     -12.578       8.516
# PC9           -1.6102      4.811     -0.335      0.738     -11.040       7.820
# PC10           7.9743      4.939      1.615      0.106      -1.705      17.654
# ==============================================================================
# Done analyzing AJ now on to the next thing.
# Ancestry: AMR
# Taking a look at the dataset for AMR regression models.
#        FID_x       PHENO         CNT        CNT2       SCORE  FID_y  \
# count  453.0  453.000000  453.000000  453.000000  453.000000  453.0
# mean     0.0    1.701987  127.037528   62.549669    0.001883    0.0
# std      0.0    0.457891    1.366769    5.202989    0.003247    0.0
# min      0.0    1.000000  122.000000   49.000000   -0.009131    0.0
# 25%      0.0    1.000000  126.000000   59.000000   -0.000526    0.0
# 50%      0.0    2.000000  128.000000   62.000000    0.002107    0.0
# 75%      0.0    2.000000  128.000000   66.000000    0.004307    0.0
# max      0.0    2.000000  128.000000   80.000000    0.009609    0.0
#
#               PC1         PC2         PC3         PC4  ...         PC6  \
# count  453.000000  453.000000  453.000000  453.000000  ...  453.000000
# mean    -0.017819   -0.008568    0.000970   -0.000533  ...    0.003584
# std      0.029649    0.034075    0.037581    0.038946  ...    0.023263
# min     -0.123816   -0.093844   -0.312350   -0.408986  ...   -0.073245
# 25%     -0.036678   -0.031159   -0.009846   -0.006238  ...   -0.009768
# 50%     -0.019175   -0.011139    0.001072    0.004173  ...    0.003848
# 75%      0.003184    0.012866    0.011358    0.013370  ...    0.018079
# max      0.048969    0.123855    0.371717    0.052928  ...    0.080846
#
#               PC7         PC8         PC9        PC10  New_Column  sex_for_qc  \
# count  453.000000  453.000000  453.000000  453.000000       453.0  453.000000
# mean     0.004827   -0.001417   -0.001931    0.001105         0.0    1.441501
# std      0.031831    0.023974    0.023192    0.025400         0.0    0.497115
# min     -0.092123   -0.204018   -0.141111   -0.057064         0.0    1.000000
# 25%     -0.014814   -0.012361   -0.013899   -0.014084         0.0    1.000000
# 50%      0.010154   -0.000880   -0.002580    0.001453         0.0    1.000000
# 75%      0.026593    0.012373    0.011910    0.013774         0.0    2.000000
# max      0.078738    0.055613    0.130723    0.247554         0.0    2.000000
#
#               age        CASE      zSCORE
# count  348.000000  453.000000  453.000000
# mean    61.091687    0.701987    0.279537
# std     11.407730    0.457891    1.019405
# min     26.000000    0.000000   -3.178409
# 25%     54.000000    0.000000   -0.476506
# 50%     61.000000    1.000000    0.349979
# 75%     69.000000    1.000000    1.040743
# max    101.000000    1.000000    2.705249
#
# [8 rows x 21 columns]
# Optimization terminated successfully.
#          Current function value: 0.502630
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                  348
# Model:                          Logit   Df Residuals:                      334
# Method:                           MLE   Df Model:                           13
# Date:                Mon, 04 Mar 2024   Pseudo R-squ.:                 0.09588
# Time:                        16:40:14   Log-Likelihood:                -174.92
# converged:                       True   LL-Null:                       -193.46
# Covariance Type:            nonrobust   LLR p-value:                 0.0003998
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.2360      0.934      3.466      0.001       1.406       5.066
# zSCORE         0.5183      0.134      3.862      0.000       0.255       0.781
# sex_for_qc    -0.2561      0.274     -0.935      0.350      -0.793       0.281
# age           -0.0253      0.012     -2.063      0.039      -0.049      -0.001
# PC1            2.5084      6.714      0.374      0.709     -10.652      15.668
# PC2            3.6065      5.893      0.612      0.541      -7.943      15.156
# PC3           -6.7648      6.638     -1.019      0.308     -19.776       6.246
# PC4           -8.0112      6.648     -1.205      0.228     -21.040       5.018
# PC5          -24.1286      8.018     -3.009      0.003     -39.844      -8.414
# PC6           -8.0208      6.520     -1.230      0.219     -20.801       4.759
# PC7           -4.9116      4.658     -1.054      0.292     -14.041       4.218
# PC8          -12.9172      5.999     -2.153      0.031     -24.675      -1.159
# PC9           -3.3050      6.155     -0.537      0.591     -15.368       8.758
# PC10         -10.0006      5.881     -1.700      0.089     -21.527       1.526
# ==============================================================================
# Done analyzing AMR now on to the next thing.
# Ancestry: EAS
# /tmp/ipykernel_2940629/3627123294.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat['CASE'] = dat['PHENO'] - 1
# /tmp/ipykernel_2940629/3627123294.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat["zSCORE"] = (dat["SCORE"] - mean_controls) / sd_controls
# Taking a look at the dataset for EAS regression models.
#         FID_x        PHENO          CNT        CNT2        SCORE   FID_y  \
# count  3328.0  3328.000000  3328.000000  3328.00000  3328.000000  3328.0
# mean      0.0     1.299279   116.534856    53.56881     0.000127     0.0
# std       0.0     0.458011     3.713191     4.99342     0.002984     0.0
# min       0.0     1.000000   104.000000    36.00000    -0.011113     0.0
# 25%       0.0     1.000000   114.000000    50.00000    -0.001864     0.0
# 50%       0.0     1.000000   116.000000    54.00000     0.000119     0.0
# 75%       0.0     2.000000   120.000000    57.00000     0.002154     0.0
# max       0.0     2.000000   126.000000    69.00000     0.010134     0.0
#
#                PC1          PC2          PC3          PC4  ...          PC6  \
# count  3328.000000  3328.000000  3328.000000  3328.000000  ...  3328.000000
# mean      0.001644    -0.000132    -0.004306    -0.000278  ...    -0.000873
# std       0.013886     0.015333     0.014706     0.012836  ...     0.005497
# min      -0.023276    -0.018313    -0.031935    -0.146574  ...    -0.046697
# 25%      -0.008635    -0.011417    -0.018440    -0.003950  ...    -0.003913
# 50%       0.003604    -0.008585    -0.003301     0.000622  ...    -0.000782
# 75%       0.006037     0.013056     0.009446     0.004360  ...     0.002474
# max       0.031778     0.043429     0.027029     0.050745  ...     0.022488
#
#                PC7          PC8          PC9         PC10  New_Column  \
# count  3328.000000  3328.000000  3328.000000  3328.000000      3328.0
# mean      0.001659    -0.000495     0.000165    -0.000027         0.0
# std       0.012751     0.014075     0.015525     0.008219         0.0
# min      -0.068679    -0.064052    -0.086185    -0.064993         0.0
# 25%      -0.003833    -0.006279    -0.005761    -0.004744         0.0
# 50%       0.002041    -0.000369    -0.000500     0.000145         0.0
# 75%       0.008951     0.005326     0.004697     0.004964         0.0
# max       0.058891     0.280381     0.382536     0.033372         0.0
#
#         sex_for_qc          age         CASE       zSCORE
# count  3328.000000  2137.000000  3328.000000  3328.000000
# mean      1.305589    64.181170     0.299279     0.048385
# std       0.460726    10.731823     0.458011     0.991470
# min       1.000000    20.000000     0.000000    -3.685779
# 25%       1.000000    58.000000     0.000000    -0.613114
# 50%       1.000000    65.000000     0.000000     0.045769
# 75%       2.000000    71.000000     1.000000     0.721558
# max       2.000000    98.000000     1.000000     3.372836
#
# [8 rows x 21 columns]
# Optimization terminated successfully.
#          Current function value: 0.525310
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                 2137
# Model:                          Logit   Df Residuals:                     2123
# Method:                           MLE   Df Model:                           13
# Date:                Mon, 04 Mar 2024   Pseudo R-squ.:                  0.2343
# Time:                        16:40:14   Log-Likelihood:                -1122.6
# converged:                       True   LL-Null:                       -1466.0
# Covariance Type:            nonrobust   LLR p-value:                2.239e-138
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.8511      0.366     -2.322      0.020      -1.569      -0.133
# zSCORE         0.2608      0.054      4.850      0.000       0.155       0.366
# sex_for_qc    -0.5371      0.105     -5.109      0.000      -0.743      -0.331
# age            0.0221      0.005      4.434      0.000       0.012       0.032
# PC1          -56.6988      4.135    -13.712      0.000     -64.803     -48.595
# PC2          -44.9513      4.529     -9.926      0.000     -53.828     -36.075
# PC3           19.6410      6.717      2.924      0.003       6.477      32.805
# PC4            6.3403      5.176      1.225      0.221      -3.804      16.485
# PC5            6.9505     12.901      0.539      0.590     -18.335      32.236
# PC6           10.9998     12.273      0.896      0.370     -13.054      35.054
# PC7            8.6037      4.815      1.787      0.074      -0.834      18.042
# PC8           -7.2870      7.038     -1.035      0.300     -21.081       6.506
# PC9            0.1385      7.945      0.017      0.986     -15.434      15.711
# PC10           0.6507      6.899      0.094      0.925     -12.870      14.172
# ==============================================================================
# Done analyzing EAS now on to the next thing.
# Ancestry: EUR
# /tmp/ipykernel_2940629/3627123294.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat['CASE'] = dat['PHENO'] - 1
# /tmp/ipykernel_2940629/3627123294.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat["zSCORE"] = (dat["SCORE"] - mean_controls) / sd_controls
# /tmp/ipykernel_2940629/3627123294.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat['CASE'] = dat['PHENO'] - 1
# /tmp/ipykernel_2940629/3627123294.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat["zSCORE"] = (dat["SCORE"] - mean_controls) / sd_controls
# Taking a look at the dataset for EUR regression models.
#          FID_x         PHENO           CNT          CNT2         SCORE  \
# count  19311.0  19311.000000  19311.000000  19311.000000  19311.000000
# mean       0.0      1.607426    122.957796     61.305422      0.003880
# std        0.0      0.488336      2.604508      4.965706      0.002987
# min        0.0      1.000000    110.000000     40.000000     -0.008609
# 25%        0.0      1.000000    122.000000     58.000000      0.001860
# 50%        0.0      2.000000    124.000000     61.000000      0.003904
# 75%        0.0      2.000000    124.000000     65.000000      0.005919
# max        0.0      2.000000    128.000000     78.000000      0.015825
#
#          FID_y           PC1           PC2           PC3           PC4  ...  \
# count  19311.0  19311.000000  19311.000000  19311.000000  19311.000000  ...
# mean       0.0      0.000058     -0.000155     -0.000047      0.000197  ...
# std        0.0      0.006639      0.006877      0.006820      0.005567  ...
# min        0.0     -0.036964     -0.050640     -0.025231     -0.200306  ...
# 25%        0.0     -0.000856     -0.000868     -0.003098     -0.001911  ...
# 50%        0.0      0.001944      0.001388      0.000140      0.000418  ...
# 75%        0.0      0.003734      0.003124      0.002966      0.002741  ...
# max        0.0      0.009587      0.021952      0.053952      0.018009  ...
#
#                 PC6           PC7           PC8           PC9          PC10  \
# count  19311.000000  19311.000000  19311.000000  19311.000000  19311.000000
# mean       0.000068      0.000004      0.000032     -0.000111     -0.000009
# std        0.005512      0.006644      0.005639      0.005700      0.005611
# min       -0.274217     -0.060811     -0.283507     -0.200710     -0.104564
# 25%       -0.002416     -0.003489     -0.002779     -0.002947     -0.003126
# 50%        0.000124     -0.000076      0.000066     -0.000137      0.000163
# 75%        0.002676      0.003263      0.002842      0.002697      0.003365
# max        0.064354      0.178202      0.089575      0.124141      0.141332
#
#        New_Column    sex_for_qc           age          CASE        zSCORE
# count     19311.0  19311.000000  13852.000000  19311.000000  19311.000000
# mean          0.0      1.388898     65.987271      0.607426      0.179781
# std           0.0      0.487513     10.838823      0.488336      1.007068
# min           0.0      1.000000      0.000000      0.000000     -4.030671
# 25%           0.0      1.000000     59.000000      0.000000     -0.501178
# 50%           0.0      1.000000     67.000000      1.000000      0.187716
# 75%           0.0      2.000000     74.000000      1.000000      0.867228
# max           0.0      2.000000    103.000000      1.000000      4.206652
#
# [8 rows x 21 columns]
# Optimization terminated successfully.
#          Current function value: 0.645158
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                13852
# Model:                          Logit   Df Residuals:                    13838
# Method:                           MLE   Df Model:                           13
# Date:                Mon, 04 Mar 2024   Pseudo R-squ.:                 0.03591
# Time:                        16:40:15   Log-Likelihood:                -8936.7
# converged:                       True   LL-Null:                       -9269.6
# Covariance Type:            nonrobust   LLR p-value:                7.108e-134
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0217      0.123     -0.176      0.860      -0.263       0.219
# zSCORE         0.3158      0.018     17.405      0.000       0.280       0.351
# sex_for_qc    -0.3780      0.036    -10.459      0.000      -0.449      -0.307
# age            0.0147      0.002      8.852      0.000       0.011       0.018
# PC1          -13.2253      2.874     -4.601      0.000     -18.859      -7.592
# PC2          -23.6050      4.064     -5.808      0.000     -31.571     -15.639
# PC3           -1.6031      3.453     -0.464      0.642      -8.371       5.165
# PC4           14.9020      3.465      4.301      0.000       8.111      21.693
# PC5           -0.1566      3.280     -0.048      0.962      -6.586       6.273
# PC6           13.1753      4.166      3.163      0.002       5.011      21.340
# PC7          -16.8930      3.145     -5.371      0.000     -23.058     -10.728
# PC8           -2.2413      3.785     -0.592      0.554      -9.660       5.178
# PC9            0.0622      3.356      0.019      0.985      -6.516       6.641
# PC10           9.5301      3.274      2.911      0.004       3.113      15.947
# ==============================================================================
# Done analyzing EUR now on to the next thing.
# Ancestry: CAS
# Taking a look at the dataset for CAS regression models.
#        FID_x       PHENO         CNT        CNT2       SCORE  FID_y  \
# count  489.0  489.000000  489.000000  489.000000  489.000000  489.0
# mean     0.0    1.445808  123.280164   59.468303    0.002007    0.0
# std      0.0    0.497564    2.229928    5.534126    0.003339    0.0
# min      0.0    1.000000  116.000000   46.000000   -0.005835    0.0
# 25%      0.0    1.000000  122.000000   56.000000   -0.000422    0.0
# 50%      0.0    1.000000  124.000000   59.000000    0.002058    0.0
# 75%      0.0    2.000000  124.000000   63.000000    0.004407    0.0
# max      0.0    2.000000  126.000000   79.000000    0.010405    0.0
#
#               PC1         PC2         PC3         PC4  ...         PC6  \
# count  489.000000  489.000000  489.000000  489.000000  ...  489.000000
# mean     0.011176    0.011638    0.002317    0.001303  ...   -0.004259
# std      0.034442    0.019901    0.042740    0.025456  ...    0.026702
# min     -0.067964   -0.051880   -0.073610   -0.079306  ...   -0.067326
# 25%      0.003960    0.000247   -0.013056   -0.002658  ...   -0.014022
# 50%      0.028927    0.004889   -0.000369    0.006057  ...   -0.003728
# 75%      0.035037    0.022562    0.005837    0.011985  ...    0.003586
# max      0.073469    0.105707    0.321708    0.249913  ...    0.216763
#
#               PC7         PC8         PC9        PC10  New_Column  sex_for_qc  \
# count  489.000000  489.000000  489.000000  489.000000       489.0  489.000000
# mean     0.000621    0.001625    0.000409    0.003386         0.0    1.519427
# std      0.013093    0.019291    0.019316    0.023438         0.0    0.500134
# min     -0.032206   -0.087851   -0.072243   -0.374722         0.0    1.000000
# 25%     -0.008713   -0.006776   -0.007355   -0.005007         0.0    1.000000
# 50%     -0.000364    0.002846    0.001411    0.004892         0.0    2.000000
# 75%      0.007837    0.010446    0.010422    0.013787         0.0    2.000000
# max      0.047724    0.177401    0.189628    0.073469         0.0    2.000000
#
#               age        CASE      zSCORE
# count  339.000000  489.000000  489.000000
# mean    57.984431    0.445808    0.094574
# std      8.338760    0.497564    1.013621
# min     30.449315    0.000000   -2.285994
# 25%     52.000000    0.000000   -0.642773
# 50%     57.445585    0.000000    0.110203
# 75%     62.535250    1.000000    0.823262
# max     84.000000    1.000000    2.643985
#
# [8 rows x 21 columns]
# Optimization terminated successfully.
#          Current function value: 0.546684
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                  339
# Model:                          Logit   Df Residuals:                      325
# Method:                           MLE   Df Model:                           13
# Date:                Mon, 04 Mar 2024   Pseudo R-squ.:                  0.2029
# Time:                        16:40:15   Log-Likelihood:                -185.33
# converged:                       True   LL-Null:                       -232.49
# Covariance Type:            nonrobust   LLR p-value:                 2.063e-14
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -5.3253      1.190     -4.477      0.000      -7.657      -2.994
# zSCORE         0.2401      0.131      1.834      0.067      -0.017       0.497
# sex_for_qc    -0.7936      0.266     -2.985      0.003      -1.315      -0.273
# age            0.1200      0.018      6.581      0.000       0.084       0.156
# PC1          -20.4441     16.226     -1.260      0.208     -52.246      11.358
# PC2           10.3749     23.221      0.447      0.655     -35.138      55.887
# PC3           17.2110     24.939      0.690      0.490     -31.668      66.090
# PC4          -20.2838     16.548     -1.226      0.220     -52.717      12.149
# PC5           13.3813     20.127      0.665      0.506     -26.068      52.830
# PC6            8.6712     16.355      0.530      0.596     -23.384      40.726
# PC7           19.6326     11.788      1.665      0.096      -3.472      42.737
# PC8           18.0063     11.420      1.577      0.115      -4.376      40.389
# PC9           -7.2656     10.052     -0.723      0.470     -26.967      12.436
# PC10          -5.6402      6.777     -0.832      0.405     -18.923       7.643
# ==============================================================================
# Done analyzing CAS now on to the next thing.
