# %% [markdown]
# # Estimate Multi-ancestry PRS profiles
# - **Project:** Multi-ancestry PRS
# - **Version:** Python/3.9
# - **Status:** COMPLETE
# - **Last Updated:** 25-FEB-2024
#
# ## Notebook Overview
# - Extract 90 SNPs from individual level data across ancestries in unrelated individual level data
# - Merge files
# - Estimate profiles

# %% [markdown]
# ## Extract 90 SNPs from individual level data across ancestries in unrelated individual level data

# %%
## Input data
cd ${WORK_DIR}/imputed_data/

# %%
## Load packages
module load plink/2.0-alpha
# Out:
# [+] Loading plink  2.0-alpha

# %%
## Extract 90 risk loci per chr

# List of ancestries
ANCESTRIES=("AAC" "AFR" "AJ" "AMR" "EAS" "EUR" "CAS")

# Iterate over ancestries
for ANCESTRY in "${ANCESTRIES[@]}"; do
    for chnum in {1..22}; do
        plink2 \
        --pfile "$ANCESTRY"/chr"$chnum"_"$ANCESTRY"_release6 \
        --extract range /data/GP2/projects/PRS_multi_ancestry_Nov2023/CHR_POS_HG38.txt  \
        --make-bed \
        --out "$ANCESTRY"/PRS_chr"$chnum"_release6
    done
done

# %%
## Change kernel to python
import pandas as pd

# Read the file into a DataFrame
file_path = f"{WORK_DIR}/GP2_master_key_release6.txt"
df = pd.read_csv(file_path, delimiter='\t')  # Assuming columns are tab-separated, adjust if needed

# Add a new column with "0"
df.insert(0, 'New_Column', 0)

# Extract columns GP2sampleID and sex_for_qc
result_df = df[['New_Column', 'GP2sampleID', 'sex_for_qc']]

# Save the result to a CSV file without headers
result_df.to_csv(f'{WORK_DIR}/sex.txt', index=False, header=False, sep = ' ')

# %%
module load plink/1.9
# Out:
# [+] Loading plink  1.9.0-beta4.4  on cn2458

# %%
# Change kernel back to bash
# List of ancestries
ANCESTRIES=("AAC" "AFR" "AJ" "AMR" "EAS" "EUR" "CAS")

cd ${WORK_DIR}/imputed_data/

# Iterate over ancestries
for ANCESTRY in "${ANCESTRIES[@]}"; do
    for chnum in {1..22};
        do
            plink \
            --bfile "$ANCESTRY"/PRS_chr"$chnum"_release6 \
            --update-sex ${WORK_DIR}/sex.txt \
            --remove ${WORK_DIR}/raw_genotypes/"$ANCESTRY"/related_"$ANCESTRY" \
            --make-bed \
            --out "$ANCESTRY"/PRS_chr"$chnum"_release6_gender
    done
done

# %%
# List of ancestries
ANCESTRIES=("AAC" "AFR" "AJ" "AMR" "EAS" "EUR" "CAS")

# Iterate over ancestries
for ANCESTRY in "${ANCESTRIES[@]}"; do
    # Change directory to the specified path
    cd ${WORK_DIR}/imputed_data/"$ANCESTRY"

    # List files matching the pattern and save to temp file
    ls *PRS*release6_gender.bim > temp

    # Print files for the current ancestry
    echo "Files for Ancestry $ANCESTRY:"
    cat temp

    # Go back to the original directory
    cd ${WORK_DIR}/imputed_data/
done
# Out:
# Files for Ancestry AAC:
# PRS_ALL_release6_gender.bim
# PRS_chr10_release6_gender.bim
# PRS_chr11_release6_gender.bim
# PRS_chr12_release6_gender.bim
# PRS_chr13_release6_gender.bim
# PRS_chr14_release6_gender.bim
# PRS_chr15_release6_gender.bim
# PRS_chr16_release6_gender.bim
# PRS_chr17_release6_gender.bim
# PRS_chr18_release6_gender.bim
# PRS_chr19_release6_gender.bim
# PRS_chr1_release6_gender.bim
# PRS_chr20_release6_gender.bim
# PRS_chr21_release6_gender.bim
# PRS_chr2_release6_gender.bim
# PRS_chr3_release6_gender.bim
# PRS_chr4_release6_gender.bim
# PRS_chr5_release6_gender.bim
# PRS_chr6_release6_gender.bim
# PRS_chr7_release6_gender.bim
# PRS_chr8_release6_gender.bim
# PRS_chr9_release6_gender.bim
# Files for Ancestry AFR:
# PRS_ALL_release6_gender.bim
# PRS_chr10_release6_gender.bim
# PRS_chr11_release6_gender.bim
# PRS_chr12_release6_gender.bim
# PRS_chr13_release6_gender.bim
# PRS_chr14_release6_gender.bim
# PRS_chr15_release6_gender.bim
# PRS_chr16_release6_gender.bim
# PRS_chr17_release6_gender.bim
# PRS_chr18_release6_gender.bim
# PRS_chr19_release6_gender.bim
# PRS_chr1_release6_gender.bim
# PRS_chr20_release6_gender.bim
# PRS_chr21_release6_gender.bim
# PRS_chr2_release6_gender.bim
# PRS_chr3_release6_gender.bim
# PRS_chr4_release6_gender.bim
# PRS_chr5_release6_gender.bim
# PRS_chr6_release6_gender.bim
# PRS_chr7_release6_gender.bim
# PRS_chr8_release6_gender.bim
# PRS_chr9_release6_gender.bim
# Files for Ancestry AJ:
# PRS_ALL_release6_gender.bim
# PRS_chr10_release6_gender.bim
# PRS_chr11_release6_gender.bim
# PRS_chr12_release6_gender.bim
# PRS_chr13_release6_gender.bim
# PRS_chr14_release6_gender.bim
# PRS_chr15_release6_gender.bim
# PRS_chr16_release6_gender.bim
# PRS_chr17_release6_gender.bim
# PRS_chr18_release6_gender.bim
# PRS_chr19_release6_gender.bim
# PRS_chr1_release6_gender.bim
# PRS_chr20_release6_gender.bim
# PRS_chr21_release6_gender.bim
# PRS_chr2_release6_gender.bim
# PRS_chr3_release6_gender.bim
# PRS_chr4_release6_gender.bim
# PRS_chr5_release6_gender.bim
# PRS_chr6_release6_gender.bim
# PRS_chr7_release6_gender.bim
# PRS_chr8_release6_gender.bim
# PRS_chr9_release6_gender.bim
# Files for Ancestry AMR:
# PRS_ALL_release6_gender.bim
# PRS_chr10_release6_gender.bim
# PRS_chr11_release6_gender.bim
# PRS_chr12_release6_gender.bim
# PRS_chr13_release6_gender.bim
# PRS_chr14_release6_gender.bim
# PRS_chr15_release6_gender.bim
# PRS_chr16_release6_gender.bim
# PRS_chr17_release6_gender.bim
# PRS_chr18_release6_gender.bim
# PRS_chr19_release6_gender.bim
# PRS_chr1_release6_gender.bim
# PRS_chr20_release6_gender.bim
# PRS_chr21_release6_gender.bim
# PRS_chr2_release6_gender.bim
# PRS_chr3_release6_gender.bim
# PRS_chr4_release6_gender.bim
# PRS_chr5_release6_gender.bim
# PRS_chr6_release6_gender.bim
# PRS_chr7_release6_gender.bim
# PRS_chr8_release6_gender.bim
# PRS_chr9_release6_gender.bim
# Files for Ancestry EAS:
# PRS_ALL_release6_gender.bim
# PRS_chr10_release6_gender.bim
# PRS_chr11_release6_gender.bim
# PRS_chr12_release6_gender.bim
# PRS_chr13_release6_gender.bim
# PRS_chr14_release6_gender.bim
# PRS_chr15_release6_gender.bim
# PRS_chr16_release6_gender.bim
# PRS_chr17_release6_gender.bim
# PRS_chr18_release6_gender.bim
# PRS_chr19_release6_gender.bim
# PRS_chr1_release6_gender.bim
# PRS_chr20_release6_gender.bim
# PRS_chr21_release6_gender.bim
# PRS_chr2_release6_gender.bim
# PRS_chr3_release6_gender.bim
# PRS_chr4_release6_gender.bim
# PRS_chr5_release6_gender.bim
# PRS_chr6_release6_gender.bim
# PRS_chr7_release6_gender.bim
# PRS_chr8_release6_gender.bim
# PRS_chr9_release6_gender.bim
# Files for Ancestry EUR:
# PRS_ALL_release6_gender.bim
# PRS_chr10_release6_gender.bim
# PRS_chr11_release6_gender.bim
# PRS_chr12_release6_gender.bim
# PRS_chr13_release6_gender.bim
# PRS_chr14_release6_gender.bim
# PRS_chr15_release6_gender.bim
# PRS_chr16_release6_gender.bim
# PRS_chr17_release6_gender.bim
# PRS_chr18_release6_gender.bim
# PRS_chr19_release6_gender.bim
# PRS_chr1_release6_gender.bim
# PRS_chr20_release6_gender.bim
# PRS_chr21_release6_gender.bim
# PRS_chr2_release6_gender.bim
# PRS_chr3_release6_gender.bim
# PRS_chr4_release6_gender.bim
# PRS_chr5_release6_gender.bim
# PRS_chr6_release6_gender.bim
# PRS_chr7_release6_gender.bim
# PRS_chr8_release6_gender.bim
# PRS_chr9_release6_gender.bim
# Files for Ancestry CAS:
# PRS_chr10_release6_gender.bim
# PRS_chr11_release6_gender.bim
# PRS_chr12_release6_gender.bim
# PRS_chr13_release6_gender.bim
# PRS_chr14_release6_gender.bim
# PRS_chr15_release6_gender.bim
# PRS_chr16_release6_gender.bim
# PRS_chr17_release6_gender.bim
# PRS_chr18_release6_gender.bim
# PRS_chr19_release6_gender.bim
# PRS_chr1_release6_gender.bim
# PRS_chr20_release6_gender.bim
# PRS_chr21_release6_gender.bim
# PRS_chr2_release6_gender.bim
# PRS_chr3_release6_gender.bim
# PRS_chr4_release6_gender.bim
# PRS_chr5_release6_gender.bim
# PRS_chr6_release6_gender.bim
# PRS_chr7_release6_gender.bim
# PRS_chr8_release6_gender.bim
# PRS_chr9_release6_gender.bim

# %%
# List of ancestries
ANCESTRIES=("AAC" "AFR" "AJ" "AMR" "EAS" "EUR" "CAS")

# Iterate over ancestries
for ANCESTRY in "${ANCESTRIES[@]}"; do

    # Remove the ".bim" extension from the file names and save to temp2
    cd ${WORK_DIR}/imputed_data/"$ANCESTRY"
    sed 's/.bim//g' temp > temp2 || { echo "Error: Sed command failed for $ANCESTRY"; exit 1; }
    
    # Exclude specific file(s) from temp2 and save to files.txt
    grep -v "PRS_chr1_release6_gender" temp2 > files.txt || { echo "Error: Grep command failed for $ANCESTRY"; exit 1; }
    echo "Final list of files:"
    cat files.txt

    # Return to the original directory
    cd ..
done
# Out:
# Final list of files:
# PRS_ALL_release6_gender
# PRS_chr10_release6_gender
# PRS_chr11_release6_gender
# PRS_chr12_release6_gender
# PRS_chr13_release6_gender
# PRS_chr14_release6_gender
# PRS_chr15_release6_gender
# PRS_chr16_release6_gender
# PRS_chr17_release6_gender
# PRS_chr18_release6_gender
# PRS_chr19_release6_gender
# PRS_chr20_release6_gender
# PRS_chr21_release6_gender
# PRS_chr2_release6_gender
# PRS_chr3_release6_gender
# PRS_chr4_release6_gender
# PRS_chr5_release6_gender
# PRS_chr6_release6_gender
# PRS_chr7_release6_gender
# PRS_chr8_release6_gender
# PRS_chr9_release6_gender
# Final list of files:
# PRS_ALL_release6_gender
# PRS_chr10_release6_gender
# PRS_chr11_release6_gender
# PRS_chr12_release6_gender
# PRS_chr13_release6_gender
# PRS_chr14_release6_gender
# PRS_chr15_release6_gender
# PRS_chr16_release6_gender
# PRS_chr17_release6_gender
# PRS_chr18_release6_gender
# PRS_chr19_release6_gender
# PRS_chr20_release6_gender
# PRS_chr21_release6_gender
# PRS_chr2_release6_gender
# PRS_chr3_release6_gender
# PRS_chr4_release6_gender
# PRS_chr5_release6_gender
# PRS_chr6_release6_gender
# PRS_chr7_release6_gender
# PRS_chr8_release6_gender
# PRS_chr9_release6_gender
# Final list of files:
# PRS_ALL_release6_gender
# PRS_chr10_release6_gender
# PRS_chr11_release6_gender
# PRS_chr12_release6_gender
# PRS_chr13_release6_gender
# PRS_chr14_release6_gender
# PRS_chr15_release6_gender
# PRS_chr16_release6_gender
# PRS_chr17_release6_gender
# PRS_chr18_release6_gender
# PRS_chr19_release6_gender
# PRS_chr20_release6_gender
# PRS_chr21_release6_gender
# PRS_chr2_release6_gender
# PRS_chr3_release6_gender
# PRS_chr4_release6_gender
# PRS_chr5_release6_gender
# PRS_chr6_release6_gender
# PRS_chr7_release6_gender
# PRS_chr8_release6_gender
# PRS_chr9_release6_gender
# Final list of files:
# PRS_ALL_release6_gender
# PRS_chr10_release6_gender
# PRS_chr11_release6_gender
# PRS_chr12_release6_gender
# PRS_chr13_release6_gender
# PRS_chr14_release6_gender
# PRS_chr15_release6_gender
# PRS_chr16_release6_gender
# PRS_chr17_release6_gender
# PRS_chr18_release6_gender
# PRS_chr19_release6_gender
# PRS_chr20_release6_gender
# PRS_chr21_release6_gender
# PRS_chr2_release6_gender
# PRS_chr3_release6_gender
# PRS_chr4_release6_gender
# PRS_chr5_release6_gender
# PRS_chr6_release6_gender
# PRS_chr7_release6_gender
# PRS_chr8_release6_gender
# PRS_chr9_release6_gender
# Final list of files:
# PRS_ALL_release6_gender
# PRS_chr10_release6_gender
# PRS_chr11_release6_gender
# PRS_chr12_release6_gender
# PRS_chr13_release6_gender
# PRS_chr14_release6_gender
# PRS_chr15_release6_gender
# PRS_chr16_release6_gender
# PRS_chr17_release6_gender
# PRS_chr18_release6_gender
# PRS_chr19_release6_gender
# PRS_chr20_release6_gender
# PRS_chr21_release6_gender
# PRS_chr2_release6_gender
# PRS_chr3_release6_gender
# PRS_chr4_release6_gender
# PRS_chr5_release6_gender
# PRS_chr6_release6_gender
# PRS_chr7_release6_gender
# PRS_chr8_release6_gender
# PRS_chr9_release6_gender
# Final list of files:
# PRS_ALL_release6_gender
# PRS_chr10_release6_gender
# PRS_chr11_release6_gender
# PRS_chr12_release6_gender
# PRS_chr13_release6_gender
# PRS_chr14_release6_gender
# PRS_chr15_release6_gender
# PRS_chr16_release6_gender
# PRS_chr17_release6_gender
# PRS_chr18_release6_gender
# PRS_chr19_release6_gender
# PRS_chr20_release6_gender
# PRS_chr21_release6_gender
# PRS_chr2_release6_gender
# PRS_chr3_release6_gender
# PRS_chr4_release6_gender
# PRS_chr5_release6_gender
# PRS_chr6_release6_gender
# PRS_chr7_release6_gender
# PRS_chr8_release6_gender
# PRS_chr9_release6_gender
# Final list of files:
# PRS_chr10_release6_gender
# PRS_chr11_release6_gender
# PRS_chr12_release6_gender
# PRS_chr13_release6_gender
# PRS_chr14_release6_gender
# PRS_chr15_release6_gender
# PRS_chr16_release6_gender
# PRS_chr17_release6_gender
# PRS_chr18_release6_gender
# PRS_chr19_release6_gender
# PRS_chr20_release6_gender
# PRS_chr21_release6_gender
# PRS_chr2_release6_gender
# PRS_chr3_release6_gender
# PRS_chr4_release6_gender
# PRS_chr5_release6_gender
# PRS_chr6_release6_gender
# PRS_chr7_release6_gender
# PRS_chr8_release6_gender
# PRS_chr9_release6_gender

# %% [markdown]
# ## Merge files

# %%
module load plink/1.9
# Out:
# [-] Unloading plink  1.9.0-beta4.4  on cn2458
# [+] Loading plink  1.9.0-beta4.4  on cn2458

# %%
## Merge list using chr 1 as your core input

# List of ancestries
ANCESTRIES=("AAC" "AFR" "AJ" "AMR" "EAS" "EUR" "CAS")

# Iterate over ancestries
for ANCESTRY in "${ANCESTRIES[@]}"; do
    # Execute plink command for each ancestry
    cd ${WORK_DIR}/imputed_data/"${ANCESTRY}"/
    plink \
    --bfile PRS_chr1_release6_gender \
    --merge-list "files.txt" \
    --make-bed \
    --out "PRS_ALL_release6_gender"
done

# %%
cd ${WORK_DIR}/imputed_data/

# List of ancestries
ANCESTRIES=("AAC" "AFR" "AJ" "AMR" "EAS" "EUR" "CAS")

# Iterate over ancestries
for ANCESTRY in "${ANCESTRIES[@]}"; do
    # Change directory to the specified ancestry
    cd "$ANCESTRY/"

    # Reformat the bim file and save to temp3
    awk '{print $1, $1":"$4, $3, $4, $5, $6}' PRS_ALL_release6_gender.bim > temp3

    # Display the first few lines of temp3
    echo "Reformatted file for Ancestry: $ANCESTRY"
    head temp3
    
    # Rename file
    mv temp3 PRS_ALL_release6_gender.bim

    # Return to the original directory
    cd -
done
# Out:
# Reformatted file for Ancestry: AAC
# 1 1:154925709 0 154925709 C G
# 1 1:155162560 0 155162560 A G
# 1 1:155235843 0 155235843 C T
# 1 1:161499264 0 161499264 G C
# 1 1:171750629 0 171750629 T C
# 1 1:205754444 0 205754444 T C
# 1 1:205768611 0 205768611 A G
# 1 1:226728377 0 226728377 C T
# 1 1:232528865 0 232528865 T C
# 2 2:17966582 0 17966582 T A
# /data/CARD_training/imputed_data
# Reformatted file for Ancestry: AFR
# 1 1:155162560 0 155162560 A G
# 1 1:155235843 0 155235843 C T
# 1 1:161499264 0 161499264 G C
# 1 1:171750629 0 171750629 T C
# 1 1:205754444 0 205754444 T C
# 1 1:205768611 0 205768611 A G
# 1 1:226728377 0 226728377 C T
# 1 1:232528865 0 232528865 T C
# 2 2:17966582 0 17966582 T A
# 2 2:95335195 0 95335195 A T
# /data/CARD_training/imputed_data
# Reformatted file for Ancestry: AJ
# 1 1:154925709 0 154925709 C G
# 1 1:155162560 0 155162560 A G
# 1 1:155235843 0 155235843 C T
# 1 1:161499264 0 161499264 C G
# 1 1:171750629 0 171750629 T C
# 1 1:205754444 0 205754444 C T
# 1 1:205754444 0 205754444 C T
# 1 1:205768611 0 205768611 A G
# 1 1:226728377 0 226728377 C T
# 1 1:232528865 0 232528865 T C
# /data/CARD_training/imputed_data
# Reformatted file for Ancestry: AMR
# 1 1:154925709 0 154925709 C G
# 1 1:154925709 0 154925709 C G
# 1 1:155162560 0 155162560 A G
# 1 1:155162560 0 155162560 A G
# 1 1:155235843 0 155235843 C T
# 1 1:155235843 0 155235843 C T
# 1 1:161499264 0 161499264 C G
# 1 1:161499264 0 161499264 C G
# 1 1:171750629 0 171750629 T C
# 1 1:171750629 0 171750629 T C
# /data/CARD_training/imputed_data
# Reformatted file for Ancestry: EAS
# 1 1:154925709 0 154925709 C G
# 1 1:161499264 0 161499264 C G
# 1 1:171750629 0 171750629 T C
# 1 1:205754444 0 205754444 C T
# 1 1:205754444 0 205754444 C T
# 1 1:205768611 0 205768611 G A
# 1 1:226728377 0 226728377 C T
# 1 1:232528865 0 232528865 T C
# 2 2:17966582 0 17966582 T A
# 2 2:95335195 0 95335195 A T
# /data/CARD_training/imputed_data
# Reformatted file for Ancestry: EUR
# 1 1:154925709 0 154925709 C G
# 1 1:155162560 0 155162560 A G
# 1 1:155235843 0 155235843 C T
# 1 1:161499264 0 161499264 C G
# 1 1:171750629 0 171750629 T C
# 1 1:205754444 0 205754444 T C
# 1 1:205768611 0 205768611 A G
# 1 1:226728377 0 226728377 C T
# 1 1:232528865 0 232528865 T C
# 2 2:17966582 0 17966582 T A
# /data/CARD_training/imputed_data
# Reformatted file for Ancestry: CAS
# 1 1:154925709 0 154925709 C G
# 1 1:155162560 0 155162560 A G
# 1 1:155235843 0 155235843 C T
# 1 1:161499264 0 161499264 C G
# 1 1:171750629 0 171750629 T C
# 1 1:205754444 0 205754444 C T
# 1 1:205754444 0 205754444 C T
# 1 1:205768611 0 205768611 A G
# 1 1:226728377 0 226728377 C T
# 1 1:232528865 0 232528865 T C
# /data/CARD_training/imputed_data

# %%
module load plink/2.0-alpha
# Out:
# [-] Unloading plink  1.9.0-beta4.4  on cn2458
# [+] Loading plink  2.0-alpha
#
# The following have been reloaded with a version change:
#   1) plink/1.9.0-beta4.4 => plink/2.0-alpha

# %%
cd ${WORK_DIR}/imputed_data/

# List of ancestries
ANCESTRIES=("AAC" "AFR" "AJ" "AMR" "EAS" "EUR" "CAS")

# Iterate over ancestries
for ANCESTRY in "${ANCESTRIES[@]}"; do
    plink2 \
    --bfile "$ANCESTRY"/PRS_ALL_release6_gender \
    --rm-dup force-first \
    --make-bed \
    --out "$ANCESTRY"/PRS_ALL_release6_gender_no_duplicates 
done
# Out:
# PLINK v2.00a3.1LM AVX2 Intel (19 May 2022)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to AAC/PRS_ALL_release6_gender_no_duplicates.log.
# Options in effect:
#   --bfile AAC/PRS_ALL_release6_gender
#   --make-bed
#   --out AAC/PRS_ALL_release6_gender_no_duplicates
#   --rm-dup force-first
#
# Start time: Mon Mar  4 16:12:51 2024
# 386344 MiB RAM detected; reserving 193172 MiB for main workspace.
# Using up to 72 threads (change this with --threads).
# 1073 samples (629 females, 444 males; 1073 founders) loaded from
# AAC/PRS_ALL_release6_gender.fam.
# 104 variants loaded from AAC/PRS_ALL_release6_gender.bim.
# 1 binary phenotype loaded (257 cases, 808 controls).
# --rm-dup: 14 duplicated IDs, 14 variants removed.
# Writing AAC/PRS_ALL_release6_gender_no_duplicates.fam ... done.
# Writing AAC/PRS_ALL_release6_gender_no_duplicates.bim ... done.
# Writing AAC/PRS_ALL_release6_gender_no_duplicates.bed ... done.
# End time: Mon Mar  4 16:12:51 2024
# PLINK v2.00a3.1LM AVX2 Intel (19 May 2022)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to AFR/PRS_ALL_release6_gender_no_duplicates.log.
# Options in effect:
#   --bfile AFR/PRS_ALL_release6_gender
#   --make-bed
#   --out AFR/PRS_ALL_release6_gender_no_duplicates
#   --rm-dup force-first
#
# Start time: Mon Mar  4 16:12:51 2024
# 386344 MiB RAM detected; reserving 193172 MiB for main workspace.
# Using up to 72 threads (change this with --threads).
# 2617 samples (1156 females, 1461 males; 2617 founders) loaded from
# AFR/PRS_ALL_release6_gender.fam.
# 98 variants loaded from AFR/PRS_ALL_release6_gender.bim.
# 1 binary phenotype loaded (920 cases, 1683 controls).
# --rm-dup: 10 duplicated IDs, 10 variants removed.
# Writing AFR/PRS_ALL_release6_gender_no_duplicates.fam ... done.
# Writing AFR/PRS_ALL_release6_gender_no_duplicates.bim ... done.
# Writing AFR/PRS_ALL_release6_gender_no_duplicates.bed ... done.
# End time: Mon Mar  4 16:12:51 2024
# PLINK v2.00a3.1LM AVX2 Intel (19 May 2022)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to AJ/PRS_ALL_release6_gender_no_duplicates.log.
# Options in effect:
#   --bfile AJ/PRS_ALL_release6_gender
#   --make-bed
#   --out AJ/PRS_ALL_release6_gender_no_duplicates
#   --rm-dup force-first
#
# Start time: Mon Mar  4 16:12:51 2024
# 386344 MiB RAM detected; reserving 193172 MiB for main workspace.
# Using up to 72 threads (change this with --threads).
# 2242 samples (870 females, 1372 males; 2242 founders) loaded from
# AJ/PRS_ALL_release6_gender.fam.
# 108 variants loaded from AJ/PRS_ALL_release6_gender.bim.
# 1 binary phenotype loaded (1011 cases, 459 controls).
# --rm-dup: 18 duplicated IDs, 18 variants removed.
# Writing AJ/PRS_ALL_release6_gender_no_duplicates.fam ... done.
# Writing AJ/PRS_ALL_release6_gender_no_duplicates.bim ... done.
# Writing AJ/PRS_ALL_release6_gender_no_duplicates.bed ... done.
# End time: Mon Mar  4 16:12:51 2024
# PLINK v2.00a3.1LM AVX2 Intel (19 May 2022)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to AMR/PRS_ALL_release6_gender_no_duplicates.log.
# Options in effect:
#   --bfile AMR/PRS_ALL_release6_gender
#   --make-bed
#   --out AMR/PRS_ALL_release6_gender_no_duplicates
#   --rm-dup force-first
#
# Start time: Mon Mar  4 16:12:51 2024
# 386344 MiB RAM detected; reserving 193172 MiB for main workspace.
# Using up to 72 threads (change this with --threads).
# 529 samples (241 females, 288 males; 529 founders) loaded from
# AMR/PRS_ALL_release6_gender.fam.
# 193 variants loaded from AMR/PRS_ALL_release6_gender.bim.
# 1 binary phenotype loaded (367 cases, 139 controls).
# --rm-dup: 90 duplicated IDs, 103 variants removed.
# Writing AMR/PRS_ALL_release6_gender_no_duplicates.fam ... done.
# Writing AMR/PRS_ALL_release6_gender_no_duplicates.bim ... done.
# Writing AMR/PRS_ALL_release6_gender_no_duplicates.bed ... done.
# End time: Mon Mar  4 16:12:51 2024
# PLINK v2.00a3.1LM AVX2 Intel (19 May 2022)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to EAS/PRS_ALL_release6_gender_no_duplicates.log.
# Options in effect:
#   --bfile EAS/PRS_ALL_release6_gender
#   --make-bed
#   --out EAS/PRS_ALL_release6_gender_no_duplicates
#   --rm-dup force-first
#
# Start time: Mon Mar  4 16:12:51 2024
# 386344 MiB RAM detected; reserving 193172 MiB for main workspace.
# Using up to 72 threads (change this with --threads).
# 3992 samples (1380 females, 2612 males; 3992 founders) loaded from
# EAS/PRS_ALL_release6_gender.fam.
# 93 variants loaded from EAS/PRS_ALL_release6_gender.bim.
# 1 binary phenotype loaded (1577 cases, 2378 controls).
# --rm-dup: 8 duplicated IDs, 8 variants removed.
# Writing EAS/PRS_ALL_release6_gender_no_duplicates.fam ... done.
# Writing EAS/PRS_ALL_release6_gender_no_duplicates.bim ... done.
# Writing EAS/PRS_ALL_release6_gender_no_duplicates.bed ... done.
# End time: Mon Mar  4 16:12:51 2024
# PLINK v2.00a3.1LM AVX2 Intel (19 May 2022)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to EUR/PRS_ALL_release6_gender_no_duplicates.log.
# Options in effect:
#   --bfile EUR/PRS_ALL_release6_gender
#   --make-bed
#   --out EUR/PRS_ALL_release6_gender_no_duplicates
#   --rm-dup force-first
#
# Start time: Mon Mar  4 16:12:51 2024
# 386344 MiB RAM detected; reserving 193172 MiB for main workspace.
# Using up to 72 threads (change this with --threads).
# 20965 samples (8226 females, 12739 males; 20965 founders) loaded from
# EUR/PRS_ALL_release6_gender.fam.
# 96 variants loaded from EUR/PRS_ALL_release6_gender.bim.
# 1 binary phenotype loaded (11841 cases, 7596 controls).
# --rm-dup: 6 duplicated IDs, 6 variants removed.
# Writing EUR/PRS_ALL_release6_gender_no_duplicates.fam ... done.
# Writing EUR/PRS_ALL_release6_gender_no_duplicates.bim ... done.
# Writing EUR/PRS_ALL_release6_gender_no_duplicates.bed ... done.
# End time: Mon Mar  4 16:12:51 2024
# PLINK v2.00a3.1LM AVX2 Intel (19 May 2022)     www.cog-genomics.org/plink/2.0/
# (C) 2005-2022 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to CAS/PRS_ALL_release6_gender_no_duplicates.log.
# Options in effect:
#   --bfile CAS/PRS_ALL_release6_gender
#   --make-bed
#   --out CAS/PRS_ALL_release6_gender_no_duplicates
#   --rm-dup force-first
#
# Start time: Mon Mar  4 16:12:51 2024
# 386344 MiB RAM detected; reserving 193172 MiB for main workspace.
# Using up to 72 threads (change this with --threads).
# 585 samples (286 females, 299 males; 585 founders) loaded from
# CAS/PRS_ALL_release6_gender.fam.
# 104 variants loaded from CAS/PRS_ALL_release6_gender.bim.
# 1 binary phenotype loaded (286 cases, 294 controls).
# --rm-dup: 14 duplicated IDs, 14 variants removed.
# Writing CAS/PRS_ALL_release6_gender_no_duplicates.fam ... done.
# Writing CAS/PRS_ALL_release6_gender_no_duplicates.bim ... done.
# Writing CAS/PRS_ALL_release6_gender_no_duplicates.bed ... done.
# End time: Mon Mar  4 16:12:51 2024

# %% [markdown]
# ## Estimate profiles

# %%
module load plink/1.9
# Out:
# [-] Unloading plink  2.0-alpha
# [+] Loading plink  1.9.0-beta4.4  on cn2458
#
# The following have been reloaded with a version change:
#   1) plink/2.0-alpha => plink/1.9.0-beta4.4

# %%
# List of ancestries
ANCESTRIES=("AAC" "AFR" "AJ" "AMR" "EAS" "EUR" "CAS")

# Iterate over ancestries
for ANCESTRY in "${ANCESTRIES[@]}"; do
    # Change directory to the specified ancestry
 
    # Calculate scores using plink
    plink \
    --bfile "$ANCESTRY/"PRS_ALL_release6_gender_no_duplicates \
    --score ${WORK_DIR}/90LOCI_AFRICAN_CHR_POS.txt \
    --out "$ANCESTRY/"PRS_score_release_AFRICANS

    # Return to the original directory
    cd /data/CARD_training/imputed_data/
done
# Out:
# PLINK v1.90b4.4 64-bit (21 May 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to AAC/PRS_score_release_AFRICANS.log.
# Options in effect:
#   --bfile AAC/PRS_ALL_release6_gender_no_duplicates
#   --out AAC/PRS_score_release_AFRICANS
#   --score /data/GP2/projects/PRS_multi_ancestry_Nov2023/90LOCI_AFRICAN_CHR_POS.txt
#
# 386344 MB RAM detected; reserving 193172 MB for main workspace.
# 90 variants loaded from .bim file.
# 1073 people (444 males, 629 females) loaded from .fam.
# 1065 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 1073 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.9895.
# 90 variants and 1073 people pass filters and QC.
# Among remaining phenotypes, 257 are cases and 808 are controls.  (8 phenotypes
# are missing.)
# --score: 84 valid predictors loaded.
# --score: Results written to AAC/PRS_score_release_AFRICANS.profile .
# PLINK v1.90b4.4 64-bit (21 May 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to AFR/PRS_score_release_AFRICANS.log.
# Options in effect:
#   --bfile AFR/PRS_ALL_release6_gender_no_duplicates
#   --out AFR/PRS_score_release_AFRICANS
#   --score /data/GP2/projects/PRS_multi_ancestry_Nov2023/90LOCI_AFRICAN_CHR_POS.txt
#
# 386344 MB RAM detected; reserving 193172 MB for main workspace.
# 88 variants loaded from .bim file.
# 2617 people (1461 males, 1156 females) loaded from .fam.
# 2603 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2617 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.979921.
# 88 variants and 2617 people pass filters and QC.
# Among remaining phenotypes, 920 are cases and 1683 are controls.  (14
# phenotypes are missing.)
# Warning: 1 line skipped in --score file (1 due to variant ID mismatch, 0 due to
# allele code mismatch); see AFR/PRS_score_release_AFRICANS.nopred for details.
# --score: 83 valid predictors loaded.
# --score: Results written to AFR/PRS_score_release_AFRICANS.profile .
# PLINK v1.90b4.4 64-bit (21 May 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to AJ/PRS_score_release_AFRICANS.log.
# Options in effect:
#   --bfile AJ/PRS_ALL_release6_gender_no_duplicates
#   --out AJ/PRS_score_release_AFRICANS
#   --score /data/GP2/projects/PRS_multi_ancestry_Nov2023/90LOCI_AFRICAN_CHR_POS.txt
#
# 386344 MB RAM detected; reserving 193172 MB for main workspace.
# 90 variants loaded from .bim file.
# 2242 people (1372 males, 870 females) loaded from .fam.
# 1470 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2242 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.992085.
# 90 variants and 2242 people pass filters and QC.
# Among remaining phenotypes, 1011 are cases and 459 are controls.  (772
# phenotypes are missing.)
# Warning: 1 line skipped in --score file (0 due to variant ID mismatch, 1 due to
# allele code mismatch); see AJ/PRS_score_release_AFRICANS.nopred for details.
# --score: 83 valid predictors loaded.
# --score: Results written to AJ/PRS_score_release_AFRICANS.profile .
# PLINK v1.90b4.4 64-bit (21 May 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to AMR/PRS_score_release_AFRICANS.log.
# Options in effect:
#   --bfile AMR/PRS_ALL_release6_gender_no_duplicates
#   --out AMR/PRS_score_release_AFRICANS
#   --score /data/GP2/projects/PRS_multi_ancestry_Nov2023/90LOCI_AFRICAN_CHR_POS.txt
#
# 386344 MB RAM detected; reserving 193172 MB for main workspace.
# 90 variants loaded from .bim file.
# 529 people (288 males, 241 females) loaded from .fam.
# 506 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 529 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.99017.
# 90 variants and 529 people pass filters and QC.
# Among remaining phenotypes, 367 are cases and 139 are controls.  (23 phenotypes
# are missing.)
# --score: 84 valid predictors loaded.
# --score: Results written to AMR/PRS_score_release_AFRICANS.profile .
# PLINK v1.90b4.4 64-bit (21 May 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to EAS/PRS_score_release_AFRICANS.log.
# Options in effect:
#   --bfile EAS/PRS_ALL_release6_gender_no_duplicates
#   --out EAS/PRS_score_release_AFRICANS
#   --score /data/GP2/projects/PRS_multi_ancestry_Nov2023/90LOCI_AFRICAN_CHR_POS.txt
#
# 386344 MB RAM detected; reserving 193172 MB for main workspace.
# 85 variants loaded from .bim file.
# 3992 people (2612 males, 1380 females) loaded from .fam.
# 3955 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 3992 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.931831.
# 85 variants and 3992 people pass filters and QC.
# Among remaining phenotypes, 1577 are cases and 2378 are controls.  (37
# phenotypes are missing.)
# Warning: 4 lines skipped in --score file (3 due to variant ID mismatch, 1 due
# to allele code mismatch); see EAS/PRS_score_release_AFRICANS.nopred for
# details.
# --score: 80 valid predictors loaded.
# --score: Results written to EAS/PRS_score_release_AFRICANS.profile .
# PLINK v1.90b4.4 64-bit (21 May 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to EUR/PRS_score_release_AFRICANS.log.
# Options in effect:
#   --bfile EUR/PRS_ALL_release6_gender_no_duplicates
#   --out EUR/PRS_score_release_AFRICANS
#   --score /data/GP2/projects/PRS_multi_ancestry_Nov2023/90LOCI_AFRICAN_CHR_POS.txt
#
# 386344 MB RAM detected; reserving 193172 MB for main workspace.
# 90 variants loaded from .bim file.
# 20965 people (12739 males, 8226 females) loaded from .fam.
# 19437 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 20965 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.953846.
# 90 variants and 20965 people pass filters and QC.
# Among remaining phenotypes, 11841 are cases and 7596 are controls.  (1528
# phenotypes are missing.)
# --score: 84 valid predictors loaded.
# --score: Results written to EUR/PRS_score_release_AFRICANS.profile .
# PLINK v1.90b4.4 64-bit (21 May 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to CAS/PRS_score_release_AFRICANS.log.
# Options in effect:
#   --bfile CAS/PRS_ALL_release6_gender_no_duplicates
#   --out CAS/PRS_score_release_AFRICANS
#   --score /data/GP2/projects/PRS_multi_ancestry_Nov2023/90LOCI_AFRICAN_CHR_POS.txt
#
# 386344 MB RAM detected; reserving 193172 MB for main workspace.
# 90 variants loaded from .bim file.
# 585 people (299 males, 286 females) loaded from .fam.
# 580 phenotype values loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 585 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.972175.
# 90 variants and 585 people pass filters and QC.
# Among remaining phenotypes, 286 are cases and 294 are controls.  (5 phenotypes
# are missing.)
# --score: 84 valid predictors loaded.
# --score: Results written to CAS/PRS_score_release_AFRICANS.profile .

# %%
# List of ancestries
ANCESTRIES=("AAC" "AFR" "AJ" "AMR" "EAS" "EUR" "CAS")

# Iterate over ancestries
for ANCESTRY in "${ANCESTRIES[@]}"; do
    plink \
    --bfile "$ANCESTRY/"PRS_ALL_release6_gender_no_duplicates \
    --score ${WORK_DIR}/META_FOO_23ANDME_90LOCI_EASTASIAN_CHR_POS.txt \
    --out "$ANCESTRY/"PRS_score_release_EASTASIANS

    # Return to the original directory
    cd -
done

# %%
# List of ancestries
ANCESTRIES=("AAC" "AFR" "AJ" "AMR" "EAS" "EUR" "CAS")

# Iterate over ancestries
for ANCESTRY in "${ANCESTRIES[@]}"; do
    plink \
    --bfile "$ANCESTRY/"PRS_ALL_release6_gender_no_duplicates \
    --score ${WORK_DIR}/META_LOESCH_23ANDME_90LOCI_LATINO_CHR_POS.txt \
    --out "$ANCESTRY/"PRS_score_release_LATINO

    # Return to the original directory
    cd /data/CARD_training/imputed_data
done

# %%
# List of ancestries
ANCESTRIES=("AAC" "AFR" "AJ" "AMR" "EAS" "EUR" "CAS")

# Iterate over ancestries
for ANCESTRY in "${ANCESTRIES[@]}"; do
    plink \
    --bfile "$ANCESTRY/"PRS_ALL_release6_gender_no_duplicates \
    --score ${WORK_DIR}/90LOCI_EUROPEANS_CHR_POS.txt \
    --out "$ANCESTRY/"PRS_score_release_EUROPEAN

    # Return to the original directory
    cd /data/CARD_training/imputed_data
done
