# %% [markdown]
# # Data visualizations
# - **Project:** Multi-ancestry PRS
# - **Version:** Python/3.9
# - **Status:** COMPLETE
# - **Last Updated:** 26-MARCH-2024
#
# ## Notebook Overview
# - Density plots

# %%
## Load packages
module load python
module load R
# Out:
# [+] Loading python 3.10  ...
# [+] Loading gcc  11.3.0  ...
# [+] Loading HDF5  1.12.2
# [+] Loading netcdf  4.9.0
# [-] Unloading gcc  11.3.0  ...
# [+] Loading gcc  11.3.0  ...
# [+] Loading openmpi/4.1.3/gcc-11.3.0  ...
# [+] Loading pandoc  2.18  on cn2458
# [+] Loading pcre2  10.40
# [+] Loading R 4.3.2

# %%
cd ${WORK_DIR}/imputed_data/AAC
mkdir density

library(data.table)
library("ggplot2")
data <- read.table("PRS_score_release_AFRICANS.profile", header = T) 
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)

## Probability of disease calculation
Model <- glm(CASE ~ SCORE, data = dat, family = 'binomial')
dat$probDisease <- predict(Model, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")

AFR_dat <- dat
AFR_dat$Group <- "AFR"

## --------------
library(data.table)
library("ggplot2")
data <- read.table("PRS_score_release_EUROPEAN.profile", header = T) 
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)

## Probability of disease calculation
Model <- glm(CASE ~ SCORE, data = dat, family = 'binomial')
dat$probDisease <- predict(Model, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")

EUR_dat <- dat
EUR_dat$Group <- "EUR"

## --------------
library(data.table)
library("ggplot2")
data <- read.table("PRS_score_release_LATINO.profile", header = T) 
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)

## Probability of disease calculation
Model <- glm(CASE ~ SCORE, data = dat, family = 'binomial')
dat$probDisease <- predict(Model, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")

LAT_dat <- dat
LAT_dat$Group <- "LAT"

## --------------
library(data.table)
library("ggplot2")
data <- read.table("PRS_score_release_EASTASIANS.profile", header = T) 
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)

## Probability of disease calculation
Model <- glm(CASE ~ SCORE, data = dat, family = 'binomial')
dat$probDisease <- predict(Model, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")

EAS_dat <- dat
EAS_dat$Group <- "EAS"

### density plot
to_plot = rbind(AFR_dat, EUR_dat, LAT_dat, EAS_dat)
to_plot_cases <- subset(to_plot, CASE == 1)
density_rocs_plot <- ggplot(to_plot_cases, aes(probDisease, color=Group)) + geom_density(alpha = 0.5) + theme_bw()
ggsave(plot = density_rocs_plot, filename = "{WORK_DIR}/imputed_data/AAC/AAC_density_joint.png", width = 8, height = 5, units = "in", dpi = 300)

# %%
###################################### AFR ###################################### 

cd ${WORK_DIR}/imputed_data/AFR
mkdir density

library(data.table)
library("ggplot2")
data <- read.table("PRS_score_release_AFRICANS.profile", header = T) 
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)

## Probability of disease calculation
Model <- glm(CASE ~ SCORE, data = dat, family = 'binomial')
dat$probDisease <- predict(Model, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")

AFR_dat <- dat
AFR_dat$Group <- "AFR"

## --------------
library(data.table)
library("ggplot2")
data <- read.table("PRS_score_release_EUROPEAN.profile", header = T) 
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)

## Probability of disease calculation
Model <- glm(CASE ~ SCORE, data = dat, family = 'binomial')
dat$probDisease <- predict(Model, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")

EUR_dat <- dat
EUR_dat$Group <- "EUR"

## --------------
library(data.table)
library("ggplot2")
data <- read.table("PRS_score_release_LATINO.profile", header = T) 
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)

## Probability of disease calculation
Model <- glm(CASE ~ SCORE, data = dat, family = 'binomial')
dat$probDisease <- predict(Model, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")

LAT_dat <- dat
LAT_dat$Group <- "LAT"

## --------------
library(data.table)
library("ggplot2")
data <- read.table("PRS_score_release_EASTASIANS.profile", header = T) 
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)

## Probability of disease calculation
Model <- glm(CASE ~ SCORE, data = dat, family = 'binomial')
dat$probDisease <- predict(Model, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")

EAS_dat <- dat
EAS_dat$Group <- "EAS"

### density plot
to_plot = rbind(AFR_dat, EUR_dat, LAT_dat, EAS_dat)
to_plot_cases <- subset(to_plot, CASE == 1)
density_rocs_plot <- ggplot(to_plot_cases, aes(probDisease, color=Group)) + geom_density(alpha = 0.5) + theme_bw()
ggsave(plot = density_rocs_plot, filename = "{WORK_DIR}/imputed_data/AFR/AFR_density_joint.png", width = 8, height = 5, units = "in", dpi = 300)
# Out:
# >

# %%
###################################### AJ ###################################### 

cd ${WORK_DIR}/imputed_data/AJ
mkdir density

library(data.table)
library("ggplot2")
data <- read.table("PRS_score_release_AFRICANS.profile", header = T) 
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)

## Probability of disease calculation
Model <- glm(CASE ~ SCORE, data = dat, family = 'binomial')
dat$probDisease <- predict(Model, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")

AFR_dat <- dat
AFR_dat$Group <- "AFR"

## --------------
library(data.table)
library("ggplot2")
data <- read.table("PRS_score_release_EUROPEAN.profile", header = T) 
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)

## Probability of disease calculation
Model <- glm(CASE ~ SCORE, data = dat, family = 'binomial')
dat$probDisease <- predict(Model, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")

EUR_dat <- dat
EUR_dat$Group <- "EUR"

## --------------
library(data.table)
library("ggplot2")
data <- read.table("PRS_score_release_LATINO.profile", header = T) 
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)

## Probability of disease calculation
Model <- glm(CASE ~ SCORE, data = dat, family = 'binomial')
dat$probDisease <- predict(Model, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")

LAT_dat <- dat
LAT_dat$Group <- "LAT"

## --------------
library(data.table)
library("ggplot2")
data <- read.table("PRS_score_release_EASTASIANS.profile", header = T) 
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)

## Probability of disease calculation
Model <- glm(CASE ~ SCORE, data = dat, family = 'binomial')
dat$probDisease <- predict(Model, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")

EAS_dat <- dat
EAS_dat$Group <- "EAS"

### density plot
to_plot = rbind(AFR_dat, EUR_dat, LAT_dat, EAS_dat)
to_plot_cases <- subset(to_plot, CASE == 1)
density_rocs_plot <- ggplot(to_plot_cases, aes(probDisease, color=Group)) + geom_density(alpha = 0.5) + theme_bw()
ggsave(plot = density_rocs_plot, filename = "{WORK_DIR}/imputed_data/AJ/AJ_density_joint.png", width = 8, height = 5, units = "in", dpi = 300)

# %%
###################################### AMR ###################################### 

cd ${WORK_DIR}/imputed_data/AMR
mkdir density

library(data.table)
library("ggplot2")
data <- read.table("PRS_score_release_AFRICANS.profile", header = T) 
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)

## Probability of disease calculation
Model <- glm(CASE ~ SCORE, data = dat, family = 'binomial')
dat$probDisease <- predict(Model, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")

AFR_dat <- dat
AFR_dat$Group <- "AFR"

## --------------
library(data.table)
library("ggplot2")
data <- read.table("PRS_score_release_EUROPEAN.profile", header = T) 
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)

## Probability of disease calculation
Model <- glm(CASE ~ SCORE, data = dat, family = 'binomial')
dat$probDisease <- predict(Model, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")

EUR_dat <- dat
EUR_dat$Group <- "EUR"

## --------------
library(data.table)
library("ggplot2")
data <- read.table("PRS_score_release_LATINO.profile", header = T) 
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)

## Probability of disease calculation
Model <- glm(CASE ~ SCORE, data = dat, family = 'binomial')
dat$probDisease <- predict(Model, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")

LAT_dat <- dat
LAT_dat$Group <- "LAT"

## --------------
library(data.table)
library("ggplot2")
data <- read.table("PRS_score_release_EASTASIANS.profile", header = T) 
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)

## Probability of disease calculation
Model <- glm(CASE ~ SCORE, data = dat, family = 'binomial')
dat$probDisease <- predict(Model, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")

EAS_dat <- dat
EAS_dat$Group <- "EAS"

### density plot
to_plot = rbind(AFR_dat, EUR_dat, LAT_dat, EAS_dat)
to_plot_cases <- subset(to_plot, CASE == 1)
density_rocs_plot <- ggplot(to_plot_cases, aes(probDisease, color=Group)) + geom_density(alpha = 0.5) + theme_bw()
ggsave(plot = density_rocs_plot, filename = "{WORK_DIR}/imputed_data/AMR/AMR_density_joint.png", width = 8, height = 5, units = "in", dpi = 300)

# %%
###################################### CAS ###################################### 

cd ${WORK_DIR}/imputed_data/CAS
mkdir density

library(data.table)
library("ggplot2")
data <- read.table("PRS_score_release_AFRICANS.profile", header = T) 
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)

## Probability of disease calculation
Model <- glm(CASE ~ SCORE, data = dat, family = 'binomial')
dat$probDisease <- predict(Model, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")

AFR_dat <- dat
AFR_dat$Group <- "AFR"

## --------------
library(data.table)
library("ggplot2")
data <- read.table("PRS_score_release_EUROPEAN.profile", header = T) 
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)

## Probability of disease calculation
Model <- glm(CASE ~ SCORE, data = dat, family = 'binomial')
dat$probDisease <- predict(Model, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")

EUR_dat <- dat
EUR_dat$Group <- "EUR"

## --------------
library(data.table)
library("ggplot2")
data <- read.table("PRS_score_release_LATINO.profile", header = T) 
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)

## Probability of disease calculation
Model <- glm(CASE ~ SCORE, data = dat, family = 'binomial')
dat$probDisease <- predict(Model, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")

LAT_dat <- dat
LAT_dat$Group <- "LAT"

## --------------
library(data.table)
library("ggplot2")
data <- read.table("PRS_score_release_EASTASIANS.profile", header = T) 
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)

## Probability of disease calculation
Model <- glm(CASE ~ SCORE, data = dat, family = 'binomial')
dat$probDisease <- predict(Model, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")

EAS_dat <- dat
EAS_dat$Group <- "EAS"

### density plot
to_plot = rbind(AFR_dat, EUR_dat, LAT_dat, EAS_dat)
to_plot_cases <- subset(to_plot, CASE == 1)
density_rocs_plot <- ggplot(to_plot_cases, aes(probDisease, color=Group)) + geom_density(alpha = 0.5) + theme_bw()
ggsave(plot = density_rocs_plot, filename = "{WORK_DIR}/imputed_data/CAS/CAS_density_joint.png", width = 8, height = 5, units = "in", dpi = 300)

# %%
###################################### EAS ###################################### 

cd ${WORK_DIR}/imputed_data/EAS
mkdir density

library(data.table)
library("ggplot2")
data <- read.table("PRS_score_release_AFRICANS.profile", header = T) 
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)

## Probability of disease calculation
Model <- glm(CASE ~ SCORE, data = dat, family = 'binomial')
dat$probDisease <- predict(Model, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")

AFR_dat <- dat
AFR_dat$Group <- "AFR"

## --------------
library(data.table)
library("ggplot2")
data <- read.table("PRS_score_release_EUROPEAN.profile", header = T) 
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)

## Probability of disease calculation
Model <- glm(CASE ~ SCORE, data = dat, family = 'binomial')
dat$probDisease <- predict(Model, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")

EUR_dat <- dat
EUR_dat$Group <- "EUR"

## --------------
library(data.table)
library("ggplot2")
data <- read.table("PRS_score_release_LATINO.profile", header = T) 
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)

## Probability of disease calculation
Model <- glm(CASE ~ SCORE, data = dat, family = 'binomial')
dat$probDisease <- predict(Model, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")

LAT_dat <- dat
LAT_dat$Group <- "LAT"

## --------------
library(data.table)
library("ggplot2")
data <- read.table("PRS_score_release_EASTASIANS.profile", header = T) 
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)

## Probability of disease calculation
Model <- glm(CASE ~ SCORE, data = dat, family = 'binomial')
dat$probDisease <- predict(Model, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")

EAS_dat <- dat
EAS_dat$Group <- "EAS"

### density plot
to_plot = rbind(AFR_dat, EUR_dat, LAT_dat, EAS_dat)
to_plot_cases <- subset(to_plot, CASE == 1)
density_rocs_plot <- ggplot(to_plot_cases, aes(probDisease, color=Group)) + geom_density(alpha = 0.5) + theme_bw()
ggsave(plot = density_rocs_plot, filename = "{WORK_DIR}/imputed_data/EAS/EAS_density_joint.png", width = 8, height = 5, units = "in", dpi = 300)

# %%
###################################### EUR ###################################### 

cd ${WORK_DIR}/imputed_data/EUR
mkdir density

library(data.table)
library("ggplot2")
data <- read.table("PRS_score_release_AFRICANS.profile", header = T) 
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)

## Probability of disease calculation
Model <- glm(CASE ~ SCORE, data = dat, family = 'binomial')
dat$probDisease <- predict(Model, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")

AFR_dat <- dat
AFR_dat$Group <- "AFR"

## --------------
library(data.table)
library("ggplot2")
data <- read.table("PRS_score_release_EUROPEAN.profile", header = T) 
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)

## Probability of disease calculation
Model <- glm(CASE ~ SCORE, data = dat, family = 'binomial')
dat$probDisease <- predict(Model, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")

EUR_dat <- dat
EUR_dat$Group <- "EUR"

## --------------
library(data.table)
library("ggplot2")
data <- read.table("PRS_score_release_LATINO.profile", header = T) 
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)

## Probability of disease calculation
Model <- glm(CASE ~ SCORE, data = dat, family = 'binomial')
dat$probDisease <- predict(Model, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")

LAT_dat <- dat
LAT_dat$Group <- "LAT"

## --------------
library(data.table)
library("ggplot2")
data <- read.table("PRS_score_release_EASTASIANS.profile", header = T) 
data$CASE <- data$PHENO - 1
dat <- subset(data, CASE != -10)

## Probability of disease calculation
Model <- glm(CASE ~ SCORE, data = dat, family = 'binomial')
dat$probDisease <- predict(Model, dat, type = c("response"))
dat$predicted <- ifelse(dat$probDisease > 0.5, "DISEASE", "CONTROL")
dat$reported <- ifelse(dat$CASE == 1, "DISEASE","CONTROL")

EAS_dat <- dat
EAS_dat$Group <- "EAS"

### density plot
to_plot = rbind(AFR_dat, EUR_dat, LAT_dat, EAS_dat)
to_plot_cases <- subset(to_plot, CASE == 1)
density_rocs_plot <- ggplot(to_plot_cases, aes(probDisease, color=Group)) + geom_density(alpha = 0.5) + theme_bw()
ggsave(plot = density_rocs_plot, filename = "{WORK_DIR}/imputed_data/EUR/EUR_density_joint.png", width = 8, height = 5, units = "in", dpi = 300)
