# %% [markdown]
# # Estimate Multi-ancestry PRS versus PD risk with admixure
# - **Project:** Multi-ancestry PRS
# - **Version:** Python/3.9
# - **Status:** COMPLETE
# - **Last Updated:** 11-MARCH-2024
#
# ## Notebook Overview
# - Logistic regression models adjusted by covariates (age, gender, admixture)

# %%
## Load packages
module load python
module load R
# Out:
# [+] Loading python 3.10  ...
# [+] Loading gcc  11.3.0  ...
# [+] Loading HDF5  1.12.2
# [+] Loading netcdf  4.9.0
# [-] Unloading gcc  11.3.0  ...
# [+] Loading gcc  11.3.0  ...
# [+] Loading openmpi/4.1.3/gcc-11.3.0  ...
# [+] Loading pandoc  2.18  on cn0978
# [+] Loading pcre2  10.40
# [+] Loading R 4.3.2

# %%
import pandas as pd
import statsmodels.api as sm

## RUN PRS versus RISK across ancestries (AFRICAN summary stats)
# List of ancestries
ancestries = ["AAC", "AFR", "AJ", "AMR", "EAS", "EUR", "CAS"]

for ancestry in ancestries:  
    print("Ancestry:", ancestry)
    # Construct file paths
    prs_file = f"{WORK_DIR}/imputed_data/" + ancestry + "/PRS_score_release_AFRICANS.profile"

    # Read PRS data
    temp_data = pd.read_csv(prs_file, delim_whitespace =True)

    # Read admx data
    temp_covs = pd.read_csv(f"{WORK_DIR}/projects/ref_panel_prep/gp2_admixture/GP2_round6/release6_ancestry_merge_train.10.Q.labeled", delim_whitespace =True)

    # Read additional covariates
    temp_covs_2 = pd.read_csv(f"{WORK_DIR}/covariates.txt", sep="\t")
    temp_covs_2 = temp_covs_2.rename(columns={"GP2sampleID": "IID"})

    # Merge covariates
    covs = pd.merge(temp_covs, temp_covs_2, on="IID")
    covs.head()

    # Merge PRS data and covariates
    dat = pd.merge(temp_data, covs, on="IID")

    # Remove missing or unknown cases
    dat = dat[dat["PHENO"] != -9]

    # Logistic regression model phenotype
    dat['CASE'] = dat['PHENO'] - 1 

    # Standardize PRS
    mean_controls = dat.loc[dat["CASE"] == 0, "SCORE"].mean()
    sd_controls = dat.loc[dat["CASE"] == 0, "SCORE"].std()
    dat["zSCORE"] = (dat["SCORE"] - mean_controls) / sd_controls

    # Logistic regression model using statsmodels formula
    formula = "CASE ~ zSCORE + sex_for_qc + age + AJ + EUR + EAS + AMR + AFR + CAS + AAC"
    model = sm.Logit.from_formula(formula, data=dat)
    result = model.fit()

    # Print the summary
    print(result.summary())

    # Print
    print("Done analyzing " + ancestry + " now on to the next thing.")
# Out:
# Ancestry: AAC
# Optimization terminated successfully.
#          Current function value: 0.397559
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                  910
# Model:                          Logit   Df Residuals:                      899
# Method:                           MLE   Df Model:                           10
# Date:                Mon, 11 Mar 2024   Pseudo R-squ.:                  0.2240
# Time:                        09:17:08   Log-Likelihood:                -361.78
# converged:                       True   LL-Null:                       -466.24
# Covariance Type:            nonrobust   LLR p-value:                 2.218e-39
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.2440      1.473      0.844      0.398      -1.643       4.131
# zSCORE         0.3183      0.094      3.386      0.001       0.134       0.503
# sex_for_qc    -0.8241      0.192     -4.295      0.000      -1.200      -0.448
# age            0.0274      0.009      3.146      0.002       0.010       0.044
# AJ             3.8174      5.100      0.748      0.454      -6.179      13.814
# EUR           -3.2968      1.461     -2.256      0.024      -6.161      -0.433
# EAS            6.8392      5.148      1.328      0.184      -3.251      16.930
# AMR           15.8744      3.094      5.130      0.000       9.810      21.939
# AFR           -5.1988      1.575     -3.300      0.001      -8.287      -2.111
# CAS            3.0411      8.831      0.344      0.731     -14.267      20.349
# AAC           -1.6400      1.639     -1.001      0.317      -4.853       1.573
# ==============================================================================
# Done analyzing AAC now on to the next thing.
# Ancestry: AFR
# Optimization terminated successfully.
#          Current function value: 0.399062
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                 1069
# Model:                          Logit   Df Residuals:                     1058
# Method:                           MLE   Df Model:                           10
# Date:                Mon, 11 Mar 2024   Pseudo R-squ.:                 0.09542
# Time:                        09:17:08   Log-Likelihood:                -426.60
# converged:                       True   LL-Null:                       -471.60
# Covariance Type:            nonrobust   LLR p-value:                 5.364e-15
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -5.8608      3.990     -1.469      0.142     -13.681       1.959
# zSCORE         0.2133      0.085      2.496      0.013       0.046       0.381
# sex_for_qc    -0.3136      0.176     -1.778      0.075      -0.659       0.032
# age            0.0088      0.005      1.637      0.102      -0.002       0.019
# AJ            12.2918     10.018      1.227      0.220      -7.343      31.927
# EUR            4.7827      4.210      1.136      0.256      -3.469      13.034
# EAS            1.1554     15.794      0.073      0.942     -29.799      32.110
# AMR           -8.8214      8.256     -1.068      0.285     -25.003       7.360
# AFR            3.5041      4.139      0.847      0.397      -4.607      11.616
# CAS           18.8732     14.150      1.334      0.182      -8.860      46.607
# AAC            5.1889      3.966      1.308      0.191      -2.583      12.961
# ==============================================================================
# Done analyzing AFR now on to the next thing.
# Ancestry: AJ
# Optimization terminated successfully.
#          Current function value: 0.522978
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                 1203
# Model:                          Logit   Df Residuals:                     1192
# Method:                           MLE   Df Model:                           10
# Date:                Mon, 11 Mar 2024   Pseudo R-squ.:                 0.02531
# Time:                        09:17:08   Log-Likelihood:                -629.14
# converged:                       True   LL-Null:                       -645.48
# Covariance Type:            nonrobust   LLR p-value:                 0.0003085
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.2624      1.127      1.120      0.263      -0.946       3.471
# zSCORE         0.0478      0.068      0.708      0.479      -0.085       0.180
# sex_for_qc    -0.7010      0.143     -4.904      0.000      -0.981      -0.421
# age            0.0145      0.007      2.047      0.041       0.001       0.028
# AJ            -0.0025      1.114     -0.002      0.998      -2.185       2.180
# EUR           -0.7989      1.761     -0.454      0.650      -4.250       2.652
# EAS            8.1683      9.421      0.867      0.386     -10.296      26.632
# AMR           -5.4415      5.612     -0.970      0.332     -16.440       5.557
# AFR           -8.7887      9.594     -0.916      0.360     -27.592      10.015
# CAS           -3.9137      6.208     -0.630      0.528     -16.082       8.254
# AAC            5.5391      9.826      0.564      0.573     -13.719      24.797
# ==============================================================================
# Done analyzing AJ now on to the next thing.
# Ancestry: AMR
# Optimization terminated successfully.
#          Current function value: 0.503443
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                  400
# Model:                          Logit   Df Residuals:                      389
# Method:                           MLE   Df Model:                           10
# Date:                Mon, 11 Mar 2024   Pseudo R-squ.:                 0.04453
# Time:                        09:17:08   Log-Likelihood:                -201.38
# converged:                       True   LL-Null:                       -210.76
# Covariance Type:            nonrobust   LLR p-value:                   0.04326
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.3045      1.263      2.617      0.009       0.830       5.779
# zSCORE         0.3285      0.122      2.686      0.007       0.089       0.568
# sex_for_qc    -0.1730      0.254     -0.680      0.496      -0.671       0.326
# age           -0.0294      0.011     -2.594      0.009      -0.052      -0.007
# AJ             1.9847      5.723      0.347      0.729      -9.232      13.201
# EUR            0.1998      1.468      0.136      0.892      -2.678       3.077
# EAS           12.1129     12.739      0.951      0.342     -12.855      37.080
# AMR           -0.1171      0.945     -0.124      0.901      -1.970       1.736
# AFR           -5.0555      3.485     -1.451      0.147     -11.886       1.775
# CAS            3.5588      7.864      0.453      0.651     -11.855      18.973
# AAC            2.4294     11.076      0.219      0.826     -19.280      24.138
# ==============================================================================
# Done analyzing AMR now on to the next thing.
# Ancestry: EAS
# Optimization terminated successfully.
#          Current function value: 0.544845
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                 2760
# Model:                          Logit   Df Residuals:                     2749
# Method:                           MLE   Df Model:                           10
# Date:                Mon, 11 Mar 2024   Pseudo R-squ.:                  0.2082
# Time:                        09:17:09   Log-Likelihood:                -1503.8
# converged:                       True   LL-Null:                       -1899.1
# Covariance Type:            nonrobust   LLR p-value:                2.185e-163
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -12.1642      0.610    -19.956      0.000     -13.359     -10.969
# zSCORE         0.1581      0.045      3.498      0.000       0.070       0.247
# sex_for_qc    -0.4535      0.090     -5.050      0.000      -0.630      -0.277
# age            0.0241      0.004      5.871      0.000       0.016       0.032
# AJ            -7.0422     30.507     -0.231      0.817     -66.835      52.750
# EUR           10.0335      6.177      1.624      0.104      -2.074      22.141
# EAS           12.5950      0.623     20.224      0.000      11.374      13.816
# AMR           31.0756     20.212      1.538      0.124      -8.539      70.690
# AFR           14.1153     15.859      0.890      0.373     -16.969      45.199
# CAS           10.2966      0.536     19.222      0.000       9.247      11.347
# AAC            5.3941     21.491      0.251      0.802     -36.727      47.515
# ==============================================================================
# Done analyzing EAS now on to the next thing.
# Ancestry: EUR
# Optimization terminated successfully.
#          Current function value: 0.655017
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                13969
# Model:                          Logit   Df Residuals:                    13958
# Method:                           MLE   Df Model:                           10
# Date:                Mon, 11 Mar 2024   Pseudo R-squ.:                 0.01959
# Time:                        09:17:09   Log-Likelihood:                -9149.9
# converged:                       True   LL-Null:                       -9332.8
# Covariance Type:            nonrobust   LLR p-value:                 1.848e-72
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4549      0.142      3.207      0.001       0.177       0.733
# zSCORE         0.1413      0.017      8.149      0.000       0.107       0.175
# sex_for_qc    -0.3810      0.036    -10.694      0.000      -0.451      -0.311
# age            0.0149      0.002      9.170      0.000       0.012       0.018
# AJ             0.2827      0.379      0.746      0.456      -0.460       1.026
# EUR           -0.6928      0.096     -7.208      0.000      -0.881      -0.504
# EAS            4.3685      1.891      2.310      0.021       0.662       8.075
# AMR            2.1204      0.819      2.590      0.010       0.516       3.725
# AFR           -4.8380      1.733     -2.792      0.005      -8.234      -1.442
# CAS            3.8049      1.267      3.004      0.003       1.322       6.287
# AAC           -7.6092      1.683     -4.521      0.000     -10.908      -4.310
# ==============================================================================
# Done analyzing EUR now on to the next thing.
# Ancestry: CAS
# Optimization terminated successfully.
#          Current function value: 0.634653
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                  414
# Model:                          Logit   Df Residuals:                      403
# Method:                           MLE   Df Model:                           10
# Date:                Mon, 11 Mar 2024   Pseudo R-squ.:                 0.08425
# Time:                        09:17:09   Log-Likelihood:                -262.75
# converged:                       True   LL-Null:                       -286.92
# Covariance Type:            nonrobust   LLR p-value:                 5.365e-07
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.5293      0.778     -1.966      0.049      -3.054      -0.005
# zSCORE         0.1957      0.110      1.787      0.074      -0.019       0.410
# sex_for_qc    -0.6490      0.216     -3.001      0.003      -1.073      -0.225
# age            0.0575      0.012      4.743      0.000       0.034       0.081
# AJ             1.5700      5.789      0.271      0.786      -9.777      12.917
# EUR            3.5419      2.075      1.707      0.088      -0.525       7.609
# EAS           -0.6124      1.776     -0.345      0.730      -4.094       2.869
# AMR           -0.5165      3.946     -0.131      0.896      -8.250       7.217
# AFR          -19.7903     16.594     -1.193      0.233     -52.315      12.734
# CAS           -1.4024      1.214     -1.155      0.248      -3.782       0.977
# AAC            5.6868     15.275      0.372      0.710     -24.252      35.626
# ==============================================================================
# Done analyzing CAS now on to the next thing.

# %%
import pandas as pd
import statsmodels.api as sm

## RUN PRS versus RISK across ancestries (EUROPEAN summary stats)
# List of ancestries
ancestries = ["AAC", "AFR", "AJ", "AMR", "EAS", "EUR", "CAS"]

for ancestry in ancestries:  
    print("Ancestry:", ancestry)
    # Construct file paths
    prs_file = f"{WORK_DIR}/imputed_data/" + ancestry + "/PRS_score_release_EUROPEAN.profile"

    # Read PRS data
    temp_data = pd.read_csv(prs_file, delim_whitespace =True)

    # Read admx data
    temp_covs = pd.read_csv(f"{WORK_DIR}/projects/ref_panel_prep/gp2_admixture/GP2_round6/release6_ancestry_merge_train.10.Q.labeled", delim_whitespace =True)

    # Read additional covariates
    temp_covs_2 = pd.read_csv(f"{WORK_DIR}/CLEAN/covariates.txt", sep="\t")
    temp_covs_2 = temp_covs_2.rename(columns={"GP2sampleID": "IID"})

    # Merge covariates
    covs = pd.merge(temp_covs, temp_covs_2, on="IID")
    covs.head()

    # Merge PRS data and covariates
    dat = pd.merge(temp_data, covs, on="IID")

    # Remove missing or unknown cases
    dat = dat[dat["PHENO"] != -9]

    # Logistic regression model phenotype
    dat['CASE'] = dat['PHENO'] - 1 

    # Standardize PRS
    mean_controls = dat.loc[dat["CASE"] == 0, "SCORE"].mean()
    sd_controls = dat.loc[dat["CASE"] == 0, "SCORE"].std()
    dat["zSCORE"] = (dat["SCORE"] - mean_controls) / sd_controls

    # Logistic regression model using statsmodels formula
    formula = "CASE ~ zSCORE + sex_for_qc + age + AJ + EUR + EAS + AMR + AFR + CAS + AAC"
    model = sm.Logit.from_formula(formula, data=dat)
    result = model.fit()

    # Print the summary
    print(result.summary())

    # Print
    print("Done analyzing " + ancestry + " now on to the next thing.")
# Out:
# Ancestry: AAC
# Optimization terminated successfully.
#          Current function value: 0.388589
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                  910
# Model:                          Logit   Df Residuals:                      899
# Method:                           MLE   Df Model:                           10
# Date:                Mon, 11 Mar 2024   Pseudo R-squ.:                  0.2416
# Time:                        09:17:20   Log-Likelihood:                -353.62
# converged:                       True   LL-Null:                       -466.24
# Covariance Type:            nonrobust   LLR p-value:                 8.514e-43
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.9985      1.509      0.662      0.508      -1.959       3.956
# zSCORE         0.5002      0.098      5.125      0.000       0.309       0.691
# sex_for_qc    -0.8010      0.194     -4.126      0.000      -1.181      -0.420
# age            0.0255      0.009      2.901      0.004       0.008       0.043
# AJ             4.0533      5.241      0.773      0.439      -6.218      14.325
# EUR           -3.4341      1.497     -2.294      0.022      -6.368      -0.500
# EAS            6.6974      5.206      1.287      0.198      -3.505      16.900
# AMR           16.4913      3.116      5.292      0.000      10.384      22.599
# AFR           -4.8467      1.624     -2.985      0.003      -8.029      -1.664
# CAS            3.8855      9.525      0.408      0.683     -14.783      22.554
# AAC           -1.1919      1.689     -0.706      0.480      -4.503       2.119
# ==============================================================================
# Done analyzing AAC now on to the next thing.
# Ancestry: AFR
# Optimization terminated successfully.
#          Current function value: 0.397484
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                 1069
# Model:                          Logit   Df Residuals:                     1058
# Method:                           MLE   Df Model:                           10
# Date:                Mon, 11 Mar 2024   Pseudo R-squ.:                 0.09899
# Time:                        09:17:21   Log-Likelihood:                -424.91
# converged:                       True   LL-Null:                       -471.60
# Covariance Type:            nonrobust   LLR p-value:                 1.146e-15
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -5.7550      4.014     -1.434      0.152     -13.622       2.112
# zSCORE         0.2742      0.089      3.093      0.002       0.100       0.448
# sex_for_qc    -0.2943      0.177     -1.665      0.096      -0.641       0.052
# age            0.0073      0.005      1.362      0.173      -0.003       0.018
# AJ            10.9022     10.072      1.082      0.279      -8.839      30.644
# EUR            4.6468      4.232      1.098      0.272      -3.649      12.942
# EAS            0.4543     15.930      0.029      0.977     -30.768      31.676
# AMR          -10.2100      8.285     -1.232      0.218     -26.449       6.029
# AFR            3.5007      4.167      0.840      0.401      -4.667      11.669
# CAS           17.5506     14.155      1.240      0.215     -10.193      45.294
# AAC            5.1448      3.993      1.288      0.198      -2.681      12.971
# ==============================================================================
# Done analyzing AFR now on to the next thing.
# Ancestry: AJ
# Optimization terminated successfully.
#          Current function value: 0.476672
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                 1203
# Model:                          Logit   Df Residuals:                     1192
# Method:                           MLE   Df Model:                           10
# Date:                Mon, 11 Mar 2024   Pseudo R-squ.:                  0.1116
# Time:                        09:17:21   Log-Likelihood:                -573.44
# converged:                       True   LL-Null:                       -645.48
# Covariance Type:            nonrobust   LLR p-value:                 6.104e-26
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3484      1.180      0.295      0.768      -1.964       2.661
# zSCORE         0.6689      0.074      9.043      0.000       0.524       0.814
# sex_for_qc    -0.7585      0.151     -5.033      0.000      -1.054      -0.463
# age            0.0211      0.008      2.797      0.005       0.006       0.036
# AJ             0.2038      1.175      0.173      0.862      -2.099       2.507
# EUR            0.1282      1.821      0.070      0.944      -3.442       3.698
# EAS           16.8638      9.812      1.719      0.086      -2.367      36.095
# AMR           -1.5811      5.881     -0.269      0.788     -13.107       9.945
# AFR           -4.4596     10.059     -0.443      0.658     -24.176      15.256
# CAS           -4.5781      6.517     -0.703      0.482     -17.351       8.194
# AAC            7.6340     10.218      0.747      0.455     -12.393      27.661
# ==============================================================================
# Done analyzing AJ now on to the next thing.
# Ancestry: AMR
# Optimization terminated successfully.
#          Current function value: 0.486594
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                  400
# Model:                          Logit   Df Residuals:                      389
# Method:                           MLE   Df Model:                           10
# Date:                Mon, 11 Mar 2024   Pseudo R-squ.:                 0.07651
# Time:                        09:17:21   Log-Likelihood:                -194.64
# converged:                       True   LL-Null:                       -210.76
# Covariance Type:            nonrobust   LLR p-value:                 0.0003636
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.4937      1.274      2.742      0.006       0.997       5.991
# zSCORE         0.5300      0.126      4.218      0.000       0.284       0.776
# sex_for_qc    -0.2247      0.258     -0.870      0.385      -0.731       0.282
# age           -0.0274      0.011     -2.383      0.017      -0.050      -0.005
# AJ             0.6326      5.784      0.109      0.913     -10.704      11.969
# EUR           -0.4737      1.474     -0.321      0.748      -3.363       2.415
# EAS           12.6456     13.156      0.961      0.336     -13.140      38.431
# AMR           -0.4485      0.949     -0.473      0.636      -2.308       1.411
# AFR           -3.6095      3.588     -1.006      0.314     -10.642       3.424
# CAS            1.1605      7.785      0.149      0.882     -14.098      16.419
# AAC            4.1924     11.187      0.375      0.708     -17.734      26.118
# ==============================================================================
# Done analyzing AMR now on to the next thing.
# Ancestry: EAS
# Optimization terminated successfully.
#          Current function value: 0.528708
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                 2760
# Model:                          Logit   Df Residuals:                     2749
# Method:                           MLE   Df Model:                           10
# Date:                Mon, 11 Mar 2024   Pseudo R-squ.:                  0.2316
# Time:                        09:17:21   Log-Likelihood:                -1459.2
# converged:                       True   LL-Null:                       -1899.1
# Covariance Type:            nonrobust   LLR p-value:                1.522e-182
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -12.1195      0.619    -19.584      0.000     -13.332     -10.907
# zSCORE         0.4616      0.047      9.759      0.000       0.369       0.554
# sex_for_qc    -0.4574      0.091     -4.999      0.000      -0.637      -0.278
# age            0.0255      0.004      6.131      0.000       0.017       0.034
# AJ            -6.2726     30.949     -0.203      0.839     -66.932      54.387
# EUR           11.2715      6.169      1.827      0.068      -0.819      23.362
# EAS           12.3514      0.630     19.600      0.000      11.116      13.587
# AMR           34.3902     20.638      1.666      0.096      -6.060      74.841
# AFR            9.5786     15.473      0.619      0.536     -20.748      39.905
# CAS           10.1879      0.543     18.755      0.000       9.123      11.253
# AAC           12.5706     21.678      0.580      0.562     -29.917      55.058
# ==============================================================================
# Done analyzing EAS now on to the next thing.
# Ancestry: EUR
# Optimization terminated successfully.
#          Current function value: 0.631147
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                13969
# Model:                          Logit   Df Residuals:                    13958
# Method:                           MLE   Df Model:                           10
# Date:                Mon, 11 Mar 2024   Pseudo R-squ.:                 0.05532
# Time:                        09:17:21   Log-Likelihood:                -8816.5
# converged:                       True   LL-Null:                       -9332.8
# Covariance Type:            nonrobust   LLR p-value:                1.803e-215
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1902      0.146      1.304      0.192      -0.096       0.476
# zSCORE         0.4654      0.018     25.767      0.000       0.430       0.501
# sex_for_qc    -0.3914      0.037    -10.718      0.000      -0.463      -0.320
# age            0.0160      0.002      9.594      0.000       0.013       0.019
# AJ             0.0802      0.393      0.204      0.838      -0.690       0.850
# EUR           -0.5646      0.098     -5.747      0.000      -0.757      -0.372
# EAS            4.5190      1.935      2.336      0.020       0.727       8.311
# AMR            2.2785      0.845      2.696      0.007       0.622       3.935
# AFR           -3.9870      1.769     -2.254      0.024      -7.454      -0.520
# CAS            4.3724      1.299      3.365      0.001       1.826       6.919
# AAC           -6.5726      1.718     -3.825      0.000      -9.940      -3.205
# ==============================================================================
# Done analyzing EUR now on to the next thing.
# Ancestry: CAS
# Optimization terminated successfully.
#          Current function value: 0.622373
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                  414
# Model:                          Logit   Df Residuals:                      403
# Method:                           MLE   Df Model:                           10
# Date:                Mon, 11 Mar 2024   Pseudo R-squ.:                  0.1020
# Time:                        09:17:21   Log-Likelihood:                -257.66
# converged:                       True   LL-Null:                       -286.92
# Covariance Type:            nonrobust   LLR p-value:                 6.917e-09
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.4219      0.776     -1.833      0.067      -2.943       0.099
# zSCORE         0.3903      0.109      3.584      0.000       0.177       0.604
# sex_for_qc    -0.6294      0.219     -2.872      0.004      -1.059      -0.200
# age            0.0568      0.012      4.676      0.000       0.033       0.081
# AJ             2.6346      5.864      0.449      0.653      -8.858      14.127
# EUR            3.3136      2.124      1.560      0.119      -0.849       7.477
# EAS           -0.8875      1.782     -0.498      0.618      -4.380       2.605
# AMR           -1.5618      3.971     -0.393      0.694      -9.345       6.221
# AFR          -21.0318     17.014     -1.236      0.216     -54.379      12.316
# CAS           -1.4830      1.219     -1.217      0.224      -3.872       0.906
# AAC            5.2428     15.280      0.343      0.732     -24.705      35.190
# ==============================================================================
# Done analyzing CAS now on to the next thing.

# %%
import pandas as pd
import statsmodels.api as sm

## RUN PRS versus RISK across ancestries (LATINO summary stats)
# List of ancestries
ancestries = ["AAC", "AFR", "AJ", "AMR", "EAS", "EUR", "CAS"]

for ancestry in ancestries:  
    print("Ancestry:", ancestry)
    # Construct file paths
    prs_file = f"{WORK_DIR}/imputed_data/" + ancestry + "/PRS_score_release_LATINO.profile"

    # Read PRS data
    temp_data = pd.read_csv(prs_file, delim_whitespace =True)

    # Read admx data
    temp_covs = pd.read_csv(f"{WORK_DIR}/projects/ref_panel_prep/gp2_admixture/GP2_round6/release6_ancestry_merge_train.10.Q.labeled", delim_whitespace =True)

    # Read additional covariates
    temp_covs_2 = pd.read_csv(f"{WORK_DIR}/covariates.txt", sep="\t")
    temp_covs_2 = temp_covs_2.rename(columns={"GP2sampleID": "IID"})

    # Merge covariates
    covs = pd.merge(temp_covs, temp_covs_2, on="IID")
    covs.head()

    # Merge PRS data and covariates
    dat = pd.merge(temp_data, covs, on="IID")

    # Remove missing or unknown cases
    dat = dat[dat["PHENO"] != -9]

    # Logistic regression model phenotype
    dat['CASE'] = dat['PHENO'] - 1 

    # Standardize PRS
    mean_controls = dat.loc[dat["CASE"] == 0, "SCORE"].mean()
    sd_controls = dat.loc[dat["CASE"] == 0, "SCORE"].std()
    dat["zSCORE"] = (dat["SCORE"] - mean_controls) / sd_controls

    # Logistic regression model using statsmodels formula
    formula = "CASE ~ zSCORE + sex_for_qc + age + AJ + EUR + EAS + AMR + AFR + CAS + AAC"
    model = sm.Logit.from_formula(formula, data=dat)
    result = model.fit()

    # Print the summary
    print(result.summary())

    # Print
    print("Done analyzing " + ancestry + " now on to the next thing.")
# Out:
# Ancestry: AAC
# Optimization terminated successfully.
#          Current function value: 0.400387
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                  910
# Model:                          Logit   Df Residuals:                      899
# Method:                           MLE   Df Model:                           10
# Date:                Mon, 11 Mar 2024   Pseudo R-squ.:                  0.2185
# Time:                        09:17:25   Log-Likelihood:                -364.35
# converged:                       True   LL-Null:                       -466.24
# Covariance Type:            nonrobust   LLR p-value:                 2.634e-38
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.8085      1.463      1.236      0.216      -1.059       4.676
# zSCORE         0.2393      0.095      2.530      0.011       0.054       0.425
# sex_for_qc    -0.7952      0.191     -4.164      0.000      -1.169      -0.421
# age            0.0280      0.009      3.227      0.001       0.011       0.045
# AJ             3.0746      5.038      0.610      0.542      -6.799      12.948
# EUR           -3.5250      1.459     -2.417      0.016      -6.384      -0.666
# EAS            5.3054      5.160      1.028      0.304      -4.809      15.420
# AMR           15.7277      3.061      5.138      0.000       9.729      21.727
# AFR           -5.9996      1.570     -3.821      0.000      -9.077      -2.922
# CAS            2.8998      9.187      0.316      0.752     -15.106      20.906
# AAC           -2.3625      1.626     -1.453      0.146      -5.550       0.825
# ==============================================================================
# Done analyzing AAC now on to the next thing.
# Ancestry: AFR
# Optimization terminated successfully.
#          Current function value: 0.401029
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                 1069
# Model:                          Logit   Df Residuals:                     1058
# Method:                           MLE   Df Model:                           10
# Date:                Mon, 11 Mar 2024   Pseudo R-squ.:                 0.09096
# Time:                        09:17:25   Log-Likelihood:                -428.70
# converged:                       True   LL-Null:                       -471.60
# Covariance Type:            nonrobust   LLR p-value:                 3.643e-14
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -5.1950      3.973     -1.308      0.191     -12.981       2.591
# zSCORE         0.1244      0.086      1.446      0.148      -0.044       0.293
# sex_for_qc    -0.3287      0.176     -1.870      0.062      -0.673       0.016
# age            0.0072      0.005      1.362      0.173      -0.003       0.018
# AJ            12.0932     10.039      1.205      0.228      -7.582      31.769
# EUR            4.9790      4.194      1.187      0.235      -3.241      13.199
# EAS            0.2032     15.848      0.013      0.990     -30.859      31.265
# AMR           -9.1538      8.172     -1.120      0.263     -25.170       6.863
# AFR            2.9651      4.123      0.719      0.472      -5.115      11.046
# CAS           18.2166     14.089      1.293      0.196      -9.398      45.831
# AAC            4.6196      3.951      1.169      0.242      -3.123      12.363
# ==============================================================================
# Done analyzing AFR now on to the next thing.
# Ancestry: AJ
# Optimization terminated successfully.
#          Current function value: 0.519148
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                 1203
# Model:                          Logit   Df Residuals:                     1192
# Method:                           MLE   Df Model:                           10
# Date:                Mon, 11 Mar 2024   Pseudo R-squ.:                 0.03245
# Time:                        09:17:25   Log-Likelihood:                -624.53
# converged:                       True   LL-Null:                       -645.48
# Covariance Type:            nonrobust   LLR p-value:                 7.831e-06
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.1723      1.130      1.037      0.300      -1.043       3.388
# zSCORE         0.2115      0.068      3.100      0.002       0.078       0.345
# sex_for_qc    -0.6907      0.144     -4.810      0.000      -0.972      -0.409
# age            0.0153      0.007      2.163      0.031       0.001       0.029
# AJ             0.0064      1.115      0.006      0.995      -2.180       2.193
# EUR           -0.5221      1.774     -0.294      0.769      -3.999       2.955
# EAS            8.8907      9.462      0.940      0.347      -9.654      27.435
# AMR           -6.4617      5.666     -1.140      0.254     -17.567       4.643
# AFR           -8.9457      9.606     -0.931      0.352     -27.773       9.882
# CAS           -4.7340      6.196     -0.764      0.445     -16.878       7.410
# AAC            4.7727      9.835      0.485      0.627     -14.504      24.049
# ==============================================================================
# Done analyzing AJ now on to the next thing.
# Ancestry: AMR
# Optimization terminated successfully.
#          Current function value: 0.506540
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                  400
# Model:                          Logit   Df Residuals:                      389
# Method:                           MLE   Df Model:                           10
# Date:                Mon, 11 Mar 2024   Pseudo R-squ.:                 0.03866
# Time:                        09:17:25   Log-Likelihood:                -202.62
# converged:                       True   LL-Null:                       -210.76
# Covariance Type:            nonrobust   LLR p-value:                   0.09150
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.5160      1.252      2.807      0.005       1.061       5.971
# zSCORE         0.2674      0.121      2.209      0.027       0.030       0.505
# sex_for_qc    -0.1559      0.252     -0.619      0.536      -0.650       0.338
# age           -0.0277      0.011     -2.449      0.014      -0.050      -0.006
# AJ             1.5254      5.654      0.270      0.787      -9.556      12.607
# EUR           -0.1597      1.462     -0.109      0.913      -3.026       2.706
# EAS           15.4225     13.179      1.170      0.242     -10.407      41.252
# AMR           -0.5660      0.953     -0.594      0.552      -2.433       1.301
# AFR           -4.8914      3.466     -1.411      0.158     -11.684       1.901
# CAS            2.1044      7.710      0.273      0.785     -13.007      17.215
# AAC            2.7312     11.109      0.246      0.806     -19.042      24.504
# ==============================================================================
# Done analyzing AMR now on to the next thing.
# Ancestry: EAS
# Optimization terminated successfully.
#          Current function value: 0.538913
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                 2760
# Model:                          Logit   Df Residuals:                     2749
# Method:                           MLE   Df Model:                           10
# Date:                Mon, 11 Mar 2024   Pseudo R-squ.:                  0.2168
# Time:                        09:17:26   Log-Likelihood:                -1487.4
# converged:                       True   LL-Null:                       -1899.1
# Covariance Type:            nonrobust   LLR p-value:                1.995e-170
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -11.9997      0.611    -19.628      0.000     -13.198     -10.801
# zSCORE         0.3066      0.046      6.638      0.000       0.216       0.397
# sex_for_qc    -0.4552      0.090     -5.032      0.000      -0.632      -0.278
# age            0.0246      0.004      5.981      0.000       0.017       0.033
# AJ            -8.6407     31.164     -0.277      0.782     -69.721      52.440
# EUR           11.8292      6.169      1.917      0.055      -0.262      23.920
# EAS           12.3253      0.624     19.741      0.000      11.102      13.549
# AMR           32.9910     20.254      1.629      0.103      -6.705      72.687
# AFR           12.4519     15.553      0.801      0.423     -18.031      42.935
# CAS           10.2905      0.538     19.124      0.000       9.236      11.345
# AAC           11.5258     21.391      0.539      0.590     -30.400      53.452
# ==============================================================================
# Done analyzing EAS now on to the next thing.
# Ancestry: EUR
# Optimization terminated successfully.
#          Current function value: 0.650733
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                13969
# Model:                          Logit   Df Residuals:                    13958
# Method:                           MLE   Df Model:                           10
# Date:                Mon, 11 Mar 2024   Pseudo R-squ.:                 0.02600
# Time:                        09:17:26   Log-Likelihood:                -9090.1
# converged:                       True   LL-Null:                       -9332.8
# Covariance Type:            nonrobust   LLR p-value:                 5.846e-98
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4068      0.143      2.854      0.004       0.127       0.686
# zSCORE         0.2390      0.018     13.524      0.000       0.204       0.274
# sex_for_qc    -0.3837      0.036    -10.720      0.000      -0.454      -0.314
# age            0.0147      0.002      8.977      0.000       0.011       0.018
# AJ             0.2553      0.381      0.670      0.503      -0.491       1.002
# EUR           -0.6139      0.096     -6.362      0.000      -0.803      -0.425
# EAS            3.6784      1.894      1.942      0.052      -0.034       7.391
# AMR            2.1452      0.824      2.605      0.009       0.531       3.759
# AFR           -4.7889      1.741     -2.750      0.006      -8.202      -1.376
# CAS            3.5653      1.275      2.796      0.005       1.066       6.065
# AAC           -7.5224      1.690     -4.450      0.000     -10.836      -4.209
# ==============================================================================
# Done analyzing EUR now on to the next thing.
# Ancestry: CAS
# Optimization terminated successfully.
#          Current function value: 0.623895
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                  414
# Model:                          Logit   Df Residuals:                      403
# Method:                           MLE   Df Model:                           10
# Date:                Mon, 11 Mar 2024   Pseudo R-squ.:                 0.09977
# Time:                        09:17:26   Log-Likelihood:                -258.29
# converged:                       True   LL-Null:                       -286.92
# Covariance Type:            nonrobust   LLR p-value:                 1.194e-08
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.4626      0.778     -1.880      0.060      -2.987       0.062
# zSCORE         0.3763      0.110      3.410      0.001       0.160       0.593
# sex_for_qc    -0.6531      0.219     -2.987      0.003      -1.082      -0.225
# age            0.0569      0.012      4.710      0.000       0.033       0.081
# AJ             3.4768      5.903      0.589      0.556      -8.093      15.047
# EUR            3.9706      2.163      1.836      0.066      -0.268       8.210
# EAS           -1.3219      1.779     -0.743      0.457      -4.808       2.164
# AMR           -1.4739      3.939     -0.374      0.708      -9.193       6.245
# AFR          -18.7294     16.984     -1.103      0.270     -52.018      14.559
# CAS           -1.3130      1.217     -1.078      0.281      -3.699       1.073
# AAC            6.1815     15.444      0.400      0.689     -24.089      36.452
# ==============================================================================
# Done analyzing CAS now on to the next thing.

# %%
import pandas as pd
import statsmodels.api as sm

## RUN PRS versus RISK across ancestries (EAST ASIANS summary stats)
# List of ancestries
ancestries = ["AAC", "AFR", "AJ", "AMR", "EAS", "EUR", "CAS"]

for ancestry in ancestries:  
    print("Ancestry:", ancestry)
    # Construct file paths
    prs_file = f"{WORK_DIR}/imputed_data/" + ancestry + "/PRS_score_release_EASTASIANS.profile"

    # Read PRS data
    temp_data = pd.read_csv(prs_file, delim_whitespace =True)

    # Read admx data
    temp_covs = pd.read_csv(f"{WORK_DIR}/projects/ref_panel_prep/gp2_admixture/GP2_round6/release6_ancestry_merge_train.10.Q.labeled", delim_whitespace =True)

    # Read additional covariates
    temp_covs_2 = pd.read_csv(f"{WORK_DIR}/covariates.txt", sep="\t")
    temp_covs_2 = temp_covs_2.rename(columns={"GP2sampleID": "IID"})

    # Merge covariates
    covs = pd.merge(temp_covs, temp_covs_2, on="IID")
    covs.head()

    # Merge PRS data and covariates
    dat = pd.merge(temp_data, covs, on="IID")

    # Remove missing or unknown cases
    dat = dat[dat["PHENO"] != -9]

    # Logistic regression model phenotype
    dat['CASE'] = dat['PHENO'] - 1 

    # Standardize PRS
    mean_controls = dat.loc[dat["CASE"] == 0, "SCORE"].mean()
    sd_controls = dat.loc[dat["CASE"] == 0, "SCORE"].std()
    dat["zSCORE"] = (dat["SCORE"] - mean_controls) / sd_controls

    # Logistic regression model using statsmodels formula
    formula = "CASE ~ zSCORE + sex_for_qc + age + AJ + EUR + EAS + AMR + AFR + CAS + AAC"
    model = sm.Logit.from_formula(formula, data=dat)
    result = model.fit()

    # Print the summary
    print(result.summary())

    # Print
    print("Done analyzing " + ancestry + " now on to the next thing.")
# Out:
# Ancestry: AAC
# Optimization terminated successfully.
#          Current function value: 0.395995
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                  910
# Model:                          Logit   Df Residuals:                      899
# Method:                           MLE   Df Model:                           10
# Date:                Mon, 11 Mar 2024   Pseudo R-squ.:                  0.2271
# Time:                        09:17:29   Log-Likelihood:                -360.36
# converged:                       True   LL-Null:                       -466.24
# Covariance Type:            nonrobust   LLR p-value:                 5.636e-40
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.3560      1.482      0.915      0.360      -1.550       4.262
# zSCORE         0.3629      0.097      3.758      0.000       0.174       0.552
# sex_for_qc    -0.8221      0.192     -4.285      0.000      -1.198      -0.446
# age            0.0277      0.009      3.175      0.001       0.011       0.045
# AJ             3.0045      5.123      0.586      0.558      -7.036      13.046
# EUR           -3.5927      1.467     -2.448      0.014      -6.469      -0.717
# EAS            7.1491      5.201      1.375      0.169      -3.045      17.343
# AMR           15.7965      3.065      5.154      0.000       9.790      21.803
# AFR           -5.3426      1.592     -3.356      0.001      -8.463      -2.222
# CAS            3.5374      9.334      0.379      0.705     -14.757      21.831
# AAC           -1.9412      1.647     -1.179      0.239      -5.169       1.287
# ==============================================================================
# Done analyzing AAC now on to the next thing.
# Ancestry: AFR
# Optimization terminated successfully.
#          Current function value: 0.398117
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                 1069
# Model:                          Logit   Df Residuals:                     1058
# Method:                           MLE   Df Model:                           10
# Date:                Mon, 11 Mar 2024   Pseudo R-squ.:                 0.09756
# Time:                        09:17:29   Log-Likelihood:                -425.59
# converged:                       True   LL-Null:                       -471.60
# Covariance Type:            nonrobust   LLR p-value:                 2.131e-15
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -5.6879      4.002     -1.421      0.155     -13.531       2.156
# zSCORE         0.2534      0.088      2.865      0.004       0.080       0.427
# sex_for_qc    -0.3238      0.177     -1.834      0.067      -0.670       0.022
# age            0.0079      0.005      1.480      0.139      -0.003       0.018
# AJ            11.1187     10.034      1.108      0.268      -8.548      30.785
# EUR            4.8141      4.228      1.138      0.255      -3.474      13.102
# EAS            1.0501     15.918      0.066      0.947     -30.148      32.248
# AMR           -9.2763      8.215     -1.129      0.259     -25.377       6.825
# AFR            3.4208      4.153      0.824      0.410      -4.720      11.561
# CAS           17.3152     14.193      1.220      0.222     -10.504      45.134
# AAC            5.0615      3.980      1.272      0.203      -2.739      12.862
# ==============================================================================
# Done analyzing AFR now on to the next thing.
# Ancestry: AJ
# Optimization terminated successfully.
#          Current function value: 0.517117
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                 1203
# Model:                          Logit   Df Residuals:                     1192
# Method:                           MLE   Df Model:                           10
# Date:                Mon, 11 Mar 2024   Pseudo R-squ.:                 0.03624
# Time:                        09:17:29   Log-Likelihood:                -622.09
# converged:                       True   LL-Null:                       -645.48
# Covariance Type:            nonrobust   LLR p-value:                 1.036e-06
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.9059      1.135      0.798      0.425      -1.318       3.130
# zSCORE         0.2576      0.068      3.786      0.000       0.124       0.391
# sex_for_qc    -0.6745      0.144     -4.690      0.000      -0.956      -0.393
# age            0.0158      0.007      2.234      0.025       0.002       0.030
# AJ             0.2073      1.120      0.185      0.853      -1.989       2.403
# EUR           -0.5825      1.763     -0.330      0.741      -4.037       2.872
# EAS            9.0944      9.520      0.955      0.339      -9.565      27.754
# AMR           -4.9566      5.638     -0.879      0.379     -16.007       6.093
# AFR           -7.5786      9.650     -0.785      0.432     -26.492      11.335
# CAS           -3.8111      6.228     -0.612      0.541     -16.018       8.395
# AAC            5.2300      9.882      0.529      0.597     -14.139      24.599
# ==============================================================================
# Done analyzing AJ now on to the next thing.
# Ancestry: AMR
# Optimization terminated successfully.
#          Current function value: 0.492725
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                  400
# Model:                          Logit   Df Residuals:                      389
# Method:                           MLE   Df Model:                           10
# Date:                Mon, 11 Mar 2024   Pseudo R-squ.:                 0.06487
# Time:                        09:17:29   Log-Likelihood:                -197.09
# converged:                       True   LL-Null:                       -210.76
# Covariance Type:            nonrobust   LLR p-value:                  0.002295
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.9688      1.262      2.352      0.019       0.495       5.442
# zSCORE         0.4893      0.125      3.902      0.000       0.244       0.735
# sex_for_qc    -0.1974      0.257     -0.769      0.442      -0.700       0.306
# age           -0.0274      0.012     -2.369      0.018      -0.050      -0.005
# AJ             2.3367      5.698      0.410      0.682      -8.830      13.504
# EUR            0.0424      1.477      0.029      0.977      -2.852       2.937
# EAS           14.5900     13.472      1.083      0.279     -11.814      40.994
# AMR            0.1898      0.947      0.200      0.841      -1.667       2.046
# AFR           -3.6517      3.578     -1.021      0.307     -10.665       3.361
# CAS            1.2830      7.907      0.162      0.871     -14.215      16.781
# AAC            3.7134     11.058      0.336      0.737     -17.959      25.386
# ==============================================================================
# Done analyzing AMR now on to the next thing.
# Ancestry: EAS
# Optimization terminated successfully.
#          Current function value: 0.538511
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                 2760
# Model:                          Logit   Df Residuals:                     2749
# Method:                           MLE   Df Model:                           10
# Date:                Mon, 11 Mar 2024   Pseudo R-squ.:                  0.2174
# Time:                        09:17:29   Log-Likelihood:                -1486.3
# converged:                       True   LL-Null:                       -1899.1
# Covariance Type:            nonrobust   LLR p-value:                6.647e-171
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -12.6099      0.622    -20.276      0.000     -13.829     -11.391
# zSCORE         0.3184      0.047      6.780      0.000       0.226       0.410
# sex_for_qc    -0.4594      0.090     -5.078      0.000      -0.637      -0.282
# age            0.0250      0.004      6.068      0.000       0.017       0.033
# AJ            -9.8641     31.281     -0.315      0.753     -71.174      51.445
# EUR           10.0313      6.240      1.608      0.108      -2.199      22.262
# EAS           12.9842      0.633     20.503      0.000      11.743      14.225
# AMR           35.0440     20.727      1.691      0.091      -5.580      75.668
# AFR           10.7038     16.087      0.665      0.506     -20.826      42.234
# CAS           10.7811      0.546     19.736      0.000       9.710      11.852
# AAC           11.1788     21.892      0.511      0.610     -31.729      54.086
# ==============================================================================
# Done analyzing EAS now on to the next thing.
# Ancestry: EUR
# Optimization terminated successfully.
#          Current function value: 0.646084
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                13969
# Model:                          Logit   Df Residuals:                    13958
# Method:                           MLE   Df Model:                           10
# Date:                Mon, 11 Mar 2024   Pseudo R-squ.:                 0.03296
# Time:                        09:17:29   Log-Likelihood:                -9025.1
# converged:                       True   LL-Null:                       -9332.8
# Covariance Type:            nonrobust   LLR p-value:                9.471e-126
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3649      0.143      2.548      0.011       0.084       0.646
# zSCORE         0.3156      0.018     17.503      0.000       0.280       0.351
# sex_for_qc    -0.3846      0.036    -10.695      0.000      -0.455      -0.314
# age            0.0155      0.002      9.444      0.000       0.012       0.019
# AJ             0.2555      0.382      0.669      0.503      -0.493       1.004
# EUR           -0.6770      0.097     -6.986      0.000      -0.867      -0.487
# EAS            4.5632      1.912      2.386      0.017       0.815       8.312
# AMR            2.2966      0.831      2.762      0.006       0.667       3.926
# AFR           -4.5460      1.763     -2.579      0.010      -8.001      -1.091
# CAS            3.8904      1.279      3.041      0.002       1.383       6.397
# AAC           -7.0454      1.700     -4.146      0.000     -10.376      -3.714
# ==============================================================================
# Done analyzing EUR now on to the next thing.
# Ancestry: CAS
# Optimization terminated successfully.
#          Current function value: 0.627084
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   CASE   No. Observations:                  414
# Model:                          Logit   Df Residuals:                      403
# Method:                           MLE   Df Model:                           10
# Date:                Mon, 11 Mar 2024   Pseudo R-squ.:                 0.09517
# Time:                        09:17:30   Log-Likelihood:                -259.61
# converged:                       True   LL-Null:                       -286.92
# Covariance Type:            nonrobust   LLR p-value:                 3.730e-08
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.4061      0.770     -1.826      0.068      -2.915       0.103
# zSCORE         0.3287      0.108      3.030      0.002       0.116       0.541
# sex_for_qc    -0.6870      0.219     -3.140      0.002      -1.116      -0.258
# age            0.0572      0.012      4.726      0.000       0.033       0.081
# AJ             2.1563      5.810      0.371      0.711      -9.230      13.543
# EUR            3.3139      2.105      1.575      0.115      -0.811       7.439
# EAS           -0.7016      1.791     -0.392      0.695      -4.213       2.809
# AMR           -0.8336      3.988     -0.209      0.834      -8.649       6.982
# AFR          -19.9984     16.904     -1.183      0.237     -53.130      13.133
# CAS           -1.4898      1.227     -1.214      0.225      -3.895       0.915
# AAC            4.8184     15.387      0.313      0.754     -25.339      34.976
# ==============================================================================
# Done analyzing CAS now on to the next thing.
